# %% [markdown]
# # Retinal OCT Imaging
# <hr style="border:2px solid pink">

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Background

# %% [markdown]
# Retinal optical coherence tomography (OCT) is a noninvasive imaging technique that essentially takes pictures of your retinas by measuring how much light reflects off the retina and optic nerve. It can be used to diagnose and manage diseases like diabetes-related retinopathy and glaucoma, amongst others. Millions of OCT scans are performed each year, and the analysis and interpretation of the images can take up a tremendous amount of time.

# %% [markdown]
# #### Business Problem

# %% [markdown]
# In order to save time and resources in analyzing and interpreting OCT scans, the problem at hand is to create a model that can predict whether a patient's retinal scan is normal or shows signs of CNV, DME, or DRUSEN diseases.
#
# The stakeholders are medical professionals, specifically ophthalmologists.

# %% [markdown]
# #### Data Understanding

# %% [markdown]
# The data for this project comes from Kaggle: https://www.kaggle.com/datasets/paultimothymooney/kermany2018/data. It
# contains 84,495 images, and 4 categories to predict (NORMAL, CNV, DME, or DRUSEN).
#
# The data is split into separate train, test, and validation folders. Within each of these, there are labeled sub-folders for each category, with each individual image labeled as such: (disease)-(randomized patient ID)-(image number by
# this patient).
#
# The images were selected from adult patients from the Shiley Eye Institute of the University of California San Diego, the California Retinal Research Foundation, Medical Center Ophthalmology Associates, the Shanghai First People’s Hospital, and Beijing Tongren Eye Center between July 1, 2013 and March 1, 2017.

# %% [markdown]
# #### Definitions

# %% [markdown]
# According to the National Library of Medicine, the following terms are defined as follows:
#
# 1. CNV: (Choroidal Neovascularization): a condition where abnormal blood vessels grow beneath the retina in the choroid area. These abnormal blood vessels can leak fluid or blood into the retina, which can cause vision loss. Commonly associated with age-related macular degeneration (AMD), which is a leading cause of vision loss in older adults.
#
# 2. DME (Diabetic Macular Edema): a complication of diabetic retinopathy, which is an eye condition that can develop in people with diabetes. DME occurs when fluid builds in the macula, the central part of the retina responsible for our central vision, leading to to vision impairment and distortion.
#
# 3. Drusen: small yellow or white deposits that accumulate in the retina. They can be found in the macula or the peripheral retina. Drusen are a hallmark sign of age-related macular degeneration (AMD).
#
# Treatment options for CNV, DME, and AMD may include medications, laser therapy, or in some cases, surgical interventions, depending on the specific condition and its stage.
# <hr style="border:2px solid pink">

# %% [markdown]
# # General Exploration

# %% [markdown]
# To get started, let's import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.image import imread
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, array_to_img, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Input
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_validate, StratifiedKFold

from sklearn.metrics import confusion_matrix, classification_report, make_scorer,\
recall_score,accuracy_score, precision_score, f1_score, roc_auc_score, ConfusionMatrixDisplay

from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall

from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Let's load in the data next. We need to create directories to where the data is saved, so let's start with that.

# %%
# create directory paths for each folder (train, test, and val)
train_path = '../Data/OCT2017/train'
test_path = '../Data/OCT2017/test'
val_path = '../Data/OCT2017/val'

# %% [markdown]
# We'll load in the data normally, no scaling or augmentations done, setting smaller batch sizes, and setting seed=42 to help with reproducibility.

# %%
original_train = ImageDataGenerator().flow_from_directory(train_path, batch_size=200, seed=42)
original_test = ImageDataGenerator().flow_from_directory(test_path, batch_size=100, seed=42)
original_val = ImageDataGenerator().flow_from_directory(val_path, batch_size=5, seed=42)

original_train_images, original_train_labels = next(original_train)
original_test_images, original_test_labels = next(original_test)
original_val_images, original_val_labels = next(original_val)
# Out:
# Found 83484 images belonging to 4 classes.
# Found 968 images belonging to 4 classes.
# Found 32 images belonging to 4 classes.

# %% [markdown]
# Notice that there are 4 classes: This represents normal, CNV, DME, or Drusen. Before visualizing the distribution, let's find out the original size of the images. We can loop through every image in the images datasets, take the size of it, add it to a list, and take the unique values of the list to confirm each image is the same size. But first, let's look at the shape as this should tell us the size as well.

# %%
print(f"Train Images Shape: {original_train_images.shape}")
print(f"Train Labels Shape: {original_train_labels.shape}")
print(f"Test Images Shape: {original_test_images.shape}")
print(f"Test Labels Shape: {original_test_labels.shape}")
print(f"Val Images Shape: {original_val_images.shape}")
print(f"Val Labels Shape: {original_val_labels.shape}")
# Out:
# Train Images Shape: (200, 256, 256, 3)
# Train Labels Shape: (200, 4)
# Test Images Shape: (100, 256, 256, 3)
# Test Labels Shape: (100, 4)
# Val Images Shape: (5, 256, 256, 3)
# Val Labels Shape: (5, 4)

# %% [markdown]
# It looks like each image is 256x256, but let's confirm this with the loop.

# %%
# loop through each images in the array and add the size to an empty list
train_sizes = []
test_sizes = []
val_sizes = []

for img in original_train_images:
    size = np.array(array_to_img(img).size)
    train_sizes.append(size)
    
for img in original_test_images:
    size = np.array(array_to_img(img).size)
    test_sizes.append(size)
    
for img in original_val_images:
    size = np.array(array_to_img(img).size)
    val_sizes.append(size)

# %%
# how many unique sizes are in each list? theoretically should be the same for each pic
# change the list of np arrays into a list of tuples, then take the "set" to get unique values

unique_train_sizes = list(set([tuple(size) for size in train_sizes]))
unique_test_sizes = list(set([tuple(size) for size in test_sizes]))
unique_val_sizes = list(set([tuple(size) for size in val_sizes]))

print(f"Original Train Image Size: {unique_train_sizes}")
print(f"Original Test Image Size: {unique_test_sizes}")
print(f"Original Val Image Size: {unique_val_sizes}")
# Out:
# Original Train Image Size: [(256, 256)]
# Original Test Image Size: [(256, 256)]
# Original Val Image Size: [(256, 256)]

# %% [markdown]
# Great! So the original images were indeed all 256x256. Since I noticed when loading in the data that there are 4 classes, let's now take a look at the distribution of the images in our dataset.

# %%
# first, create paths to each individual folder
normal_train_path = '../Data/OCT2017/train/NORMAL'
cnv_train_path = '../Data/OCT2017/train/CNV'
dme_train_path = '../Data/OCT2017/train/DME'
drusen_train_path = '../Data/OCT2017/train/DRUSEN'

# then, take the "length" of each folder to get the total number of images per category
normal_count = len(os.listdir(normal_train_path))
cnv_count = len(os.listdir(cnv_train_path))
dme_count = len(os.listdir(dme_train_path))
drusen_count = len(os.listdir(drusen_train_path))

# print the results
print(f'Normal Count: {normal_count}')
print(f'CNV Count: {cnv_count}')
print(f'DME Count: {dme_count}')
print(f'Drusen Count: {drusen_count}')
# Out:
# Normal Count: 26315
# CNV Count: 37205
# DME Count: 11348
# Drusen Count: 8616

# %% [markdown]
# So, there are 26,315 normal images, 37,205 CNV images, 11,348 DME images, and 8,616 Drusen images. Let's visualize the distribution.

# %%
# create the categories for X (categories) and Y (counts)
categories = ['Normal', 'CNV', 'DME', 'Drusen']
counts = [normal_count, cnv_count, dme_count, drusen_count]

# plot it
fig, ax = plt.subplots(figsize=(8,8))
plt.bar(categories, counts)
plt.xlabel('Category')
plt.ylabel('Number of Images')
plt.title('Distribution of Images')

# add counts to the top of the bars
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
    space = 1
    label = "{:.0f}".format(y_value)
    ax.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha='center', va='bottom')

plt.show();

# %% [markdown]
# This makes the distributions a little more clear! There's the most CNV images and the least Drusen images. Another thing to note is that our dataset it imbalanced - it may be beneficial to try data augmentation when modeling.
#
# Let's look at a few images and labels, so we can get an idea of what we're dealing with.

# %%
array_to_img(original_train_images[16])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x1DBB8D69D30>

# %%
original_train_labels[16]
# Out:
# array([0., 1., 0., 0.], dtype=float32)

# %%
original_train.class_indices
# Out:
# {'CNV': 0, 'DME': 1, 'DRUSEN': 2, 'NORMAL': 3}

# %% [markdown]
# Ok, so here, I see that each category corresponds to a class. CNV is class 0, DME is class 1, DRUSEN is class 2, and NORMAL is class 3.
#
# You would interpret the array [0., 1., 0., 0.] as follows: the first class (index 0, corresponds to CNV) has a probability of 0. The second class (index 1, corresponds to DME) has a probability of 1. The third class (index 2, corresponds to Drusen) and the fourth class (index 3, corresponds to normal) have probabilities of 0. This means that the image falls under class 1, and is DME.
#
# Let's plot a few images from each class, with their corresponding labels titling the plot.

# %%
# we have paths to each subfolder, so create a list paths that has them all
# create a list categories with each of the subfolders for labeling purposes
paths = [cnv_train_path, dme_train_path, drusen_train_path, normal_train_path]
categories = ['CNV', 'DME', 'DRUSEN', 'NORMAL']
fig, axes = plt.subplots(nrows=len(categories), ncols=3, figsize=(8, 8))

# iterate through paths to get the image path
for index, path in enumerate(paths):
    image_files = [file for file in os.listdir(path) if file.endswith('.jpeg')]
    
    # Limit the number of images to fit the layout
    total_images_per_cat = min(len(image_files), 3)
    
    for i in range(total_images_per_cat): 
        image_file = image_files[i]
        image_path = os.path.join(path, image_file)
        image = imread(image_path)
        image = image[:400, :400]
            
        # Display the image in a subplot
        ax = axes[index, i]
        ax.imshow(image, cmap='gray')
        ax.set_title(categories[index])  # Display the label
        ax.axis('off')

plt.show()

# %% [markdown]
# Great! So we have a little better understanding of what each image might look like. Let's start preprocessing so we can start modeling.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# To preprocess the data for a convolutional neural network, I'd like to start the following:
# 1. Scale the data: CNNs are sensitive to the scale of input features. By scaling the data, you ensure numerical stability during training. For images, pixel values are usually in the range [0,255], so you can rescale them to the range [0,1] by dividing each pixel by 255.
# 2. Resize the images: Smaller images can be less computationally intensive, leading to faster training times. This will also help ensure all inputs have the same shape. I will start with decreasing the size to 64x64.
# 3. Set the seed: To help with reproducibility, I will set the seed equal to 42.
# 4. Set the color mode: Since these images are originally in black and white, I will set the color_mode to grayscale to capture this.
# 5. Set data augmentation filters: we'll add filters such as flipping, shifting, rotating, and adjusting the brightness/zoom/shearness of the images. This will randomly apply these transformations to the images in order to add more data to the training set only, adding variety into our model and increasing the size of the training set.

# %%
# to remind myself where each path leads
train_path = '../Data/OCT2017/train'
test_path = '../Data/OCT2017/test'
val_path = '../Data/OCT2017/val'

# %%
# giving you the split already
# val set of 32 = last set you test on
# the test gen set, train the model on train split using val split, test it on this as unseen
# ideally after on a good model, train on entire train set, and test on val set
# then test on entire dataset and deploy
# try using 32x32 instead of 64x64, and then bump up as needed if there are decent scores

# add in some flips and rotates, adds x number of images for the model to train on
# dont worry too much about data augmentation and using the validation split in the fit method

# %%
# load in and preprocess the data in smaller batches
# Scale and transform the images, reshape to be 64x64, set the seed, and set the color to grayscale

target_size = (64,64)
train_generator = ImageDataGenerator(rescale=1.0/255.0,
                                         horizontal_flip=True,
                                         height_shift_range=0.2,
                                         width_shift_range=0.2,
                                         rotation_range=45,
                                         brightness_range=[0.2,1],
                                         zoom_range=0.2, 
                                         shear_range=0.2
                                         ).flow_from_directory(train_path, 
                                                               target_size=target_size, 
                                                               batch_size=200, 
                                                               seed=42, 
                                                               color_mode='grayscale') 

test_generator = ImageDataGenerator(rescale=1.0/255.0).flow_from_directory(test_path, 
                                                                         target_size=target_size, 
                                                                         batch_size=100, 
                                                                         seed=42, 
                                                                         color_mode='grayscale')

val_generator = ImageDataGenerator(rescale=1.0/255.0).flow_from_directory(val_path, 
                                                                        target_size=target_size, 
                                                                        batch_size=5, 
                                                                        seed=42, 
                                                                        color_mode='grayscale')

# next fetches the next batch of data and labels from the generator
# returns a batch of images and their labels
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)
# Out:
# Found 83484 images belonging to 4 classes.
# Found 968 images belonging to 4 classes.
# Found 32 images belonging to 4 classes.

# %% [markdown]
# Great! Let's check out the following to make sure everything was properly loaded.
# 1. Check out the shapes - everything should be rescaled to 64x64.
# 2. Check out the images - everything should be in black and white and smaller in size.

# %%
print(f"Train Images Shape: {train_images.shape}")
print(f"Train Labels Shape: {train_labels.shape}")
print(f"Test Images Shape: {test_images.shape}")
print(f"Test Labels Shape: {test_labels.shape}")
print(f"Val Images Shape: {val_images.shape}")
print(f"Val Labels Shape: {val_labels.shape}")
# Out:
# Train Images Shape: (200, 64, 64, 1)
# Train Labels Shape: (200, 4)
# Test Images Shape: (100, 64, 64, 1)
# Test Labels Shape: (100, 4)
# Val Images Shape: (5, 64, 64, 1)
# Val Labels Shape: (5, 4)

# %% [markdown]
# The shapes all look good! We can see that they are indeed 64x64 for the images, with the color channel as 1, indicating it is grayscale. Next, let's check out a few images.

# %%
train_generator.class_indices
# Out:
# {'CNV': 0, 'DME': 1, 'DRUSEN': 2, 'NORMAL': 3}

# %%
array_to_img(train_images[0])
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x1DBD76FA460>

# %%
# second value has probability of 1, so this DME
print(train_labels[0])
# Out:
# [0. 1. 0. 0.]

# %%
array_to_img(train_images[3])
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x1DBD76FAF40>

# %%
# last value has probability of 1, so this is normal
print(train_labels[3])
# Out:
# [0. 0. 0. 1.]

# %%
array_to_img(train_images[6])
# Out:
# <PIL.Image.Image image mode=L size=64x64 at 0x1DBD76FAC10>

# %%
# first value has probability of 1, so this is CNV
print(train_labels[6])
# Out:
# [1. 0. 0. 0.]

# %% [markdown]
# The images look good, they are in black and white, and scaled down to 64x64.
#
# Let's create some functions to help speed along some of the repetitive steps I will take.

# %% [markdown]
# # Create Functions

# %% [markdown]
# Next, let's build some functions next to help speed up viewing the results of each model.
# 1. A function that evaluates the model's train and test performance.
# 2. A function to plot the loss and accuracy.
# 3. A function to plot the confusion matrices.
#
# Let's start with the evaluate function. We'll print out the loss, accuracy, precision, and recall for both the train and test sets.

# %%
# 1. a function that evaluates the train and test performance of the model
def evaluate_model(model):
    train_results = model.evaluate(train_images, train_labels)
    test_results = model.evaluate(test_images, test_labels)
    
    print(f'Training Loss: {train_results[0]:.3} \nTraining Accuracy: {train_results[1]:.3} \nTraining Precision: {train_results[2]:.3} \nTraining Recall: {train_results[3]:.3}')  
    print('---------------------------')
    print(f'Testing Loss: {test_results[0]:.3} \nTesting Accuracy: {test_results[1]:.3} \nTesting Precision: {test_results[2]:.3} \nTesting Recall: {test_results[3]:.3}')

# %% [markdown]
# Next, let's create a function to plot the loss and accuracy for us.

# %%
# 2. a function to plot the loss and accuracy
def plot_metrics(results):
    train_loss = results.history['loss']
    train_accuracy = results.history['accuracy']

    val_loss = results.history['val_loss']
    val_accuracy = results.history['val_accuracy']

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    sns.lineplot(x=results.epoch, y=train_loss, ax=ax1, label='train_loss')
    sns.lineplot(x=results.epoch, y=train_accuracy, ax=ax2, label='train_accuracy')

    sns.lineplot(x=results.epoch, y=val_loss, ax=ax1, label='val_loss')
    sns.lineplot(x=results.epoch, y=val_accuracy, ax=ax2, label='val_accuracy')
    
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')

    plt.tight_layout()
    plt.show();

# %% [markdown]
# Finally, let's create a function to plot the confusion matrix for us.
#
# confusion matrix only plotting for individual batches, can't get it for the test set AFTER the train test split

# %%
# 3. a function to plot the confusion matrix
def plot_confusion_matrix(model, test_images, test_labels):
    y_pred = model.predict(test_images)
    y_pred = np.argmax(y_pred, axis=1)
    y_test = np.argmax(y_test, axis=1)

    cm = confusion_matrix(test_labels, y_pred)
    cm_df = pd.DataFrame(cm, index=['CNV', 'DME', 'DRUSEN', 'NORMAL'], columns=['CNV', 'DME', 'DRUSEN', 'NORMAL'])

    plt.figure(figsize=(5, 4))
    sns.heatmap(cm_df, annot=True)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()

# %%
# base = most frequent class - dummy classifier or class distribution
# baseline model = fsm, updates names

# %% [markdown]
# # Baseline model

# %% [markdown]
# For my baseline model, I will use the class distribution. We created the counts of each disease earlier, let's divide that by the total number of images to get the % distribution.

# %%
# should equal 83,484 as we saw when we loaded in the data using ImageDataGenerator
total = normal_count + cnv_count + dme_count + drusen_count
total
# Out:
# 83484

# %%
print(f'Normal % Distribution: {round((normal_count/total),2)}')
print(f'CNV % Distribution: {round((cnv_count/total),2)}')
print(f'DME % Distribution: {round((dme_count/total),2)}')
print(f'Drusen % Distribution: {round((drusen_count/total),2)}')
# Out:
# Normal % Distribution: 0.32
# CNV % Distribution: 0.45
# DME % Distribution: 0.14
# Drusen % Distribution: 0.1

# %% [markdown]
# # First Simple Model

# %% [markdown]
# For my first simple model, I will use a simple convolutional neural network with no hidden convolutional layers. I will begin with a dense input layer, expecting grayscale images of size 64x64x1. The input layer will have 64 units and use the ReLU activation function to introduce non-linearity and capture complex features. Next, I will add a flatten layer to transform the output from the previous layer into a 1D vector, preparing it for the final output layer. The output layer will consist of a dense layer with 4 units to represent the 4 classes, and it will use the softmax activation function, which is a common choice for multi-class classification tasks.

# %%
model_1 = Sequential()
model_1.add(Dense(64, activation='relu', input_shape=(64, 64, 1)))
model_1.add(Flatten())
model_1.add(Dense(4, activation='softmax'))

# %% [markdown]
# Let's view the architecture of the model.

# %%
model_1.summary()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_130 (Dense)            (None, 64, 64, 64)        128
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 262144)            0
# _________________________________________________________________
# dense_131 (Dense)            (None, 4)                 1048580
# =================================================================
# Total params: 1,048,708
# Trainable params: 1,048,708
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# So we can see that there are a LOT of parameters for such a simple model! Must be due to the size of the dataset. Let's compile the model using the adam optimizer (Adam is a good starting choice because Adam is an adaptive learning rate optimization algorithm. It should help with a more efficient convergence), categorical crossentropy as the loss (this is an appropriate choice for a multi-class classsification task), and accuracy as the metric.

# %%
precision = Precision()
recall = Recall()

# %%
model_1.compile(optimizer='adam',
                loss='categorical_crossentropy', 
                metrics=['accuracy', precision, recall])

# %% [markdown]
# Finally, let's fit the model on the train set. I will use the following parameters:
# - Smaller batches of 100, meaning my model will process 100 training samples at a time before adjusting the weights.
# - 25 epochs: epochs specifies how many times the model will iterate over the entire dataset.
# - Validation data: Remember the train test split? I will use the original test_images dataset with 243 images as my validation data in this case, as we have a separate test set from the train test split.

# %%
# set validation split = 25% of data, this is the holdout test set
model_1_results = model_1.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 282ms/step - loss: 1.5793 - accuracy: 0.2733 - precision_10: 0.5111 - recall_10: 0.1533 - val_loss: 2.2685 - val_accuracy: 0.3600 - val_precision_10: 0.3659 - val_recall_10: 0.3000
# Epoch 2/25
# 2/2 [==============================] - 0s 50ms/step - loss: 1.8853 - accuracy: 0.4733 - precision_10: 0.4831 - recall_10: 0.3800 - val_loss: 2.0356 - val_accuracy: 0.4000 - val_precision_10: 0.2778 - val_recall_10: 0.2000
# Epoch 3/25
# 2/2 [==============================] - 0s 51ms/step - loss: 1.4103 - accuracy: 0.4400 - precision_10: 0.4674 - recall_10: 0.2867 - val_loss: 1.8428 - val_accuracy: 0.3200 - val_precision_10: 0.1765 - val_recall_10: 0.0600
# Epoch 4/25
# 2/2 [==============================] - 0s 49ms/step - loss: 1.3681 - accuracy: 0.3467 - precision_10: 0.3818 - recall_10: 0.1400 - val_loss: 1.5175 - val_accuracy: 0.3200 - val_precision_10: 0.3333 - val_recall_10: 0.1000
# Epoch 5/25
# 2/2 [==============================] - 0s 50ms/step - loss: 1.0932 - accuracy: 0.5000 - precision_10: 0.7500 - recall_10: 0.2800 - val_loss: 1.7146 - val_accuracy: 0.3400 - val_precision_10: 0.3500 - val_recall_10: 0.1400
# Epoch 6/25
# 2/2 [==============================] - 0s 52ms/step - loss: 1.1449 - accuracy: 0.5733 - precision_10: 0.7778 - recall_10: 0.3733 - val_loss: 1.7550 - val_accuracy: 0.3600 - val_precision_10: 0.3636 - val_recall_10: 0.1600
# Epoch 7/25
# 2/2 [==============================] - 0s 50ms/step - loss: 1.1211 - accuracy: 0.6000 - precision_10: 0.7326 - recall_10: 0.4200 - val_loss: 1.6406 - val_accuracy: 0.4000 - val_precision_10: 0.3200 - val_recall_10: 0.1600
# Epoch 8/25
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0642 - accuracy: 0.6267 - precision_10: 0.7416 - recall_10: 0.4400 - val_loss: 1.5329 - val_accuracy: 0.3400 - val_precision_10: 0.3750 - val_recall_10: 0.1800
# Epoch 9/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.9373 - accuracy: 0.6667 - precision_10: 0.7727 - recall_10: 0.4533 - val_loss: 1.5065 - val_accuracy: 0.3200 - val_precision_10: 0.3889 - val_recall_10: 0.1400
# Epoch 10/25
# 2/2 [==============================] - 0s 48ms/step - loss: 0.8832 - accuracy: 0.6133 - precision_10: 0.7778 - recall_10: 0.4200 - val_loss: 1.5836 - val_accuracy: 0.3800 - val_precision_10: 0.3810 - val_recall_10: 0.1600
# Epoch 11/25
# 2/2 [==============================] - 0s 48ms/step - loss: 0.8846 - accuracy: 0.6333 - precision_10: 0.7692 - recall_10: 0.4000 - val_loss: 1.6227 - val_accuracy: 0.3800 - val_precision_10: 0.3333 - val_recall_10: 0.1400
# Epoch 12/25
# 2/2 [==============================] - 0s 54ms/step - loss: 0.8534 - accuracy: 0.6200 - precision_10: 0.8250 - recall_10: 0.4400 - val_loss: 1.5956 - val_accuracy: 0.4200 - val_precision_10: 0.3636 - val_recall_10: 0.1600
# Epoch 13/25
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7863 - accuracy: 0.6800 - precision_10: 0.9231 - recall_10: 0.4800 - val_loss: 1.5793 - val_accuracy: 0.4200 - val_precision_10: 0.4400 - val_recall_10: 0.2200
# Epoch 14/25
# 2/2 [==============================] - 0s 95ms/step - loss: 0.7666 - accuracy: 0.7067 - precision_10: 0.9080 - recall_10: 0.5267 - val_loss: 1.6396 - val_accuracy: 0.4200 - val_precision_10: 0.4231 - val_recall_10: 0.2200
# Epoch 15/25
# 2/2 [==============================] - 0s 106ms/step - loss: 0.7506 - accuracy: 0.7467 - precision_10: 0.9011 - recall_10: 0.5467 - val_loss: 1.6510 - val_accuracy: 0.4400 - val_precision_10: 0.4231 - val_recall_10: 0.2200
# Epoch 16/25
# 2/2 [==============================] - 0s 133ms/step - loss: 0.7259 - accuracy: 0.7667 - precision_10: 0.9043 - recall_10: 0.5667 - val_loss: 1.6399 - val_accuracy: 0.4400 - val_precision_10: 0.4167 - val_recall_10: 0.2000
# Epoch 17/25
# 2/2 [==============================] - 0s 156ms/step - loss: 0.6851 - accuracy: 0.7667 - precision_10: 0.9255 - recall_10: 0.5800 - val_loss: 1.6317 - val_accuracy: 0.4400 - val_precision_10: 0.3913 - val_recall_10: 0.1800
# Epoch 18/25
# 2/2 [==============================] - 0s 158ms/step - loss: 0.6481 - accuracy: 0.7800 - precision_10: 0.9551 - recall_10: 0.5667 - val_loss: 1.6300 - val_accuracy: 0.3600 - val_precision_10: 0.3600 - val_recall_10: 0.1800
# Epoch 19/25
# 2/2 [==============================] - 0s 150ms/step - loss: 0.6310 - accuracy: 0.8067 - precision_10: 0.9674 - recall_10: 0.5933 - val_loss: 1.6598 - val_accuracy: 0.3800 - val_precision_10: 0.3462 - val_recall_10: 0.1800
# Epoch 20/25
# 2/2 [==============================] - 0s 155ms/step - loss: 0.6192 - accuracy: 0.8067 - precision_10: 0.9794 - recall_10: 0.6333 - val_loss: 1.7111 - val_accuracy: 0.3600 - val_precision_10: 0.3200 - val_recall_10: 0.1600
# Epoch 21/25
# 2/2 [==============================] - 0s 165ms/step - loss: 0.5933 - accuracy: 0.8200 - precision_10: 0.9608 - recall_10: 0.6533 - val_loss: 1.7514 - val_accuracy: 0.3600 - val_precision_10: 0.3462 - val_recall_10: 0.1800
# Epoch 22/25
# 2/2 [==============================] - 0s 142ms/step - loss: 0.5665 - accuracy: 0.8333 - precision_10: 0.9712 - recall_10: 0.6733 - val_loss: 1.8038 - val_accuracy: 0.3800 - val_precision_10: 0.3333 - val_recall_10: 0.1800
# Epoch 23/25
# 2/2 [==============================] - 0s 117ms/step - loss: 0.5490 - accuracy: 0.8200 - precision_10: 0.9712 - recall_10: 0.6733 - val_loss: 1.8279 - val_accuracy: 0.4000 - val_precision_10: 0.3000 - val_recall_10: 0.1800
# Epoch 24/25
# 2/2 [==============================] - 0s 140ms/step - loss: 0.5302 - accuracy: 0.8467 - precision_10: 0.9722 - recall_10: 0.7000 - val_loss: 1.8268 - val_accuracy: 0.3800 - val_precision_10: 0.3226 - val_recall_10: 0.2000
# Epoch 25/25
# 2/2 [==============================] - 0s 132ms/step - loss: 0.5077 - accuracy: 0.8533 - precision_10: 0.9815 - recall_10: 0.7067 - val_loss: 1.8206 - val_accuracy: 0.4000 - val_precision_10: 0.3125 - val_recall_10: 0.2000

# %% [markdown]
# Great! Let's evaluate the scores.

# %%
evaluate_model(model_1)
# Out:
# 7/7 [==============================] - 0s 33ms/step - loss: 0.8238 - accuracy: 0.7400 - precision_10: 0.8286 - recall_10: 0.5800
# 4/4 [==============================] - 0s 27ms/step - loss: 3.4798 - accuracy: 0.2400 - precision_10: 0.2273 - recall_10: 0.2000
# Training Loss: 0.824
# Training Accuracy: 0.74
# Training Precision: 0.829
# Training Recall: 0.58
# ---------------------------
# Testing Loss: 3.48
# Testing Accuracy: 0.24
# Testing Precision: 0.227
# Testing Recall: 0.2

# %% [markdown]
# UPDATE: This is very overfit! We have a train accuracy of 91% and a test accuracy of 34%. Training recall and precision are pretty high, standing at 97% for precision and 81% for recall, but again, the test scores are abysmal. Test precision stands at 39% and test recall stands at 32%. Let's visualize the loss and accuracy.

# %%
plot_metrics(model_1_results)

# %% [markdown]
# UPDATE LATER:
# Here, we can see that the train loss is decreasing, val loss is jumping all over the place, train accuracy is steadily increasing, but val accuracy is low.

# %% [markdown]
# # Test Model

# %%
test_model = Sequential()

test_model.add(Conv2D(filters=64, 
                      kernel_size=(3,3), 
                      activation='relu', 
                      input_shape=(64, 64, 1)))

test_model.add(Dense(128, activation='relu'))
test_model.add(Dense(64, activation='relu'))
test_model.add(MaxPooling2D(pool_size=(2,2)))
test_model.add(Dropout(0.2))

test_model.add(Dense(128, activation='relu'))
test_model.add(Dense(64, activation='relu'))
test_model.add(MaxPooling2D(pool_size=(2,2)))
test_model.add(Dropout(0.2))

test_model.add(Dense(128, activation='relu'))
test_model.add(Dense(64, activation='relu'))
test_model.add(MaxPooling2D(pool_size=(2,2)))
test_model.add(Dropout(0.2))

test_model.add(Flatten())
test_model.add(Dense(128, activation='relu'))
test_model.add(Dense(64, activation='relu'))
test_model.add(Dropout(0.3))
test_model.add(Dense(4, activation='softmax'))

test_model.compile(optimizer=Adam(lr=0.00001), loss='categorical_crossentropy',metrics=['accuracy', precision, recall])

test_model.summary()
# Out:
# Model: "sequential_66"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_140 (Conv2D)          (None, 62, 62, 64)        640
# _________________________________________________________________
# dense_170 (Dense)            (None, 62, 62, 128)       8320
# _________________________________________________________________
# dense_171 (Dense)            (None, 62, 62, 64)        8256
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# dense_172 (Dense)            (None, 31, 31, 128)       8320
# _________________________________________________________________
# dense_173 (Dense)            (None, 31, 31, 64)        8256
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 15, 15, 64)        0
# _________________________________________________________________
# dense_174 (Dense)            (None, 15, 15, 128)       8320
# _________________________________________________________________
# dense_175 (Dense)            (None, 15, 15, 64)        8256
# _________________________________________________________________
# max_pooling2d_84 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_53 (Flatten)         (None, 3136)              0
# _________________________________________________________________
# dense_176 (Dense)            (None, 128)               401536
# _________________________________________________________________
# dense_177 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_178 (Dense)            (None, 4)                 260
# =================================================================
# Total params: 460,420
# Trainable params: 460,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
# callbacks=early_stop

# %%
test_model_results = test_model.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=150, 
                              epochs=10, 
                              class_weight=class_weights_dict)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 129ms/step - loss: 1.3606 - accuracy: 0.3933 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3853 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 0s 113ms/step - loss: 1.3617 - accuracy: 0.3467 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 0s 108ms/step - loss: 1.3611 - accuracy: 0.3733 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 0s 106ms/step - loss: 1.3616 - accuracy: 0.4400 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 107ms/step - loss: 1.3599 - accuracy: 0.4800 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 108ms/step - loss: 1.3611 - accuracy: 0.3867 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 127ms/step - loss: 1.3609 - accuracy: 0.4067 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3852 - val_accuracy: 0.3600 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 116ms/step - loss: 1.3602 - accuracy: 0.4400 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3851 - val_accuracy: 0.3600 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 97ms/step - loss: 1.3613 - accuracy: 0.3667 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3851 - val_accuracy: 0.3800 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 100ms/step - loss: 1.3600 - accuracy: 0.4000 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.3851 - val_accuracy: 0.3800 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00

# %%
evaluate_model(test_model)
# Out:
# 7/7 [==============================] - 0s 45ms/step - loss: 1.3839 - accuracy: 0.4400 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00
# 4/4 [==============================] - 0s 37ms/step - loss: 1.3860 - accuracy: 0.2200 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00
# Training Loss: 1.38
# Training Accuracy: 0.44
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.39
# Testing Accuracy: 0.22
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=3)

# %%
y_ints = [y.argmax() for y in train_labels]
class_weights = compute_class_weight(class_weight='balanced',
                                                  classes=np.unique(y_ints),
                                                  y=y_ints)

# turn into dict so it can be put in the fit statement
class_weights_dict = {class_index: weight for class_index, weight in enumerate(class_weights)}

# %%
class_weights_dict
# Out:
# {0: 0.5376344086021505,
#  1: 1.7241379310344827,
#  2: 2.7777777777777777,
#  3: 0.8333333333333334}

# %%
test_2 = Sequential()
test_2.add(Conv2D(64, (3, 3), activation='relu', input_shape=(64, 64, 1)))
test_2.add(MaxPooling2D(pool_size=(2, 2)))
test_2.add(Dropout(0.2))
test_2.add(Dense(128, activation='relu'))

test_2.add(Flatten())
# test_2.add(Dense(128, activation='relu'))
# test_2.add(Dropout(0.2))
test_2.add(Dense(64, activation='relu'))
test_2.add(Dense(32, activation='relu'))
test_2.add(Dense(4, activation='softmax'))

test_2.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy', precision, recall])

test_2.summary()
# Out:
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_144 (Conv2D)          (None, 62, 62, 64)        640
# _________________________________________________________________
# max_pooling2d_88 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# dense_192 (Dense)            (None, 31, 31, 128)       8320
# _________________________________________________________________
# flatten_57 (Flatten)         (None, 123008)            0
# _________________________________________________________________
# dense_193 (Dense)            (None, 64)                7872576
# _________________________________________________________________
# dense_194 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_195 (Dense)            (None, 4)                 132
# =================================================================
# Total params: 7,883,748
# Trainable params: 7,883,748
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_2_results = test_2.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=150, 
                              epochs=50, 
                              class_weight=class_weights_dict, 
                              callbacks=early_stop)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 411ms/step - loss: 1.3624 - accuracy: 0.1800 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.4162 - val_accuracy: 0.4000 - val_precision_10: 0.3125 - val_recall_10: 0.1000
# Epoch 2/50
# 1/1 [==============================] - 0s 51ms/step - loss: 1.4226 - accuracy: 0.4867 - precision_10: 0.6094 - recall_10: 0.2600 - val_loss: 2.1676 - val_accuracy: 0.1600 - val_precision_10: 0.1667 - val_recall_10: 0.1000
# Epoch 3/50
# 1/1 [==============================] - 0s 51ms/step - loss: 1.8708 - accuracy: 0.1400 - precision_10: 0.1509 - recall_10: 0.1067 - val_loss: 1.6108 - val_accuracy: 0.1600 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 50ms/step - loss: 1.4186 - accuracy: 0.1400 - precision_10: 0.1304 - recall_10: 0.0200 - val_loss: 1.3503 - val_accuracy: 0.3400 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2892 - accuracy: 0.4800 - precision_10: 0.8000 - recall_10: 0.0267 - val_loss: 1.3591 - val_accuracy: 0.4000 - val_precision_10: 0.5000 - val_recall_10: 0.0800
# Epoch 6/50
# 1/1 [==============================] - 0s 49ms/step - loss: 1.3543 - accuracy: 0.4933 - precision_10: 0.8000 - recall_10: 0.1600 - val_loss: 1.3646 - val_accuracy: 0.4000 - val_precision_10: 0.4286 - val_recall_10: 0.0600
# Epoch 7/50
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3404 - accuracy: 0.4933 - precision_10: 0.8333 - recall_10: 0.1667 - val_loss: 1.3636 - val_accuracy: 0.3600 - val_precision_10: 0.5000 - val_recall_10: 0.0400

# %%
evaluate_model(test_2)
# Out:
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2654 - accuracy: 0.4600 - precision_10: 0.7059 - recall_10: 0.0600
# 4/4 [==============================] - 0s 14ms/step - loss: 1.4812 - accuracy: 0.2200 - precision_10: 0.1765 - recall_10: 0.0300
# Training Loss: 1.27
# Training Accuracy: 0.46
# Training Precision: 0.706
# Training Recall: 0.06
# ---------------------------
# Testing Loss: 1.48
# Testing Accuracy: 0.22
# Testing Precision: 0.176
# Testing Recall: 0.03

# %% [markdown]
# # Model #2

# %% [markdown]
# My first simple model was very overfit, let's try making it more complex and adding some hidden layers. Will add convolutional and max pooling.

# %%
model_2 = Sequential()

model_2.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_2.add(MaxPooling2D(pool_size=(2,2)))

model_2.add(Conv2D(64, (3, 3), activation='relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))

model_2.add(Flatten())
model_2.add(Dense(4, activation='softmax'))

model_2.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy', precision, recall])

model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 50180
# =================================================================
# Total params: 68,996
# Trainable params: 68,996
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# A lot less params.

# %%
model_2_results = model_2.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7121 - accuracy: 0.7400 - precision: 0.8571 - recall: 0.6000 - val_loss: 1.2390 - val_accuracy: 0.5000 - val_precision: 0.6957 - val_recall: 0.3200
# Epoch 2/25
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6860 - accuracy: 0.7467 - precision: 0.8774 - recall: 0.6200 - val_loss: 1.2544 - val_accuracy: 0.5200 - val_precision: 0.6296 - val_recall: 0.3400
# Epoch 3/25
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6505 - accuracy: 0.7667 - precision: 0.8889 - recall: 0.6400 - val_loss: 1.2950 - val_accuracy: 0.4600 - val_precision: 0.5517 - val_recall: 0.3200
# Epoch 4/25
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6264 - accuracy: 0.8133 - precision: 0.9174 - recall: 0.6667 - val_loss: 1.3245 - val_accuracy: 0.4600 - val_precision: 0.5333 - val_recall: 0.3200
# Epoch 5/25
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5881 - accuracy: 0.8067 - precision: 0.8966 - recall: 0.6933 - val_loss: 1.3577 - val_accuracy: 0.4400 - val_precision: 0.5625 - val_recall: 0.3600
# Epoch 6/25
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5897 - accuracy: 0.7800 - precision: 0.8534 - recall: 0.6600 - val_loss: 1.3222 - val_accuracy: 0.4400 - val_precision: 0.5758 - val_recall: 0.3800
# Epoch 7/25
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5579 - accuracy: 0.8400 - precision: 0.9153 - recall: 0.7200 - val_loss: 1.3894 - val_accuracy: 0.4400 - val_precision: 0.5484 - val_recall: 0.3400
# Epoch 8/25
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5159 - accuracy: 0.8533 - precision: 0.9244 - recall: 0.7333 - val_loss: 1.5118 - val_accuracy: 0.4200 - val_precision: 0.5278 - val_recall: 0.3800
# Epoch 9/25
# 2/2 [==============================] - 0s 59ms/step - loss: 0.
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2332 - accuracy: 0.9333 - precision: 0.9577 - recall: 0.9067 - val_loss: 1.9202 - val_accuracy: 0.4600 - val_precision: 0.4419 - val_recall: 0.3800

# %%
evaluate_model(model_2)
# Out:
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6436 - accuracy: 0.8400 - precision: 0.8495 - recall: 0.7900
# 4/4 [==============================] - 0s 14ms/step - loss: 4.7955 - accuracy: 0.2600 - precision: 0.2778 - recall: 0.2500
# Training Loss: 0.644
# Training Accuracy: 0.84
# Training Precision: 0.849
# Training Recall: 0.79
# ---------------------------
# Testing Loss: 4.8
# Testing Accuracy: 0.26
# Testing Precision: 0.278
# Testing Recall: 0.25

# %% [markdown]
# UPDATE: A little bit better - train accuracy at 77%, precision at 86%, recall at 65%. Testing accuracy is higher at 44%, precision at 43%, and recall at 30%.

# %%
plot_metrics(model_2_results)

# %% [markdown]
# # Model #3

# %% [markdown]
# Let's add more complexity - more conv and 2d layers, add some dense layers, and add dense layer after flatten.

# %%
model_3 = Sequential()

model_3.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_3.add(MaxPooling2D(pool_size=(2,2)))

model_3.add(Conv2D(64, (3, 3), activation='relu'))
model_3.add(MaxPooling2D(pool_size=(2,2)))

model_3.add(Conv2D(32, (3, 3), activation='relu'))
model_3.add(MaxPooling2D(pool_size=(2,2)))

model_3.add(Flatten())
model_3.add(Dense(32, activation='relu'))
model_3.add(Dense(16, activation='relu'))
model_3.add(Dense(4, activation='softmax'))

model_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 12, 12, 32)        18464
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                36896
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 74,772
# Trainable params: 74,772
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# More params than first model, less than baseline. Fit the model.

# %%
# dont do train test split
# train on entirety of train data
# use val data as pre given test data
# validation data = the test set

# research how batch size in image data generator affects batch size - how affects .fit on model
# epochs makes a difference

# %%
model_3_results = model_3.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 0s 230ms/step - loss: 1.3870 - accuracy: 0.1333 - precision: 0.2500 - recall: 0.0840 - val_loss: 1.3728 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 61ms/step - loss: 1.3641 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3460 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3341 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3154 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 0s 59ms/step - loss: 1.2800 - accuracy: 0.4867 - precision: 0.3333 - recall: 0.0200 - val_loss: 1.3045 - val_accuracy: 0.4000 - val_precision: 0.5217 - val_recall: 0.2400
# Epoch 5/25
# 2/2 [==============================] - 0s 55ms/step - loss: 1.2580 - accuracy: 0.4867 - precision: 0.5128 - recall: 0.2667 - val_loss: 1.3001 - val_accuracy: 0.4000 - val_precision: 0.4688 - val_recall: 0.3000
# Epoch 6/25
# 2/2 [==============================] - 0s 53ms/step - loss: 1.2459 - accuracy: 0.4867 - precision: 0.5102 - recall: 0.3333 - val_loss: 1.2653 - val_accuracy: 0.4000 - val_precision: 0.5455 - val_recall: 0.2400
# Epoch 7/25
# 2/2 [==============================] - 0s 57ms/step - loss: 1.
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1190 - accuracy: 0.5533 - precision: 0.8438 - recall: 0.1800 - val_loss: 1.1796 - val_accuracy: 0.4600 - val_precision: 0.7059 - val_recall: 0.2400
# Epoch 25/25
# 2/2 [==============================] - 0s 58ms/step - loss: 1.1080 - accuracy: 0.5400 - precision: 0.7241 - recall: 0.2800 - val_loss: 1.1985 - val_accuracy: 0.4600 - val_precision: 0.5217 - val_recall: 0.2400

# %%
# not complex enough
# feature engineering!! add data (image augmentation)
# start simply (binary) either has it or it doesn't, then think about the mutliclass

# %%
evaluate_model(model_3)
# Out:
# 7/7 [==============================] - 0s 12ms/step - loss: 1.1223 - accuracy: 0.5150 - precision: 0.6571 - recall: 0.3450
# 4/4 [==============================] - 0s 9ms/step - loss: 1.9708 - accuracy: 0.2900 - precision: 0.2308 - recall: 0.1200
# Training Loss: 1.12
# Training Accuracy: 0.515
# Training Precision: 0.657
# Training Recall: 0.345
# ---------------------------
# Testing Loss: 1.97
# Testing Accuracy: 0.29
# Testing Precision: 0.231
# Testing Recall: 0.12

# %% [markdown]
# Worse all around

# %%
plot_metrics(model_3_results)

# %% [markdown]
# Let's try increasing the input units. Same model as second model otherwise.

# %% [markdown]
# # Model #4

# %%
model_4 = Sequential()

model_4.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_4.add(MaxPooling2D(pool_size=(2,2)))

model_4.add(Conv2D(128, (3, 3), activation='relu')) # increased from 64 to 128
model_4.add(MaxPooling2D(pool_size=(2,2)))

model_4.add(Conv2D(64, (3, 3), activation='relu')) # increased from 32 to 64
model_4.add(MaxPooling2D(pool_size=(2,2)))

model_4.add(Flatten())
model_4.add(Dense(64, activation='relu')) # increased from 32 to 64
model_4.add(Dense(32, activation='relu')) # increased from 16 to 32
model_4.add(Dense(4, activation='softmax'))

model_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_4.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 29, 29, 128)       36992
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 12, 12, 64)        73792
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                147520
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 260,836
# Trainable params: 260,836
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# More params!

# %%
model_4_results = model_4.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 259ms/step - loss: 1.3827 - accuracy: 0.2733 - precision: 0.2308 - recall: 0.0480 - val_loss: 1.3576 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 86ms/step - loss: 1.3461 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3024 - val_accuracy: 0.4000 - val_precision: 0.6667 - val_recall: 0.0400
# Epoch 3/25
# 2/2 [==============================] - 0s 82ms/step - loss: 1.2638 - accuracy: 0.4867 - precision: 0.5217 - recall: 0.0800 - val_loss: 1.3288 - val_accuracy: 0.4000 - val_precision: 0.4545 - val_recall: 0.3000
# Epoch 4/25
# 2/2 [==============================] - 0s 80ms/step - loss: 1.2785 - accuracy: 0.4867 - precision: 0.5000 - recall: 0.3533 - val_loss: 1.2674 - val_accuracy: 0.4000 - val_precision: 0.5238 - val_recall: 0.2200
# Epoch 5/25
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2249 - accuracy: 0.4867 - precision: 0.5143 - recall: 0.2400 - val_loss: 1.2494 - val_accuracy: 0.4000 - val_precision: 0.6000 - val_recall: 0.1200
# Epoch 6/25
# 2/2 [==============================] - 0s 77ms/step - loss: 1.2133 - accuracy: 0.4867 - precision: 0.5652 - recall: 0.0867 - val_loss: 1.2455 - val_accuracy: 0.4000 - val_precision: 0.6000 - val_recall: 0.1200
# Epoch 7/25
# Epoch 21/25
# 2/2 [==============================] - 0s 143ms/step - loss: 1.1083 - accuracy: 0.5600 - precision: 0.7568 - recall: 0.1867 - val_loss: 1.1905 - val_accuracy: 0.4800 - val_precision: 0.6250 - val_recall: 0.2000
# Epoch 22/25
# 2/2 [==============================] - 0s 161ms/step - loss: 1.0880 - accuracy: 0.5333 - precision: 0.7067 - recall: 0.3533 - val_loss: 1.2260 - val_accuracy: 0.4600 - val_precision: 0.4054 - val_recall: 0.3000
# Epoch 23/25
# 2/2 [==============================] - 0s 143ms/step - loss: 1.0902 - accuracy: 0.5467 - precision: 0.6146 - recall: 0.3933 - val_loss: 1.1817 - val_accuracy: 0.4600 - val_precision: 0.6471 - val_recall: 0.2200
# Epoch 24/25
# 2/2 [==============================] - 0s 134ms/step - loss: 1.0639 - accuracy: 0.5667 - precision: 0.7656 - recall: 0.3267 - val_loss: 1.1669 - val_accuracy: 0.4800 - val_precision: 0.7333 - val_recall: 0.2200
# Epoch 25/25
# 2/2 [==============================] - 0s 129ms/step - loss: 1.0505 - accuracy: 0.6000 - precision: 0.7143 - recall: 0.3000 - val_loss: 1.1822 - val_accuracy: 0.4600 - val_precision: 0.6000 - val_recall: 0.2400

# %%
evaluate_model(model_4)
# Out:
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0678 - accuracy: 0.5700 - precision: 0.6939 - recall: 0.3400
# 4/4 [==============================] - 0s 12ms/step - loss: 2.1485 - accuracy: 0.2800 - precision: 0.3239 - recall: 0.2300
# Training Loss: 1.07
# Training Accuracy: 0.57
# Training Precision: 0.694
# Training Recall: 0.34
# ---------------------------
# Testing Loss: 2.15
# Testing Accuracy: 0.28
# Testing Precision: 0.324
# Testing Recall: 0.23

# %%
plot_metrics(model_4_results)

# %% [markdown]
# Performed about the same as second model.

# %% [markdown]
# Let's try adding regularization.

# %% [markdown]
# # Model #5

# %% [markdown]
# Add regulurization, start with just L2.

# %%
model_5 = Sequential()

model_5.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.01)))

model_5.add(MaxPooling2D(pool_size=(2,2)))

model_5.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_5.add(MaxPooling2D(pool_size=(2,2)))

model_5.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_5.add(MaxPooling2D(pool_size=(2,2)))

model_5.add(Flatten())
model_5.add(Dense(64, activation='relu'))
model_5.add(Dense(32, activation='relu'))
model_5.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.01)))

model_5.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_5.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 29, 29, 128)       36992
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 12, 12, 64)        73792
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                147520
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 260,836
# Trainable params: 260,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_5_results = model_5.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 266ms/step - loss: 2.8172 - accuracy: 0.3467 - precision: 0.3239 - recall: 0.0920 - val_loss: 2.6703 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 78ms/step - loss: 2.6239 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.5001 - val_accuracy: 0.4000 - val_precision: 0.6000 - val_recall: 0.1200
# Epoch 3/25
# 2/2 [==============================] - 0s 92ms/step - loss: 2.4520 - accuracy: 0.4867 - precision: 0.4808 - recall: 0.1667 - val_loss: 2.4462 - val_accuracy: 0.4000 - val_precision: 0.4412 - val_recall: 0.3000
# Epoch 4/25
- val_accuracy: 0.4000 - val_precision: 0.6667 - val_recall: 0.1600
# Epoch 19/25
# 2/2 [==============================] - 0s 99ms/step - loss: 1.4562 - accuracy: 0.4867 - precision: 0.6364 - recall: 0.1400 - val_loss: 1.5096 - val_accuracy: 0.4000 - val_precision: 0.5556 - val_recall: 0.2000
# Epoch 20/25
# 2/2 [==============================] - 0s 92ms/step - loss: 1.4315 - accuracy: 0.4867 - precision: 0.6833 - recall: 0.2733 - val_loss: 1.4943 - val_accuracy: 0.4000 - val_precision: 0.5909 - val_recall: 0.2600
# Epoch 21/25
# 2/2 [==============================] - 0s 88ms/step - loss: 1.4117 - accuracy: 0.4933 - precision: 0.5930 - recall: 0.3400 - val_loss: 1.4576 - val_accuracy: 0.4400 - val_precision: 0.5625 - val_recall: 0.1800
# Epoch 22/25
# 2/2 [==============================] - 0s 120ms/step - loss: 1.3834 - accuracy: 0.5333 - precision: 0.6667 - recall: 0.1733 - val_loss: 1.4276 - val_accuracy: 0.5000 - val_precision: 0.7500 - val_recall: 0.1200
# Epoch 23/25
# 2/2 [==============================] - 0s 166ms/step - loss: 1.3644 - accuracy: 0.5267 - precision: 0.7917 - recall: 0.1267 - val_loss: 1.4142 - val_accuracy: 0.4800 - val_precision: 0.5625 - val_recall: 0.1800
# Epoch 24/25
# 2/2 [==============================] - 0s 140ms/step - loss: 1.3481 - accuracy: 0.5133 - precision: 0.6458 - recall: 0.2067 - val_loss: 1.4109 - val_accuracy: 0.4600 - val_precision: 0.5500 - val_recall: 0.2200
# Epoch 25/25
# 2/2 [==============================] - 0s 154ms/step - loss: 1.3174 - accuracy: 0.5133 - precision: 0.6400 - recall: 0.3200 - val_loss: 1.3795 - val_accuracy: 0.4600 - val_precision: 0.6111 - val_recall: 0.2200

# %%
evaluate_model(model_5)
# Out:
# 7/7 [==============================] - 0s 18ms/step - loss: 1.3196 - accuracy: 0.5200 - precision: 0.6757 - recall: 0.2500
# 4/4 [==============================] - 0s 13ms/step - loss: 1.9471 - accuracy: 0.2700 - precision: 0.2800 - recall: 0.1400
# Training Loss: 1.32
# Training Accuracy: 0.52
# Training Precision: 0.676
# Training Recall: 0.25
# ---------------------------
# Testing Loss: 1.95
# Testing Accuracy: 0.27
# Testing Precision: 0.28
# Testing Recall: 0.14

# %% [markdown]
# About the same.

# %%
plot_metrics(model_5_results)

# %% [markdown]
# Let's try adding dropout regularization.

# %% [markdown]
# # Model #6

# %%
model_6 = Sequential()

model_6.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.01)))

model_6.add(MaxPooling2D(pool_size=(2,2)))
model_6.add(Dropout(0.8))

model_6.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_6.add(MaxPooling2D(pool_size=(2,2)))
model_6.add(Dropout(0.5))

model_6.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_6.add(MaxPooling2D(pool_size=(2,2)))
model_6.add(Dropout(0.2))

model_6.add(Flatten())
model_6.add(Dense(64, activation='relu'))
model_6.add(Dense(32, activation='relu'))
model_6.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.01)))

model_6.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_6.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 29, 29, 128)       36992
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 64)        73792
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                147520
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 260,836
# Trainable params: 260,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_6_results = model_6.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s
# Epoch 24/25
# 2/2 [==============================] - 0s 245ms/step - loss: 1.5013 - accuracy: 0.5400 - precision: 0.6883 - recall: 0.3533 - val_loss: 1.6096 - val_accuracy: 0.4400 - val_precision: 0.8000 - val_recall: 0.0800
# Epoch 25/25
# 2/2 [==============================] - 0s 232ms/step - loss: 1.5033 - accuracy: 0.5533 - precision: 0.6000 - recall: 0.3400 - val_loss: 1.5962 - val_accuracy: 0.4400 - val_precision: 1.0000 - val_recall: 0.0800

# %%
evaluate_model(model_6)
# Out:
# 7/7 [==============================] - 0s 49ms/step - loss: 1.5589 - accuracy: 0.5200 - precision: 0.8750 - recall: 0.0350
# 4/4 [==============================] - 0s 35ms/step - loss: 1.8550 - accuracy: 0.2600 - precision: 0.2222 - recall: 0.0200
# Training Loss: 1.56
# Training Accuracy: 0.52
# Training Precision: 0.875
# Training Recall: 0.035
# ---------------------------
# Testing Loss: 1.85
# Testing Accuracy: 0.26
# Testing Precision: 0.222
# Testing Recall: 0.02

# %%
plot_metrics(model_6_results)

# %% [markdown]
# # Model #6

# %% [markdown]
# Let's try adding dense hidden layers.

# %%
model_7 = Sequential()

model_7.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.01)))

model_7.add(Dense(128, activation='relu'))
model_7.add(MaxPooling2D(pool_size=(2,2)))
model_7.add(Dropout(0.8))

model_7.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_7.add(Dense(64, activation='relu'))
model_7.add(MaxPooling2D(pool_size=(2,2)))
model_7.add(Dropout(0.5))

model_7.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_7.add(Dense(32, activation='relu'))
model_7.add(MaxPooling2D(pool_size=(2,2)))
model_7.add(Dropout(0.2))

model_7.add(Flatten())
model_7.add(Dense(64, activation='relu'))
model_7.add(Dense(32, activation='relu'))
model_7.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.01)))

model_7.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_7.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# dense_19 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# dense_20 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# dense_21 (Dense)             (None, 12, 12, 32)        2080
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                73792
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_24 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 275,396
# Trainable params: 275,396
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# That added more params, let's check it out.

# %%
model_7_results = model_7.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 3s 1s/step - loss: 3.3418 - accuracy: 0.3867 - precision: 0.2222 - recall: 0.0080 - val_loss: 3.1941 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 1s 710ms/step - loss: 3.1068 - accuracy: 0.4867 - precision: 0.4783 - recall: 0.0733 - val_loss: 3.0034 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 1s 685ms/step - loss: 2.9132 - accuracy: 0.4867 - precision: 0.4861 - recall: 0.2333 - val_loss: 2.8531 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 1s 552ms/step - loss: 2.7537 - accuracy: 0.4867 - precision: 0.5111 - recall: 0.1533 - val_loss: 2.7121 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 1s 632ms/step - loss: 2.5983 - accuracy: 0.4867 - precision: 0.5172 - recall: 0.1000 - val_loss: 2.5649 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s 582ms/step - loss: 2.4799 - accuracy: 0.4867 - precision: 0.4915 - recall: 0.1933 - val_loss: 2.4366 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] - 1s 534ms/step - loss: 2.3664 - accuracy: 0.4867 - precision: 0.5098 - recall: 0.1733 - val_loss: 2.3405 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 2/2 [==============================] - 1s 706ms/step - loss: 2.2512 - accuracy: 0.4867 - precision: 0.4211 - recall: 0.0533 - val_loss: 2.2418 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 1s 548ms/step - loss: 2.1601 - accuracy: 0.4867 - precision: 0.4571 - recall: 0.1067 - val_loss: 2.1539 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 1s 574ms/step - loss: 2.0629 - accuracy: 0.4867 - precision: 0.4815 - recall: 0.0867 - val_loss: 2.0785 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 2/2 [==============================] - 1s 561ms/step - loss: 1.9816 - accuracy: 0.4867 - precision: 0.5758 - recall: 0.1267 - val_loss: 1.9983 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 2/2 [==============================] - 1s 553ms/step - loss: 1.9126 - accuracy: 0.4867 - precision: 0.5246 - recall: 0.2133 - val_loss: 1.9250 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 2/2 [==============================] - 1s 505ms/step - loss: 1.8350 - accuracy: 0.4867 - precision: 0.5352 - recall: 0.2533 - val_loss: 1.8619 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 2/2 [==============================] - 1s 493ms/step - loss: 1.7858 - accuracy: 0.4867 - precision: 0.5385 - recall: 0.2333 - val_loss: 1.8049 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 2/2 [==============================] - 1s 502ms/step - loss: 1.7218 - accuracy: 0.4867 - precision: 0.6111 - recall: 0.1467 - val_loss: 1.7510 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/25
# 2/2 [==============================] - 1s 444ms/step - loss: 1.6796 - accuracy: 0.4867 - precision: 0.5484 - recall: 0.1133 - val_loss: 1.7020 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/25
# 2/2 [==============================] - 1s 519ms/step - loss: 1.6309 - accuracy: 0.4867 - precision: 0.5690 - recall: 0.2200 - val_loss: 1.6616 - val_accuracy: 0.4000 - val_precision: 1.0000 - val_recall: 0.0400
# Epoch 18/25
# 2/2 [==============================] - 1s 475ms/step - loss: 1.6067 - accuracy: 0.4867 - precision: 0.5400 - recall: 0.3600 - val_loss: 1.6309 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 1s 483ms/step - loss: 1.5568 - accuracy: 0.4867 - precision: 0.5286 - recall: 0.2467 - val_loss: 1.6063 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 1s 451ms/step - loss: 1.5259 - accuracy: 0.4867 - precision: 0.6111 - recall: 0.1467 - val_loss: 1.5780 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 1s 438ms/step - loss: 1.4969 - accuracy: 0.4867 - precision: 0.6667 - recall: 0.1333 - val_loss: 1.5455 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 1s 417ms/step - loss: 1.4859 - accuracy: 0.4867 - precision: 0.5745 - recall: 0.1800 - val_loss: 1.5153 - val_accuracy: 0.4000 - val_precision: 0.7500 - val_recall: 0.0600
# Epoch 23/25
# 2/2 [==============================] - 1s 506ms/step - loss: 1.4505 - accuracy: 0.4867 - precision: 0.5455 - recall: 0.2800 - val_loss: 1.4931 - val_accuracy: 0.4000 - val_precision: 1.0000 - val_recall: 0.0400
# Epoch 24/25
# 2/2 [==============================] - 1s 440ms/step - loss: 1.4283 - accuracy: 0.4933 - precision: 0.6774 - recall: 0.1400 - val_loss: 1.4792 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 1s 480ms/step - loss: 1.4133 - accuracy: 0.4933 - precision: 0.6667 - recall: 0.0667 - val_loss: 1.4610 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_7)
# Out:
# 7/7 [==============================] - 1s 106ms/step - loss: 1.4354 - accuracy: 0.4900 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 76ms/step - loss: 1.7386 - accuracy: 0.2800 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.44
# Training Accuracy: 0.49
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.74
# Testing Accuracy: 0.28
# Testing Precision: 0.0
# Testing Recall: 0.0

# %% [markdown]
# The loss looks better but the accuracy! still terrible ugh.

# %%
plot_metrics(model_7_results)

# %% [markdown]
# # Model #8

# %% [markdown]
# Not really getting better results yet, still overfit and not performing that well. Let's try adding early stopping to help with the overfitting.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %%
model_8 = Sequential()

model_8.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.01)))

model_8.add(Dense(128, activation='relu'))
model_8.add(MaxPooling2D(pool_size=(2,2)))
model_8.add(Dropout(0.8))

model_8.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_8.add(Dense(64, activation='relu'))
model_8.add(MaxPooling2D(pool_size=(2,2)))
model_8.add(Dropout(0.5))

model_8.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_8.add(Dense(32, activation='relu'))
model_8.add(MaxPooling2D(pool_size=(2,2)))
model_8.add(Dropout(0.2))

model_8.add(Flatten())
model_8.add(Dense(64, activation='relu'))
model_8.add(Dense(32, activation='relu'))
model_8.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.01)))

model_8.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_8.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# dense_31 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# dense_32 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 12, 12, 64)        36928
# _________________________________________________________________
# dense_33 (Dense)             (None, 12, 12, 32)        2080
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                73792
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_36 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 275,396
# Trainable params: 275,396
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_8_results = model_8.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 2s 1s/step - loss: 3.3472 - accuracy: 0.1800 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.1853 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 1s 656ms/step - loss: 3.1333 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.9978 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 1s 679ms/step - loss: 2.9160 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.8043 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 1s 563ms/step - loss: 2.7010 - accuracy: 0.4867 - precision: 0.4474 - recall: 0.1133 - val_loss: 2.6325 - val_accuracy: 0.4000 - val_precision: 0.6250 - val_recall: 0.1000
# Epoch 5/25
# 2/2 [==============================] - 1s 530ms/step - loss: 2.5739 - accuracy: 0.4867 - precision: 0.4959 - recall: 0.4000 - val_loss: 2.4943 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s 579ms/step - loss: 2.4117 - accuracy: 0.4867 - precision: 0.5250 - recall: 0.1400 - val_loss: 2.3918 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] - 1s 544ms/step - loss: 2.3017 - accuracy: 0.4867 - precision: 0.5000 - recall: 0.0067 - val_loss: 2.2834 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 2/2 [==============================] - 1s 602ms/step - loss: 2.2000 - accuracy: 0.5000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.1747 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 1s 569ms/step - loss: 2.0905 - accuracy: 0.4867 - precision: 0.4000 - recall: 0.0267 - val_loss: 2.0754 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 1s 563ms/step - loss: 2.0050 - accuracy: 0.4867 - precision: 0.5128 - recall: 0.1333 - val_loss: 1.9926 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 2/2 [==============================] - 1s 521ms/step - loss: 1.9227 - accuracy: 0.4867 - precision: 0.5849 - recall: 0.2067 - val_loss: 1.9293 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 2/2 [==============================] - 1s 514ms/step - loss: 1.8501 - accuracy: 0.4867 - precision: 0.5455 - recall: 0.0800 - val_loss: 1.8740 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 2/2 [==============================] - 1s 523ms/step - loss: 1.7911 - accuracy: 0.4867 - precision: 0.4286 - recall: 0.0200 - val_loss: 1.8151 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 2/2 [==============================] - 1s 492ms/step - loss: 1.7340 - accuracy: 0.4867 - precision: 0.5000 - recall: 0.0333 - val_loss: 1.7542 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 2/2 [==============================] - 1s 490ms/step - loss: 1.6770 - accuracy: 0.4867 - precision: 0.6071 - recall: 0.1133 - val_loss: 1.7022 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/25
# 2/2 [==============================] - 1s 492ms/step - loss: 1.6305 - accuracy: 0.4867 - precision: 0.5493 - recall: 0.2600 - val_loss: 1.6593 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/25
# 2/2 [==============================] - 1s 445ms/step - loss: 1.5879 - accuracy: 0.4867 - precision: 0.5395 - recall: 0.2733 - val_loss: 1.6212 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/25
# 2/2 [==============================] - 1s 487ms/step - loss: 1.5494 - accuracy: 0.4867 - precision: 0.5397 - recall: 0.2267 - val_loss: 1.5883 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 1s 441ms/step - loss: 1.5150 - accuracy: 0.4867 - precision: 0.6400 - recall: 0.1067 - val_loss: 1.5572 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 1s 430ms/step - loss: 1.4896 - accuracy: 0.4867 - precision: 0.5000 - recall: 0.0467 - val_loss: 1.5268 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 1s 448ms/step - loss: 1.4618 - accuracy: 0.4933 - precision: 0.6471 - recall: 0.0733 - val_loss: 1.4987 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 1s 471ms/step - loss: 1.4374 - accuracy: 0.5000 - precision: 0.6562 - recall: 0.1400 - val_loss: 1.4750 - val_accuracy: 0.4000 - val_precision: 0.7500 - val_recall: 0.0600
# Epoch 23/25
# 2/2 [==============================] - 1s 471ms/step - loss: 1.4199 - accuracy: 0.4867 - precision: 0.5686 - recall: 0.1933 - val_loss: 1.4552 - val_accuracy: 0.4000 - val_precision: 0.6250 - val_recall: 0.1000
# Epoch 24/25
# 2/2 [==============================] - 1s 547ms/step - loss: 1.3977 - accuracy: 0.4867 - precision: 0.5893 - recall: 0.2200 - val_loss: 1.4363 - val_accuracy: 0.4000 - val_precision: 0.6250 - val_recall: 0.1000
# Epoch 25/25
# 2/2 [==============================] - 1s 643ms/step - loss: 1.3778 - accuracy: 0.4867 - precision: 0.5606 - recall: 0.2467 - val_loss: 1.4173 - val_accuracy: 0.4000 - val_precision: 0.5556 - val_recall: 0.1000

# %%
evaluate_model(model_8)
# Out:
# 7/7 [==============================] - 1s 123ms/step - loss: 1.3802 - accuracy: 0.4650 - precision: 0.5769 - recall: 0.0750
# 4/4 [==============================] - 0s 110ms/step - loss: 1.8138 - accuracy: 0.2200 - precision: 0.1538 - recall: 0.0200
# Training Loss: 1.38
# Training Accuracy: 0.465
# Training Precision: 0.577
# Training Recall: 0.075
# ---------------------------
# Testing Loss: 1.81
# Testing Accuracy: 0.22
# Testing Precision: 0.154
# Testing Recall: 0.02

# %%
plot_metrics(model_8_results)

# %% [markdown]
# # Model #9

# %% [markdown]
# Maybe my model is too complex, let's try reducing some layers and see if that helps performance.

# %%
model_9 = Sequential()

model_9.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.01)))

model_9.add(Dense(128, activation='relu'))
model_9.add(MaxPooling2D(pool_size=(2,2)))
model_9.add(Dropout(0.8))

model_9.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.01)))
model_9.add(Dense(64, activation='relu'))
model_9.add(MaxPooling2D(pool_size=(2,2)))
model_9.add(Dropout(0.5))

model_9.add(Flatten())
model_9.add(Dense(64, activation='relu'))
model_9.add(Dense(32, activation='relu'))
model_9.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.01)))

model_9.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_9.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# dense_42 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# dense_43 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                802880
# _________________________________________________________________
# dense_45 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_46 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 965,476
# Trainable params: 965,476
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# More params!

# %%
model_9_results = model_9.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 414ms/step - loss: 2.7097 - accuracy: 0.3000 - precision: 0.1538 - recall: 0.0080 - val_loss: 2.5553 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 241ms/step - loss: 2.4460 - accuracy: 0.4867 - precision: 0.6098 - recall: 0.1667 - val_loss: 2.3651 - val_accuracy: 0.4000 - val_precision: 0.6667 - val_recall: 0.0800
# Epoch 3/25
# 2/2 [==============================] - 0s 242ms/step - loss: 2.3530 - accuracy: 0.4867 - precision: 0.5000 - recall: 0.4067 - val_loss: 2.2869 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 0s 245ms/step - loss: 2.1990 - accuracy: 0.4867 - precision: 0.5294 - recall: 0.1200 - val_loss: 2.2287 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 1s 405ms/step - loss: 2.1220 - accuracy: 0.4867 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.1304 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s
# 2/2 [==============================] - 1s 678ms/step - loss: 1.2017 - accuracy: 0.5667 - precision: 0.7000 - recall: 0.3267 - val_loss: 1.3717 - val_accuracy: 0.4200 - val_precision: 0.6667 - val_recall: 0.2400
# Epoch 25/25
# 2/2 [==============================] - 1s 680ms/step - loss: 1.1855 - accuracy: 0.5600 - precision: 0.6571 - recall: 0.3067 - val_loss: 1.3756 - val_accuracy: 0.4600 - val_precision: 0.7000 - val_recall: 0.2800

# %%
evaluate_model(model_9)
# Out:
# 7/7 [==============================] - 0s 70ms/step - loss: 1.2136 - accuracy: 0.5350 - precision: 0.6951 - recall: 0.2850
# 4/4 [==============================] - 0s 67ms/step - loss: 2.0821 - accuracy: 0.2500 - precision: 0.2222 - recall: 0.1800
# Training Loss: 1.21
# Training Accuracy: 0.535
# Training Precision: 0.695
# Training Recall: 0.285
# ---------------------------
# Testing Loss: 2.08
# Testing Accuracy: 0.25
# Testing Precision: 0.222
# Testing Recall: 0.18

# %%
plot_metrics(model_9_results)

# %% [markdown]
# # Model #10

# %% [markdown]
# Let's try reducing regulurization strength.

# %%
model_10 = Sequential()

model_10.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.0001)))

model_10.add(Dense(128, activation='relu'))
model_10.add(MaxPooling2D(pool_size=(2,2)))
model_10.add(Dropout(0.8))

model_10.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.0001)))
model_10.add(Dense(64, activation='relu'))
model_10.add(MaxPooling2D(pool_size=(2,2)))
model_10.add(Dropout(0.5))

model_10.add(Flatten())
model_10.add(Dense(64, activation='relu'))
model_10.add(Dense(32, activation='relu'))
model_10.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.0001)))

model_10.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_10.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# dense_47 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# dense_48 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                802880
# _________________________________________________________________
# dense_50 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_51 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 965,476
# Trainable params: 965,476
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_10_results = model_10.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 2s 1s/step - loss: 1.3876 - accuracy: 0.3067 - precision: 0.2222 - recall: 0.0720 - val_loss: 1.3590 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 1s 630ms/step - loss: 1.2997 - accuracy: 0.4867 - precision: 0.4857 - recall: 0.1133 - val_loss: 1.3078 - val_accuracy: 0.4000 - val_precision: 0.6667 - val_recall: 0.0400
# Epoch 3/25
# 2/2 [==============================] - 1s 557ms/step - loss: 1.2804 - accuracy: 0.4867 - precision: 0.5200 - recall: 0.3467 - val_loss: 1.3077 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 1s 570ms/step - loss: 1.2394 - accuracy: 0.4867 - precision: 0.4878 - recall: 0.1333 - val_loss: 1.3060 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 1s 535ms/step - loss: 1.2283 - accuracy: 0.4867 - precision: 0.5294 - recall: 0.0600 - val_loss: 1.2787 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s 566ms/step - loss: 1.2238 - accuracy: 0.4867 - precision: 0.5333 - recall: 0.2133 - val_loss: 1.2680 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] - 1s 637ms/step - loss: 1.2181 - accuracy: 0.4867 - precision: 0.5341 - recall: 0.3133 - val_loss: 1.2806 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 2/2 [==============================] - 1s 577ms/step - loss: 1.2031 - accuracy: 0.4933 - precision: 0.5789 - recall: 0.1467 - val_loss: 1.2867 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 1s 564ms/step - loss: 1.1982 - accuracy: 0.4867 - precision: 0.6552 - recall: 0.1267 - val_loss: 1.2793 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 1s
# Epoch 25/25
# 2/2 [==============================] - 1s 419ms/step - loss: 0.9987 - accuracy: 0.5867 - precision: 0.7067 - recall: 0.3533 - val_loss: 1.2510 - val_accuracy: 0.4200 - val_precision: 0.7143 - val_recall: 0.2000

# %%
evaluate_model(model_10)
# Out:
# 7/7 [==============================] - 1s 90ms/step - loss: 1.0795 - accuracy: 0.5650 - precision: 0.7213 - recall: 0.2200
# 4/4 [==============================] - 0s 70ms/step - loss: 1.7353 - accuracy: 0.2300 - precision: 0.2041 - recall: 0.1000
# Training Loss: 1.08
# Training Accuracy: 0.565
# Training Precision: 0.721
# Training Recall: 0.22
# ---------------------------
# Testing Loss: 1.74
# Testing Accuracy: 0.23
# Testing Precision: 0.204
# Testing Recall: 0.1

# %%
plot_metrics(model_10_results)

# %% [markdown]
# # Model #11

# %% [markdown]
# Let's add batch normalization.

# %%
model_11 = Sequential()

model_11.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1), 
                        kernel_regularizer=l2(0.0001)))
model_11.add(BatchNormalization())
model_11.add(Dense(128, activation='relu'))
model_11.add(MaxPooling2D(pool_size=(2,2)))
model_11.add(Dropout(0.8))

model_11.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.0001)))
model_11.add(BatchNormalization())
model_11.add(Dense(64, activation='relu'))
model_11.add(MaxPooling2D(pool_size=(2,2)))
model_11.add(Dropout(0.5))

model_11.add(Flatten())
model_11.add(Dense(64, activation='relu'))
model_11.add(Dense(32, activation='relu'))
model_11.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.0001)))

model_11.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_11.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_52 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 29, 29, 128)       512
# _________________________________________________________________
# dense_53 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_54 (Dense)             (None, 64)                802880
# _________________________________________________________________
# dense_55 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_56 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 966,116
# Trainable params: 965,796
# Non-trainable params: 320
# _________________________________________________________________

# %%
model_11_results = model_11.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 3s 2s/step - loss: 5.1596 - accuracy: 0.2600 - precision: 0.2686 - recall: 0.1880 - val_loss: 1.3906 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 2s 831ms/step - loss: 3.2161 - accuracy: 0.3800 - precision: 0.3800 - recall: 0.3800 - val_loss: 1.3980 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 1s 685ms/step - loss: 3.1013 - accuracy: 0.2200 - precision: 0.2188 - recall: 0.1867 - val_loss: 1.3971 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 1s 633ms/step - loss: 1.4831 - accuracy: 0.3600 - precision: 0.4306 - recall: 0.2067 - val_loss: 1.3936 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 1s 725ms/step - loss: 1.4038 - accuracy: 0.5000 - precision: 0.5113 - recall: 0.4533 - val_loss: 1.3920 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s 687ms/step - loss: 1.3580 - accuracy: 0.4267 - precision: 0.4719 - recall: 0.2800 - val_loss: 1.3914 - val_accuracy: 0.4800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] - 1s 643ms/step - loss: 1.2686 - accuracy: 0.5133 - precision: 0.5402 - recall: 0.3133 - val_loss: 1.3913 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 2/2 [==============================] - 1s 607ms/step - loss: 1.3624 - accuracy: 0.4733 - precision: 0.4915 - recall: 0.3867 - val_loss: 1.3908 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 1s 693ms/step - loss: 1.1706 - accuracy: 0.5200 - precision: 0.5766 - recall: 0.4267 - val_loss: 1.3894 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 1s 615ms/step - loss: 1.2319 - accuracy: 0.4933 - precision: 0.5741 - recall: 0.2067 - val_loss: 1.3872 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 2/2 [==============================] - 1s 682ms/step - loss: 1.1022 - accuracy: 0.5133 - precision: 0.5181 - recall: 0.2867 - val_loss: 1.3860 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 2/2 [==============================] - 1s 614ms/step - loss: 1.0320 - accuracy: 0.5600 - precision: 0.6404 - recall: 0.3800 - val_loss: 1.3851 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 2/2 [==============================] - 1s 705ms/step - loss: 1.1112 - accuracy: 0.5267 - precision: 0.5574 - recall: 0.4533 - val_loss: 1.3833 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 2/2 [==============================] - 1s 561ms/step - loss: 1.0651 - accuracy: 0.5400 - precision: 0.5750 - recall: 0.4600 - val_loss: 1.3806 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 2/2 [==============================] - 1s 630ms/step - loss: 1.0855 - accuracy: 0.5067 - precision: 0.5435 - recall: 0.3333 - val_loss: 1.3765 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/25
# 2/2 [==============================] - 1s 541ms/step - loss: 1.0085 - accuracy: 0.5400 - precision: 0.6842 - recall: 0.3467 - val_loss: 1.3754 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/25
# 2/2 [==============================] - 1s 561ms/step - loss: 1.0029 - accuracy: 0.5600 - precision: 0.6667 - recall: 0.4133 - val_loss: 1.3753 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/25
# 2/2 [==============================] - 1s 642ms/step - loss: 0.9855 - accuracy: 0.5933 - precision: 0.6559 - recall: 0.4067 - val_loss: 1.3726 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 1s 591ms/step - loss: 0.9285 - accuracy: 0.6133 - precision: 0.6809 - recall: 0.4267 - val_loss: 1.3691 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 1s 593ms/step - loss: 0.8920 - accuracy: 0.6333 - precision: 0.7381 - recall: 0.4133 - val_loss: 1.3678 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 1s 594ms/step - loss: 0.9070 - accuracy: 0.5733 - precision: 0.6882 - recall: 0.4267 - val_loss: 1.3690 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 1s 500ms/step - loss: 0.9121 - accuracy: 0.6333 - precision: 0.6460 - recall: 0.4867 - val_loss: 1.3691 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/25
# 2/2 [==============================] - 1s 547ms/step - loss: 0.9053 - accuracy: 0.6333 - precision: 0.7059 - recall: 0.4800 - val_loss: 1.3672 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 1s 597ms/step - loss: 0.8398 - accuracy: 0.6333 - precision: 0.8043 - recall: 0.4933 - val_loss: 1.3630 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 1s 597ms/step - loss: 0.8705 - accuracy: 0.6467 - precision: 0.7263 - recall: 0.4600 - val_loss: 1.3609 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_11)
# Out:
# 7/7 [==============================] - 1s 104ms/step - loss: 1.3490 - accuracy: 0.4650 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 70ms/step - loss: 1.4243 - accuracy: 0.2200 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.35
# Training Accuracy: 0.465
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.42
# Testing Accuracy: 0.22
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_11_results)

# %% [markdown]
# # Model #12

# %% [markdown]
# Scores are worse all around, but not overfit. Let's try reducing regularization, see if that helps.

# %%
# removed l2, decreasing dropout

model_12 = Sequential()

model_12.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1)))

model_12.add(BatchNormalization())
model_12.add(Dense(128, activation='relu'))
model_12.add(MaxPooling2D(pool_size=(2,2)))
model_12.add(Dropout(0.5))

model_12.add(Conv2D(128, (3, 3), activation='relu'))
model_12.add(BatchNormalization())
model_12.add(Dense(64, activation='relu'))
model_12.add(MaxPooling2D(pool_size=(2,2)))
model_12.add(Dropout(0.2))

model_12.add(Flatten())
model_12.add(Dense(64, activation='relu'))
model_12.add(Dense(32, activation='relu'))
model_12.add(Dense(4, activation='softmax'))

model_12.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_12.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_62 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 29, 29, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 29, 29, 128)       512
# _________________________________________________________________
# dense_63 (Dense)             (None, 29, 29, 64)        8256
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_16 (Flatten)         (None,
- val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 1s 557ms/step - loss: 0.4672 - accuracy: 0.8533 - precision: 0.9219 - recall: 0.7867 - val_loss: 1.3737 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 1s 630ms/step - loss: 0.4583 - accuracy: 0.8533 - precision: 0.9048 - recall: 0.7600 - val_loss: 1.3756 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_12)
# Out:
# 7/7 [==============================] - 1s 93ms/step - loss: 1.3342 - accuracy: 0.4650 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 79ms/step - loss: 1.4293 - accuracy: 0.2200 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.33
# Training Accuracy: 0.465
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.43
# Testing Accuracy: 0.22
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_12_results)

# %% [markdown]
# # Model #13

# %% [markdown]
# Scores were more consistent the last round, still very low. Precision and recall were shot. Let's try reducing the hidden layers.

# %%
model_13 = Sequential()

model_13.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1)))

model_13.add(BatchNormalization())
model_13.add(Dense(128, activation='relu'))
model_13.add(MaxPooling2D(pool_size=(2,2)))
model_13.add(Dropout(0.5))

model_13.add(Flatten())
model_13.add(Dense(64, activation='relu'))
model_13.add(Dense(32, activation='relu'))
model_13.add(Dense(4, activation='softmax'))

model_13.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_13.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_67 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 123008)            0
# _________________________________________________________________
# dense_68 (Dense)             (None, 64)                7872576
# _________________________________________________________________
# dense_69 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_70 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 7,879,460
# Trainable params: 7,879,396
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_13_results = model_13.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 731ms/step - loss: 3.7644 - accuracy: 0.1600 - precision: 0.3276 - recall: 0.0760 - val_loss: 1.3733 - val_accuracy: 0.4000 - val_precision: 0.6000 - val_recall: 0.0600
# Epoch 2/25
# 2/2 [==============================] - 1s 329ms/step - loss: 8.8524 - accuracy: 0.4867 - precision: 0.4867 - recall: 0.4867 - val_loss: 1.4007 - val_accuracy: 0.1000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 1s 380ms/step - loss: 4.1221 - accuracy: 0.3267 - precision: 0.3311 - recall: 0.3267 - val_loss: 1.3549 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 1s 323ms/step - loss: 1.3185 - accuracy: 0.4400 - precision: 0.4421 - recall: 0.2800 - val_loss: 1.3452 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 1s 341ms/step - loss: 1.4808 - accuracy: 0.4267 - precision: 0.4254 - recall: 0.3800 - val_loss: 1.3469 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 1s 383ms/step - loss: 1.3660 - accuracy: 0.5000 - precision: 0.5126 - recall: 0.4067 - val_loss: 1.3586 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] - 1s 369ms/step - loss: 1.1372 - accuracy: 0.5400 - precision: 0.6395 - recall: 0.3667 - val_loss: 1.3667 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 2/2 [==============================] - 1s 324ms/step - loss: 1.0684 - accuracy: 0.5467 - precision: 0.6145 - recall: 0.3400 - val_loss: 1.3700 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 1s 329ms/step - loss: 0.9090 - accuracy: 0.5867 - precision: 0.6729 - recall: 0.4800 - val_loss: 1.3719 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 1s 326ms/step - loss: 0.8131 - accuracy: 0.6267 - precision: 0.7154 - recall: 0.5867 - val_loss: 1.3738 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 2/2 [==============================] - 1s 308ms/step - loss: 0.7051 - accuracy: 0.6933 - precision: 0.8660 - recall: 0.5600 - val_loss: 1.3753 - val_accuracy: 0.3200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 2/2 [==============================] - 1s 350ms/step - loss: 0.6634 - accuracy: 0.7667 - precision: 0.9457 - recall: 0.5800 - val_loss: 1.3760 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 2/2 [==============================] - 1s 350ms/step - loss: 0.6180 - accuracy: 0.8133 - precision: 0.9891 - recall: 0.6067 - val_loss: 1.3759 - val_accuracy: 0.3200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 2/2 [==============================] - 1s 323ms/step - loss: 0.5756 - accuracy: 0.8200 - precision: 0.9802 - recall: 0.6600 - val_loss: 1.3753 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 2/2 [==============================] - 1s 347ms/step - loss: 0.5288 - accuracy: 0.8200 - precision: 0.9818 - recall: 0.7200 - val_loss: 1.3743 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/25
# 2/2 [==============================] - 1s 305ms/step - loss: 0.4879 - accuracy: 0.8333 - precision: 0.9580 - recall: 0.7600 - val_loss: 1.3732 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/25
# 2/2 [==============================] - 1s 289ms/step - loss: 0.4536 - accuracy: 0.8467 - precision: 0.9440 - recall: 0.7867 - val_loss: 1.3717 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/25
# 2/2 [==============================] - 1s 338ms/step - loss: 0.4184 - accuracy: 0.8800 - precision: 0.9385 - recall: 0.8133 - val_loss: 1.3702 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 1s 300ms/step - loss: 0.3892 - accuracy: 0.8867 - precision: 0.9259 - recall: 0.8333 - val_loss: 1.3685 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 1s 299ms/step - loss: 0.3599 - accuracy: 0.8800 - precision: 0.9028 - recall: 0.8667 - val_loss: 1.3668 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 1s 302ms/step - loss: 0.3324 - accuracy: 0.8867 - precision: 0.9091 - recall: 0.8667 - val_loss: 1.3651 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 1s 292ms/step - loss: 0.3045 - accuracy: 0.9067 - precision: 0.9167 - recall: 0.8800 - val_loss: 1.3633 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/25
# 2/2 [==============================] - 1s 336ms/step - loss: 0.2863 - accuracy: 0.9067 - precision: 0.9366 - recall: 0.8867 - val_loss: 1.3617 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 1s 302ms/step - loss: 0.2677 - accuracy: 0.9133 - precision: 0.9635 - recall: 0.8800 - val_loss: 1.3598 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 1s 292ms/step - loss: 0.2537 - accuracy: 0.9200 - precision: 0.9708 - recall: 0.8867 - val_loss: 1.3579 - val_accuracy: 0.2400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_13)
# Out:
# 7/7 [==============================] - 0s 55ms/step - loss: 1.3058 - accuracy: 0.5700 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 37ms/step - loss: 1.4052 - accuracy: 0.2000 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.31
# Training Accuracy: 0.57
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.41
# Testing Accuracy: 0.2
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_13_results)

# %% [markdown]
# Test score is still low, let's add regularization back in.

# %% [markdown]
# # Model #14

# %%
model_14 = Sequential()

model_14.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1),
                        kernel_regularizer=l2(0.00001)))

model_14.add(BatchNormalization())
model_14.add(Dense(128, activation='relu'))
model_14.add(MaxPooling2D(pool_size=(2,2)))
model_14.add(Dropout(0.5))

model_14.add(Flatten())
model_14.add(Dense(64, activation='relu'))
model_14.add(Dense(32, activation='relu'))
model_14.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.00001)))

model_14.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_14.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_71 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 123008)            0
# _________________________________________________________________
# dense_72 (Dense)             (None, 64)                7872576
# _________________________________________________________________
# dense_73 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_74 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 7,879,460
# Trainable params: 7,879,396
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_14_results = model_14.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 356ms/step - loss: 2.8179 - accuracy: 0.3133 - precision: 0.5577 - recall: 0.1160 - val_loss: 1.3337 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 168ms/step - loss: 3.6086 - accuracy: 0.3333 - precision: 0.3333 - recall: 0.3333 - val_loss: 1.3330 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 0s 155ms/step - loss: 2.0712 - accuracy: 0.4333 - precision: 0.4420 - recall: 0.4067 - val_loss: 1.3679 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 0s 162ms/step - loss: 1.6158 - accuracy: 0.4867 - precision: 0.4945 - recall: 0.3000 - val_loss: 1.3699 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] - 0s 159ms/step - loss: 1.0129 - accuracy: 0.5733 - precision: 0.6632 - recall: 0.4200 - val_loss: 1.3761 - val_accuracy: 0.2400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 2/2 [==============================] - 0s 147ms/step - loss: 0.8848 - accuracy: 0.6333 - precision: 0.7444 - recall: 0.4467 - val_loss: 1.3816 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 2/2 [==============================] -
- val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 0s 208ms/step - loss: 0.1475 - accuracy: 0.9800 - precision: 1.0000 - recall: 0.9467 - val_loss: 1.3193 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 0s 211ms/step - loss: 0.1319 - accuracy: 0.9933 - precision: 1.0000 - recall: 0.9733 - val_loss: 1.3190 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_15)
# Out:
# 7/7 [==============================] - 0s 31ms/step - loss: 1.2072 - accuracy: 0.7000 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 23ms/step - loss: 1.5151 - accuracy: 0.2000 - precision: 0.3333 - recall: 0.0100
# Training Loss: 1.21
# Training Accuracy: 0.7
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.52
# Testing Accuracy: 0.2
# Testing Precision: 0.333
# Testing Recall: 0.01

# %%
plot_metrics(model_15_results)

# %% [markdown]
# # Model #16

# %% [markdown]
# Let's change to tanh

# %%
model_16 = Sequential()

model_16.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='tanh', 
                        input_shape=(64, 64, 1),
                        kernel_regularizer=l2(0.00001)))

model_16.add(BatchNormalization())
model_16.add(Dense(128, activation='tanh'))
model_16.add(MaxPooling2D(pool_size=(2,2)))
model_16.add(Dropout(0.5))

model_16.add(Flatten())
model_16.add(Dense(64, activation='tanh'))
model_16.add(Dense(32, activation='tanh'))
model_16.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.00001)))

model_16.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_16.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_79 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 123008)            0
# _________________________________________________________________
# dense_80 (Dense)             (None, 64)                7872576
# _________________________________________________________________
# dense_81 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_82 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 7,879,460
# Trainable params: 7,879,396
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_16_results = model_16.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 2s 1s/step - loss: 1.5679 - accuracy: 0.3533 - precision: 0.4394 - recall: 0.1160 - val_loss: 4.0914 - val_accuracy: 0.1200 - val_precision: 0.1277 - val_recall: 0.1200
# Epoch 2/25
# 2/2 [==============================] - 1s 392ms/step - loss: 1.5194 - accuracy: 0.5000 - precision: 0.5103 - recall: 0.4933 - val_loss: 3.2691 - val_accuracy: 0.1800 - val_precision: 0.1875 - val_recall: 0.1800
# Epoch 3/25
# 2/2 [==============================] - 1s 456ms/step - loss: 1.3444 - accuracy: 0.5733 - precision: 0.5846 - recall: 0.5067 - val_loss: 2.6583 - val_accuracy: 0.2400 - val_precision: 0.2449 - val_recall: 0.2400
# Epoch 4/25
# 2/2 [==============================] - 1s 449ms/step - loss: 1.2209 - accuracy: 0.5933 - precision: 0.6348 - recall: 0.4867 - val_loss: 2.3864 - val_accuracy: 0.3000 - val_precision: 0.3061 - val_recall: 0.3000
# Epoch 5/25
# 2/2 [==============================] - 1s 408ms/step - loss: 1.1388 - accuracy: 0.6600 - precision: 0.6990 - recall: 0.4800 - val_loss: 2.3111 - val_accuracy: 0.3200 - val_precision: 0.3191 - val_recall: 0.3000
# Epoch 6/25
# 2/2 [==============================] - 1s 410ms/step - loss: 1.0820 - accuracy: 0.6467 - precision: 0.6952 - recall: 0.4867 - val_loss: 2.2483 - val_accuracy: 0.3000 - val_precision: 0.3125 - val_recall: 0.3000
# Epoch 7/25
# 2/2 [==============================] - 1s 373ms/step - loss: 1.0309 - accuracy: 0.6467 - precision: 0.7130 - recall: 0.5133 - val_loss: 2.1671 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 8/25
# 2/2 [==============================] - 1s 330ms/step - loss: 0.9836 - accuracy: 0.6800 - precision: 0.7358 - recall: 0.5200 - val_loss: 2.1015 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch
# Epoch 22/25
# 2/2 [==============================] - 1s 316ms/step - loss: 0.6515 - accuracy: 0.8000 - precision: 0.8651 - recall: 0.7267 - val_loss: 1.5224 - val_accuracy: 0.3600 - val_precision: 0.4688 - val_recall: 0.3000
# Epoch 23/25
# 2/2 [==============================] - 1s 312ms/step - loss: 0.6163 - accuracy: 0.8067 - precision: 0.8672 - recall: 0.7400 - val_loss: 1.5614 - val_accuracy: 0.3400 - val_precision: 0.4286 - val_recall: 0.3000
# Epoch 24/25
# 2/2 [==============================] - 1s 306ms/step - loss: 0.6085 - accuracy: 0.8267 - precision: 0.8730 - recall: 0.7333 - val_loss: 1.5988 - val_accuracy: 0.3800 - val_precision: 0.3947 - val_recall: 0.3000
# Epoch 25/25
# 2/2 [==============================] - 1s 298ms/step - loss: 0.5887 - accuracy: 0.8200 - precision: 0.8819 - recall: 0.7467 - val_loss: 1.6021 - val_accuracy: 0.3600 - val_precision: 0.4054 - val_recall: 0.3000

# %%
evaluate_model(model_16)
# Out:
# 7/7 [==============================] - 0s 46ms/step - loss: 1.3129 - accuracy: 0.4550 - precision: 0.5032 - recall: 0.3950
# 4/4 [==============================] - 0s 34ms/step - loss: 1.9012 - accuracy: 0.2300 - precision: 0.2024 - recall: 0.1700
# Training Loss: 1.31
# Training Accuracy: 0.455
# Training Precision: 0.503
# Training Recall: 0.395
# ---------------------------
# Testing Loss: 1.9
# Testing Accuracy: 0.23
# Testing Precision: 0.202
# Testing Recall: 0.17

# %%
plot_metrics(model_16_results)

# %% [markdown]
# # Model #17

# %% [markdown]
# We have an imbalanced dataset, nothing above seems to be helping, let's try adjusting the class weights.

# %%
y_ints = [y.argmax() for y in train_labels]
class_weights = compute_class_weight(class_weight='balanced',
                                                  classes=np.unique(y_ints),
                                                  y=y_ints)

# turn into dict so it can be put in the fit statement
class_weights_dict = {class_index: weight for class_index, weight in enumerate(class_weights)}

# %%
model_17 = Sequential()

model_17.add(Conv2D(filters=32, 
                        kernel_size=(3,3), 
                        activation='relu', 
                        input_shape=(64, 64, 1),
                        kernel_regularizer=l2(0.00001)))

model_17.add(BatchNormalization())
model_17.add(Dense(128, activation='relu'))
model_17.add(MaxPooling2D(pool_size=(2,2)))
model_17.add(Dropout(0.5))

model_17.add(Flatten())
model_17.add(Dense(64, activation='relu'))
model_17.add(Dense(32, activation='relu'))
model_17.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.00001)))

model_17.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_17.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_44 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_83 (Dense)             (None, 62, 62, 128)       4224
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 31, 31, 128)       0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 31, 31, 128)       0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 123008)            0
# _________________________________________________________________
# dense_84 (Dense)             (None, 64)                7872576
# _________________________________________________________________
# dense_85 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_86 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 7,879,460
# Trainable params: 7,879,396
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_17_results = model_17.fit(train_images, 
                              train_labels, 
                              validation_split=0.25,
                              batch_size=100, 
                              epochs=25,
                              validation_data=(test_images, test_labels))
# Out:
# Epoch 1/25
# 2/2 [==============================] - 1s 327ms/step - loss: 2.7034 - accuracy: 0.2400 - precision: 0.3139 - recall: 0.1720 - val_loss: 1.3478 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 2/2 [==============================] - 0s 154ms/step - loss: 1.6287 - accuracy: 0.4000 - precision: 0.3966 - recall: 0.3067 - val_loss: 1.3171 - val_accuracy: 0.4600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 2/2 [==============================] - 0s 163ms/step - loss: 3.6916 - accuracy: 0.4533 - precision: 0.4533 - recall: 0.4533 - val_loss: 1.3133 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 2/2 [==============================] - 0s 164ms/step - loss: 2.3370 - accuracy: 0.3133 - precision: 0.3151 - recall: 0.3067 - val_loss: 1.3213 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 2/2 [==============================] -
- val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 2/2 [==============================] - 0s 159ms/step - loss: 0.9861 - accuracy: 0.5467 - precision: 0.7159 - recall: 0.4200 - val_loss: 1.3714 - val_accuracy: 0.4400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 2/2 [==============================] - 0s 196ms/step - loss: 0.9135 - accuracy: 0.6333 - precision: 0.8148 - recall: 0.4400 - val_loss: 1.3734 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 2/2 [==============================] - 0s 195ms/step - loss: 0.9099 - accuracy: 0.5733 - precision: 0.7444 - recall: 0.4467 - val_loss: 1.3760 - val_accuracy: 0.3200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 2/2 [==============================] - 0s 206ms/step - loss: 0.8577 - accuracy: 0.6533 - precision: 0.8846 - recall: 0.4600 - val_loss: 1.3770 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.8139 - accuracy: 0.7400 - precision: 0.9211 - recall: 0.4667 - val_loss: 1.3761 - val_accuracy: 0.3000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 2/2 [==============================] - 0s 165ms/step - loss: 0.7969 - accuracy: 0.7533 - precision: 0.9412 - recall: 0.4267 - val_loss: 1.3744 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 2/2 [==============================] - 0s 185ms/step - loss: 0.7624 - accuracy: 0.7400 - precision: 0.9070 - recall: 0.5200 - val_loss: 1.3728 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/25
# 2/2 [==============================] - 0s 210ms/step - loss: 0.7245 - accuracy: 0.7267 - precision: 0.9032 - recall: 0.5600 - val_loss: 1.3721 - val_accuracy: 0.3200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/25
# 2/2 [==============================] - 0s 187ms/step - loss: 0.6842 - accuracy: 0.7400 - precision: 0.8558 - recall: 0.5933 - val_loss: 1.3716 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/25
# 2/2 [==============================] - 0s 220ms/step - loss: 0.6497 - accuracy: 0.7667 - precision: 0.8468 - recall: 0.6267 - val_loss: 1.3707 - val_accuracy: 0.3200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 0s 197ms/step - loss: 0.6147 - accuracy: 0.7800 - precision: 0.8636 - recall: 0.6333 - val_loss: 1.3691 - val_accuracy: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 0s 174ms/step - loss: 0.5871 - accuracy: 0.7867 - precision: 0.9043 - recall: 0.6933 - val_loss: 1.3676 - val_accuracy: 0.3800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 0s 182ms/step - loss: 0.5513 - accuracy: 0.7800 - precision: 0.8983 - recall: 0.7067 - val_loss: 1.3665 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 0s 207ms/step - loss: 0.5269 - accuracy: 0.8000 - precision: 0.9076 - recall: 0.7200 - val_loss: 1.3661 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/25
# 2/2 [==============================] - 0s 184ms/step - loss: 0.4985 - accuracy: 0.7933 - precision: 0.9174 - recall: 0.7400 - val_loss: 1.3662 - val_accuracy: 0.3800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 0s 195ms/step - loss: 0.4925 - accuracy: 0.8000 - precision: 0.9180 - recall: 0.7467 - val_loss: 1.3637 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 0s 198ms/step - loss: 0.4643 - accuracy: 0.8133 - precision: 0.9127 - recall: 0.7667 - val_loss: 1.3598 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_19)
# Out:
# 7/7 [==============================] - 0s 31ms/step - loss: 1.3302 - accuracy: 0.5550 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 20ms/step - loss: 1.4033 - accuracy: 0.2200 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.33
# Training Accuracy: 0.555
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.4
# Testing Accuracy: 0.22
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_19_results)

# %% [markdown]
# Decrease params - the first dense after flatten has a lot, let's remove it. also removed dense in hidden layers

# %% [markdown]
# # Model #20

# %% [markdown]
# change num of filters and input units, added dense back in hidden, keep basic arch the same

# %%
model_20 = Sequential()

model_20.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_20.add(BatchNormalization())
model_20.add(Dense(32, activation='relu'))
model_20.add(MaxPooling2D(pool_size=(2,2)))
model_20.add(Dropout(0.3))

model_20.add(Flatten())
model_20.add(Dense(16, activation='relu'))
model_20.add(Dense(4, activation='softmax'))

model_20.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', precision, recall])

model_20.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_96 (Dense)             (None, 62, 62, 32)        1056
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None,
- val_accuracy: 0.3800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/25
# 2/2 [==============================] - 0s 183ms/step - loss: 1.1480 - accuracy: 0.4867 - precision: 0.7170 - recall: 0.2533 - val_loss: 1.3672 - val_accuracy: 0.3800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/25
# 2/2 [==============================] - 0s 169ms/step - loss: 1.1345 - accuracy: 0.4867 - precision: 0.6667 - recall: 0.3067 - val_loss: 1.3664 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/25
# 2/2 [==============================] - 0s 189ms/step - loss: 1.1285 - accuracy: 0.4867 - precision: 0.6463 - recall: 0.3533 - val_loss: 1.3654 - val_accuracy: 0.3800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/25
# 2/2 [==============================] - 0s 165ms/step - loss: 1.1221 - accuracy: 0.4933 - precision: 0.6444 - recall: 0.3867 - val_loss: 1.3644 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/25
# 2/2 [==============================] - 0s 180ms/step - loss: 1.1162 - accuracy: 0.4867 - precision: 0.6095 - recall: 0.4267 - val_loss: 1.3634 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/25
# 2/2 [==============================] - 0s 173ms/step - loss: 1.1155 - accuracy: 0.4867 - precision: 0.6078 - recall: 0.4133 - val_loss: 1.3627 - val_accuracy: 0.4200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/25
# 2/2 [==============================] - 0s 173ms/step - loss: 1.1054 - accuracy: 0.4933 - precision: 0.6458 - recall: 0.4133 - val_loss: 1.3620 - val_accuracy: 0.4000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_20)
# Out:
# 7/7 [==============================] - 0s 24ms/step - loss: 1.3564 - accuracy: 0.5200 - precision: 0.0000e+00 - recall: 0.0000e+00
# 4/4 [==============================] - 0s 17ms/step - loss: 1.3971 - accuracy: 0.1900 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.36
# Training Accuracy: 0.52
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.4
# Testing Accuracy: 0.19
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_20_results)

# %% [markdown]
# # Twenty First Model

# %% [markdown]
# try changing the optimizer around, test on this model for
# SGD,
# RMSprop,
# Adam,
# Adadelta,
# Adagrad,
# Adamax,
# Nadam,
# Ftrl

# %%
model_21 = Sequential()

model_21.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_21.add(BatchNormalization())
model_21.add(Dense(64, activation='relu'))
model_21.add(MaxPooling2D(pool_size=(2,2)))
model_21.add(Dropout(0.3))

model_21.add(Flatten())
model_21.add(Dense(16, activation='relu'))
model_21.add(Dense(8, activation='relu'))
model_21.add(Dense(4, activation='softmax'))

# %%
model_21.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_81 (Dense)             (None, 62, 62, 64)        2112
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 61504)             0
# _________________________________________________________________
# dense_82 (Dense)             (None, 16)                984080
# _________________________________________________________________
# dense_83 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_84 (Dense)             (None, 4)                 36
# =================================================================
# Total params: 986,812
# Trainable params: 986,748
# Non-trainable params: 64
# _________________________________________________________________

# %%
results = {}
optimizers = ['SGD', 'RMSprop', 'Adam', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam']

for optimizer_name in optimizers:
    model = model_21
    optimizer = 'Adam'
    
    if optimizer_name == 'SGD':
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    elif optimizer_name == 'RMSprop':
        optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
    elif optimizer_name == 'Adam':
        optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
    elif optimizer_name == 'Adadelta':
        optimizer = tf.keras.optimizers.Adadelta(learning_rate=0.01)
    elif optimizer_name == 'Adagrad':
        optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.01)
    elif optimizer_name == 'Adamax':
        optimizer = tf.keras.optimizers.Adamax(learning_rate=0.01)
    elif optimizer_name == 'Nadam':
        optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
    
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accurac
 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0179 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 1.4484 - val_accuracy: 0.2000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0156 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4496 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0099 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4491 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 1/20
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1926 - accuracy: 0.9333 - precision: 0.9272 - recall: 0.5600 - val_loss: 1.4686 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0887 - accuracy: 0.9800 - precision: 0.9799 - recall: 0.9733 - val_loss: 1.4660 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0739 - accuracy: 0.9800 - precision: 0.9866 - recall: 0.9800 - val_loss: 1.4631 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0226 - accuracy: 0.9933 - precision: 1.0000 - recall: 0.9933 - val_loss: 1.4653 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0154 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4668 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0082 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4673 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0080 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 1.4676 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0062 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 1.4681 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 1/20
# 5/5 [==============================] - 2s 396ms/step - loss: 0.4531 - accuracy: 0.9133 - precision: 0.9013 - recall: 0.5480 - val_loss: 1.5102 - val_accuracy: 0.2300 - val_precision: 0.4000 - val_recall: 0.0400
# Epoch 2/20
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0592 - accuracy: 0.9733 - precision: 0.9733 - recall: 0.9733 - val_loss: 1.5421 - val_accuracy: 0.2100 - val_precision: 0.3000 - val_recall: 0.0300
# Epoch 3/20
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0079 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 1.5568 - val_accuracy: 0.1900 - val_precision: 0.2500 - val_recall: 0.0300
# Epoch 4/20
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0124 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 1.6004 - val_accuracy: 0.1900 - val_precision: 0.2105 - val_recall: 0.0400
# Epoch 5/20
# 5/5 [==============================] - 1s 184ms/step - loss: 3.2309e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6181 - val_accuracy: 0.1800 - val_precision: 0.2105 - val_recall: 0.0400
# Epoch 6/20
# 5/5 [==============================] - 1s 191ms/step - loss: 2.9226e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.6360 - val_accuracy: 0.1800 - val_precision: 0.2500 - val_recall: 0.0500

# %%
# Initialize dictionaries to store average scores for each metric
average_accuracy = {}

for optimizer in optimizers:
    history = results[optimizer].history
    # Calculate the average accuracy for the optimizer
    avg_acc = sum(history['accuracy']) / len(history['accuracy'])
    average_accuracy[optimizer] = avg_acc

# Print the average scores for each optimizer
for optimizer in optimizers:
    print(f"{optimizer}:")
    print(f"Average Accuracy: {average_accuracy[optimizer]}")
# Out:
# SGD:
# Average Accuracy: 0.4304761929171426
# RMSprop:
# Average Accuracy: 0.5146666705608368
# Adam:
# Average Accuracy: 0.8811111052831014
# Adadelta:
# Average Accuracy: 0.970333331823349
# Adagrad:
# Average Accuracy: 0.995555559794108
# Adamax:
# Average Accuracy: 0.9841666743159294
# Nadam:
# Average Accuracy: 0.9788888990879059

# %% [markdown]
# Nadam seems to have the highest accuracy. Let's try it with Nadam

# %%
model_21 = Sequential()

model_21.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
model_21.add(BatchNormalization())
model_21.add(Dense(64, activation='relu'))
model_21.add(MaxPooling2D(pool_size=(2,2)))
model_21.add(Dropout(0.3))

model_21.add(Flatten())
model_21.add(Dense(16, activation='relu'))
model_21.add(Dense(8, activation='relu'))
model_21.add(Dense(4, activation='softmax'))

# %%
model_21.compile(optimizer='Nadam',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_21_results = model_21.fit(X_train, 
                                y_train, 
                                batch_size=30, 
                                epochs=20,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/20
# 5/5 [==============================] -
                                  y_train, 
                                  batch_size=batch_size, 
                                  epochs=epoch,
                                  validation_data=(extra_val_images, extra_val_labels),
                                  callbacks=[early_stop],
                                  class_weight=class_weights_dict)
        
        # Store the results in a dictionary using the combination of batch size and epochs as keys
        results_2[(batch_size, epoch)] = model_results
# Out:
# Epoch 1/5
# 15/15 [==============================] - 2s 140ms/step - loss: 0.6326 - accuracy: 0.6667 - precision: 0.7373 - recall: 0.4350 - val_loss: 1.3777 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/5
# 15/15 [==============================] - 1s 80ms/step - loss: 0.5492 - accuracy: 0.7467 - precision: 0.7739 - recall: 0.5933 - val_loss: 1.3791 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/5
# 15/15 [==============================] - 1s 81ms/step - loss: 0.4554 - accuracy: 0.7800 - precision: 0.8333 - recall: 0.6667 - val_loss: 1.3972 - val_accuracy: 0.2300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/5
# 15/15 [==============================] - 1s 79ms/step - loss: 0.5251 - accuracy: 0.7800 - precision: 0.8034 - recall: 0.6267 - val_loss: 1.3933 - val_accuracy: 0.2400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/5
# 15/15 [==============================] - 1s 78ms/step - loss: 0.5032 - accuracy: 0.7200 - precision: 0.7299 - recall: 0.6667 - val_loss: 1.3827 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 1/10
# 15/15 [==============================] - 2s 141ms/step - loss: 0.3195 - accuracy: 0.8267 - precision: 0.8380 - recall: 0.4760 - val_loss: 1.3874 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 15/15 [==============================] - 1s 78ms/step - loss: 0.1874 - accuracy: 0.9200 - precision: 0.9149 - recall: 0.8600 - val_loss: 1.3969 - val_accuracy: 0.2800 - val_precision: 0.5000 - val_recall: 0.0100
# Epoch 3/10
# 15/15 [==============================] - 1s 76ms/step - loss: 0.2194 - accuracy: 0.8800 - precision: 0.8889 - recall: 0.8533 - val_loss: 1.4197 - val_accuracy: 0.2900 - val_precision: 0.2000 - val_recall: 0.0100
# Epoch 4/10
# 15/15 [==============================] - 1s 81ms/step - loss: 0.2262 - accuracy: 0.9000 - precision: 0.9044 - recall: 0.8200 - val_loss: 1.4447 - val_accuracy: 0.2800 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 5/10
# 15/15 [==============================] - 1s 76ms/step - loss: 0.1825 - accuracy: 0.9400 - precision: 0.9507 - recall: 0.9000 - val_loss: 1.4227 - val_accuracy: 0.2700 - val_precision: 0.2500 - val_recall: 0.0100
# Epoch 6/10
# 15/15 [==============================] - 1s 78ms/step - loss: 0.2002 - accuracy: 0.8867 - precision: 0.8897 - recall: 0.8600 - val_loss: 1.4285 - val_accuracy: 0.2100 - val_precision: 0.5000 - val_recall: 0.0100
# Epoch 1/20
# 15/15 [==============================] - 2s 147ms/step - loss: 0.4042 - accuracy: 0.8467 - precision: 0.8467 - recall: 0.5080 - val_loss: 1.4311 - val_accuracy: 0.2800 - val_precision: 0.2000 - val_recall: 0.0100
# Epoch 2/20
# 15/15 [==============================] - 1s 81ms/step - loss: 0.1564 - accuracy: 0.9267 - precision: 0.9301 - recall: 0.8867 - val_loss: 1.4261 - val_accuracy: 0.2600 - val_precision: 0.2222 - val_recall: 0.0200
# Epoch 3/20
# 15/15 [==============================] - 1s 78ms/step - loss: 0.1217 - accuracy: 0.9600 - precision: 0.9597 - recall: 0.9533 - val_loss: 1.4715 - val_accuracy: 0.2800 - val_precision: 0.2000 - val_recall: 0.0200
# Epoch 4/20
# 15/15 [==============================] - 1s 79ms/step - loss: 0.0434 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 
- val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 15/30
# 3/3 [==============================] - 1s 259ms/step - loss: 1.6557e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4153 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 16/30
# 3/3 [==============================] - 1s 251ms/step - loss: 1.2418e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4703 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 1/50
# 3/3 [==============================] - 2s 585ms/step - loss: 2.9948e-09 - accuracy: 1.0000 - precision: 0.7200 - recall: 0.7200 - val_loss: 11.4745 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 2/50
# 3/3 [==============================] - 1s 252ms/step - loss: 1.6557e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4739 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 3/50
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4570 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 4/50
# 3/3 [==============================] - 1s 257ms/step - loss: 3.4088e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4482 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 5/50
# 3/3 [==============================] - 1s 251ms/step - loss: 2.9948e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4473 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 6/50
# 3/3 [==============================] - 1s 252ms/step - loss: 1.2418e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4501 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 7/50
# 3/3 [==============================] - 1s 250ms/step - loss: 1.6557e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4546 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 8/50
# 3/3 [==============================] - 1s 248ms/step - loss: 1.8759e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4539 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 9/50
# 3/3 [==============================] - 1s 252ms/step - loss: 8.2784e-10 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4674 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000
# Epoch 10/50
# 3/3 [==============================] - 1s 245ms/step - loss: 2.2898e-09 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 11.4699 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.3000

# %%
average_accuracy = {}

for batch_size in batch_sizes:
    for epoch in epochs:
        history = results_2[(batch_size, epoch)].history
        avg_acc = sum(history['accuracy']) / len(history['accuracy'])
        average_accuracy[(batch_size, epoch)] = avg_acc

for batch_size in batch_sizes:
    for epoch in epochs:
        print(f"Batch Size {batch_size}, Epochs {epoch}:")
        print(f"Average Accuracy: {average_accuracy[(batch_size, epoch)]}")
# Out:
# Batch Size 10, Epochs 5:
# Average Accuracy: 0.7386666655540466
# Batch Size 10, Epochs 10:
# Average Accuracy: 0.8922222157319387
# Batch Size 10, Epochs 20:
# Average Accuracy: 0.9561904839106968
# Batch Size 10, Epochs 30:
# Average Accuracy: 0.9847619192940849
# Batch Size 10, Epochs 50:
# Average Accuracy: 0.9961904798235212
# Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Batch Size 50, Epochs 50:
# Average Accuracy: 1.0

# %% [markdown]
# Batch Size 10, Epochs 20 looks like a good accuracy score, let's try it out.

# %%
model_21 = Sequential()

model_21.add(Conv2D(filters=32, 
                    kernel_size=(3,3), 
                    activation='relu', 
                    input_shape=(64, 64, 1)))

model_21.add(BatchNormalization())
model_21.add(Dense(64, activation='relu'))
model_21.add(MaxPooling2D(pool_size=(2,2)))
model_21.add(Dropout(0.3))

model_21.add(Flatten())
model_21.add(Dense(16, activation='relu'))
model_21.add(Dense(8, activation='relu'))
model_21.add(Dense(4, activation='softmax'))

# %%
model_21.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_21_results = model_21.fit(X_train, 
                                y_train, 
                                batch_size=10, 
                                epochs=20,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/20
# 15/15 [==============================] - 2s 142ms/step - loss: 1.5462 - accuracy: 0.3000 - precision: 0.2727 - recall: 0.1200 - val_loss: 1.3854 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 15/15 [==============================] - 1s 74ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3854 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 15/15 [==============================] - 1s 78ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3855 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 15/15 [==============================] - 1s 78ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3854 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 15/15 [==============================] - 1s 82ms/step - loss: 1.3864 - accuracy: 0.1933 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3853 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 15/15 [==============================] - 1s 76ms/step - loss: 1.3863 - accuracy: 0.2600 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3854 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 15/15 [==============================] - 1s 83ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3855 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 15/15 [==============================] - 1s 85ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3856 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 15/15 [==============================] - 1s 83ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3857 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - 1s 83ms/step - loss: 1.3864 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3854 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_21)
# Out:
# 5/5 [==============================] - 0s 27ms/step - loss: 1.3855 - accuracy: 0.3133 - precision: 0.0000e+00 - recall: 0.0000e+00
# 2/2 [==============================] - 0s 12ms/step - loss: 1.3866 - accuracy: 0.2600 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.39
# Training Accuracy: 0.313
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.39
# Testing Accuracy: 0.26
# Testing Precision: 0.0
# Testing Recall: 0.0

# %% [markdown]
# # More models

# %%
model_22 = Sequential()

model_22.add(Conv2D(filters=32, 
                    kernel_size=(3,3), 
                    activation='relu', 
                    input_shape=(64, 64, 1), 
                    kernel_regularizer=l2(0.000001)))

model_22.add(BatchNormalization())
model_22.add(Dense(64, activation='relu'))
model_22.add(MaxPooling2D(pool_size=(2,2)))
model_22.add(Dropout(0.3))

model_22.add(Flatten())
model_22.add(Dense(16, activation='relu'))
model_22.add(Dropout(0.2))
model_22.add(Dense(8, activation='relu'))
model_22.add(Dense(4, activation='softmax', kernel_regularizer=l2(0.000001)))

# %%
model_22.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_93 (Dense)             (None, 62, 62, 64)        2112
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 31, 31, 64)        0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 61504)             0
# _________________________________________________________________
# dense_94 (Dense)             (None, 16)                984080
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_95 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_96 (Dense)             (None, 4)                 36
# =================================================================
# Total params: 986,812
# Trainable params: 986,748
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_22.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_22_results = model_22.fit(X_train, 
                                y_train, 
                                batch_size=50, 
                                epochs=25,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 2s 679ms/step - loss: 3.8630 - accuracy: 0.4333 - precision: 0.4312 - recall: 0.2350 - val_loss: 1.3947 - val_accuracy: 0.2100 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 3/3 [==============================] - 1s 257ms/step - loss: 3.0009 - accuracy: 0.2733 - precision: 0.2662 - recall: 0.2467 - val_loss: 1.3798 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 3/3 [==============================] - 1s 256ms/step - loss: 1.6837 - accuracy: 0.4133 - precision: 0.4778 - recall: 0.2867 - val_loss: 1.3898 - val_accuracy: 0.3300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 3/3 [==============================] - 1s 246ms/step - loss: 1.4023 - accuracy: 0.2267 - precision: 0.2000 - recall: 0.0267 - val_loss: 1.3876 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 3/3 [==============================] - 1s 254ms/step - loss: 1.3550 - accuracy: 0.3067 - precision: 0.6667 - recall: 0.0133 - val_loss: 1.3858 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 3/3 [==============================] - 1s 254ms/step - loss: 1.3557 - accuracy: 0.1533 - precision: 0.6667 - recall: 0.0133 - val_loss: 1.3864 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 3/3 [==============================] - 1s 251ms/step - loss: 1.3376 - accuracy: 0.1467 - precision: 0.5000 - recall: 0.0200 - val_loss: 1.3882 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_22)
# Out:
# 5/5 [==============================] - 0s 26ms/step - loss: 1.3723 - accuracy: 0.3000 - precision: 0.0000e+00 - recall: 0.0000e+00
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3957 - accuracy: 0.2400 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.37
# Training Accuracy: 0.3
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.4
# Testing Accuracy: 0.24
# Testing Precision: 0.0
# Testing Recall: 0.0

# %%
plot_metrics(model_22_results)

# %% [markdown]
# # Next one

# %%
model_23 = Sequential()

model_23.add(Conv2D(filters=32, 
                    kernel_size=(3, 3), 
                    activation='relu', 
                    input_shape=(64, 64, 1)))

model_23.add(BatchNormalization())
model_23.add(Dense(32, activation='relu'))
model_23.add(MaxPooling2D(pool_size=(2, 2)))

model_23.add(Flatten())
model_23.add(Dense(16, activation='relu'))
model_23.add(Dense(4, activation='softmax'))

# %%
model_23.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# dense_97 (Dense)             (None, 62, 62, 32)        1056
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 30752)             0
# _________________________________________________________________
# dense_98 (Dense)             (None, 16)                492048
# _________________________________________________________________
# dense_99 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 493,620
# Trainable params: 493,556
# Non-trainable params: 64
# _________________________________________________________________

# %%
model_23.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_23_results = model_23.fit(X_train, 
                                y_train, 
                                batch_size=50, 
                                epochs=25,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 2s 506ms/step - loss: 2.0389 - accuracy: 0.3467 - precision: 0.4744 - recall: 0.1850 - val_loss: 1.3888 - val_accuracy: 0.1800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 3/3 [==============================] - 1s 178ms/step - loss: 2.2253 - accuracy: 0.1200 - precision: 0.1402 - recall: 0.1000 - val_loss: 1.3860 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 3/3 [==============================] - 1s 176ms/step - loss: 1.3378 - accuracy: 0.3133 - precision: 1.0000 - recall: 0.0200 - val_loss: 1.3859 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 3/3 [==============================] - 1s 175ms/step - loss: 1.3657 - accuracy: 0.3200 - precision: 0.3333 - recall: 0.0067 - val_loss: 1.3856 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 3/3 [==============================] - 1s 175ms/step - loss: 1.3708 - accuracy: 0.3133 - precision: 0.5000 - recall: 0.0133 - val_loss: 1.3853 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/25
# 3/3 [==============================] - 1s 169ms/step - loss: 1.3505 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3849 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/25
# 3/3 [==============================] - 1s 182ms/step - loss: 1.3533 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3847 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/25
# 3/3 [==============================] - 1s 182ms/step - loss: 1.3545 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3844 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/25
# 3/3 [==============================] - 1s 171ms/step - loss: 1.3507 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3841 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/25
# 3/3 [==============================] - 1s 184ms/step - loss: 1.3493 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3836 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/25
# 3/3 [==============================] - 1s 174ms/step - loss: 1.3461 - accuracy: 0.3267 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3839 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/25
# 3/3 [==============================] - 0s 157ms/step - loss: 1.3462 - accuracy: 0.3267 - precision: 0.6667 - recall: 0.0133 - val_loss: 1.3841 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/25
# 3/3 [==============================] - 1s 169ms/step - loss: 1.3454 - accuracy: 0.3267 - precision: 0.6667 - recall: 0.0133 - val_loss: 1.3842 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/25
# 3/3 [==============================] - 0s 166ms/step - loss: 1.3449 - accuracy: 0.3267 - precision: 0.5000 - recall: 0.0133 - val_loss: 1.3844 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/25
# 3/3 [==============================] - 1s 171ms/step - loss: 1.3447 - accuracy: 0.3267 - precision: 0.6667 - recall: 0.0133 - val_loss: 1.3844 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_23)
# Out:
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3792 - accuracy: 0.3200 - precision: 0.0000e+00 - recall: 0.0000e+00
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3888 - accuracy: 0.2400 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.38
# Training Accuracy: 0.32
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.39
# Testing Accuracy: 0.24
# Testing Precision: 0.0
# Testing Recall: 0.0

# %% [markdown]
# # Again

# %%
model_24 = Sequential()

model_24.add(Conv2D(filters=16, 
                    kernel_size=(3, 3), 
                    activation='relu', 
                    input_shape=(64, 64, 1)))

model_24.add(MaxPooling2D(pool_size=(2, 2)))
model_24.add(Flatten())
model_24.add(Dense(4, activation='softmax'))

# %%
model_24.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 62, 62, 16)        160
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 31, 31, 16)        0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 15376)             0
# _________________________________________________________________
# dense_100 (Dense)            (None, 4)                 61508
# =================================================================
# Total params: 61,668
# Trainable params: 61,668
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_24.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_24_results = model_24.fit(X_train, 
                                y_train, 
                                batch_size=30, 
                                epochs=15,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 1s 221ms/step - loss: 1.4201 - accuracy: 0.1867 - precision: 0.7500 - recall: 0.0150 - val_loss: 1.4328 - val_accuracy: 0.2700 - val_precision: 0.2500 - val_recall: 0.0100
# Epoch 2/15
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2915 - accuracy: 0.5733 - precision: 0.9091 - recall: 0.0667 - val_loss: 1.4043 - val_accuracy: 0.2500 - val_precision: 0.2500 - val_recall: 0.0100
# Epoch 3/15
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1950 - accuracy: 0.5600 - precision: 1.0000 - recall: 0.0400 - val_loss: 1.3966 - val_accuracy: 0.3000 - val_precision: 0.2000 - val_recall: 0.0100
# Epoch 4/15
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1243 - accuracy: 0.5733 - precision: 0.8667 - recall: 0.0867 - val_loss: 1.4473 - val_accuracy: 0.2300 - val_precision: 0.1250 - val_recall: 0.0100
# Epoch 5/15
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0455 - accuracy: 0.6667 - precision: 0.9000 - recall: 0.2400 - val_loss: 1.4693 - val_accuracy: 0.2600 - val_precision: 0.1111 - val_recall: 0.0200
# Epoch 6/15
# 5/5 [==============================] - 0s 40ms/step - loss: 0.9748 - accuracy: 0.6800 - precision: 0.9070 - recall: 0.2600 - val_loss: 1.4549 - val_accuracy: 0.2300 - val_precision: 0.2857 - val_recall: 0.0400
# Epoch 7/15
# 5/5 [==============================] - 0s 40ms/step - loss: 0.8972 - accuracy: 0.6867 - precision: 0.9362 - recall: 0.2933 - val_loss: 1.5321 - val_accuracy: 0.2200 - val_precision: 0.1579 - val_recall: 0.0300
# Epoch 8/15
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8475 - accuracy: 0.7600 - precision: 0.8971 - recall: 0.4067 - val_loss: 1.5939 - val_accuracy: 0.2300 - val_precision: 0.2353 - val_recall: 0.0800

# %%
evaluate_model(model_24)
# Out:
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7896 - accuracy: 0.7467 - precision: 0.9157 - recall: 0.5067
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5233 - accuracy: 0.2800 - precision: 0.2800 - recall: 0.1400
# Training Loss: 0.79
# Training Accuracy: 0.747
# Training Precision: 0.916
# Training Recall: 0.507
# ---------------------------
# Testing Loss: 1.52
# Testing Accuracy: 0.28
# Testing Precision: 0.28
# Testing Recall: 0.14

# %% [markdown]
# Let's check out testing the batches, epochs, and optimizers here on this one all at once.

# %%
results_combined = {}
optimizers = ['SGD', 'RMSprop', 'Adam', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl']
batch_sizes = [10, 20, 30, 40, 50]
epochs = [5, 10, 20, 30, 50]

model = model_24  # Assuming you have defined model_21 previously

for optimizer_name in optimizers:
    for batch_size in batch_sizes:
        for epoch in epochs:
            optimizer = 'Adam'
            
            if optimizer_name == 'SGD':
                optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
            elif optimizer_name == 'RMSprop':
                optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
            elif optimizer_name == 'Adam':
                optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
            elif optimizer_name == 'Adadelta':
                optimizer = tf.keras.optimizers.Adadelta(learning_rate=0.01)
            elif optimizer_name == 'Adagrad':
                optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.01)
            elif optimizer_name == 'Adamax':
                optimizer = tf.keras.optimizers.Adamax(learning_rate=0.01)
            elif optimizer_name == 'Nadam':
                optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
            elif optimizer_name == 'Ftrl':
                optimizer = tf.keras.optimizers.Ftrl(learning_rate=0.01)
            
            model.compile(optimizer=optimizer,
                          loss='categorical_crossentropy',
                          metrics=['accuracy', precision, recall])
            
            model_results = model.fit(X_train, 
                                      y_train, 
                                      batch_size=batch_size, 
                                      epochs=epoch,
                                      validation_data=(extra_val_images, extra_val_labels),
                                      callbacks=[early_stop],
                                      class_weight=class_weights_dict)
            
            results_combined[(optimizer_name, batch_size, epoch)] = model_results
# Out:
# Epoch 1/5
# 15/15 [==============================] - 1s 80ms/step - loss: 0.7887 - accuracy: 0.7533 - precision: 0.7315 - recall: 0.3950 - val_loss: 1.5016 - val_accuracy: 0.2000 - val_precision: 0.2000 - val_recall: 0.0400
# Epoch 2/5
# 15/15 [==============================] - 0s 19ms/step - loss: 0.7589 - accuracy: 0.7533 - precision: 0.9000 - recall: 0.4800 - val_loss: 1.5025 - val_accuracy: 0.2300 - val_precision: 0.2381 - val_recall: 0.0500
# Epoch 3/5
- accuracy: 1.0000 - precision: 1.0000 - recall: 0.9867 - val_loss: 2.6852 - val_accuracy: 0.3000 - val_precision: 0.3000 - val_recall: 0.2400
# Epoch 5/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0985 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9867 - val_loss: 2.7091 - val_accuracy: 0.3100 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 6/10
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0982 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7578 - val_accuracy: 0.3000 - val_precision: 0.3012 - val_recall: 0.2500
# Epoch 7/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0985 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.6794 - val_accuracy: 0.2700 - val_precision: 0.3012 - val_recall: 0.2500
# Epoch 8/10
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0961 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.6985 - val_accuracy: 0.2900 - val_precision: 0.3125 - val_recall: 0.2500
# Epoch 1/20
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0957 - accuracy: 1.0000 - precision: 0.7598 - recall: 0.6960 - val_loss: 2.6981 - val_accuracy: 0.3000 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 2/20
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0949 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.6969 - val_accuracy: 0.3000 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 3/20
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0950 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7347 - val_accuracy: 0.2800 - val_precision: 0.3210 - val_recall: 0.2600
# Epoch 4/20
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0936 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7215 - val_accuracy: 0.2900 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 5/20
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0932 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9867 - val_loss: 2.7349 - val_accuracy: 0.2900 - val_precision: 0.3165 - val_recall: 0.2500
# Epoch 6/20
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0918 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.6998 - val_accuracy: 0.2900 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 7/20
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0917 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7383 - val_accuracy: 0.3100 - val_precision: 0.3012 - val_recall: 0.2500
# Epoch 1/30
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0923 - accuracy: 1.0000 - precision: 0.7500 - recall: 0.6960 - val_loss: 2.7217 - val_accuracy: 0.3000 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 2/30
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0906 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7311 - val_accuracy: 0.3100 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 3/30
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0906 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7604 - val_accuracy: 0.3000 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 4/30
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0899 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7947 - val_accuracy: 0.3000 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 5/30
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0891 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7542 - val_accuracy: 0.2800 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 6/30
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0896 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7506 - val_accuracy: 0.3100 - val_precision: 0.3095 - val_recall: 0.2600
# Epoch 1/50
# 4/4 [==============================] - 1s 277ms/step - loss: 0.0879 - accuracy: 1.0000 - precision: 0.7521 - recall: 0.7040 - val_loss: 2.7378 - val_accuracy: 0.2800 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 2/50
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0893 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7900 - val_accuracy: 0.2800 - val_precision: 0.3250 - val_recall: 0.2600
# Epoch 3/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0873 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7355 - val_accuracy: 0.3000 - val_precision: 0.3210 - val_recall: 0.2600
# Epoch 4/50
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0869 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7721 - val_accuracy: 0.2800 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 5/50
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0875 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7482 - val_accuracy: 0.3100 - val_precision: 0.3210 - val_recall: 0.2600
# Epoch 6/50
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0861 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7675 - val_accuracy: 0.3000 - val_precision: 0.3210 - val_recall: 0.2600
# Epoch 7/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0861 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7231 - val_accuracy: 0.2800 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 8/50
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0870 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.7649 - val_accuracy: 0.2900 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 9/50
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0843 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7545 - val_accuracy: 0.3000 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 10/50
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0840 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7623 - val_accuracy: 0.2900 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 11/50
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0836 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.8160 - val_accuracy: 0.3100 - val_precision: 0.2941 - val_recall: 0.2500
# Epoch 12/50
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0847 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7844 - val_accuracy: 0.2900 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 1/5
# 3/3 [==============================] - 1s 368ms/step - loss: 0.0823 - accuracy: 1.0000 - precision: 0.7576 - recall: 0.7000 - val_loss: 2.7921 - val_accuracy: 0.3100 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 2/5
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0828 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7632 - val_accuracy: 0.2800 - val_precision: 0.3140 - val_recall: 0.2700
# Epoch 3/5
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0816 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9933 - val_loss: 2.8032 - val_accuracy: 0.2800 - val_precision: 0.3125 - val_recall: 0.2500
# Epoch 4/5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0815 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7765 - val_accuracy: 0.2800 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 5/5
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0829 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.7739 - val_accuracy: 0.2800 - val_precision: 0.3095 - val_recall: 0.2600
# Epoch 1/10
# 3/3 [==============================] - 1s 366ms/step - loss: 0.0804 - accuracy: 1.0000 - precision: 0.7521 - recall: 0.7040 - val_loss: 2.7977 - val_accuracy: 0.2900 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 2/10
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0803 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8304 - val_accuracy: 0.3000 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 3/10
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0799 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8199 - val_accuracy: 0.2800 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 4/10
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0799 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8278 - val_accuracy: 0.3000 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 5/10
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0794 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8196 - val_accuracy: 0.3100 - val_precision: 0.3095 - val_recall: 0.2600
# Epoch 6/10
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0790 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8080 - val_accuracy: 0.2800 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 1/20
# 3/3 [==============================] - 1s 363ms/step - loss: 0.0782 - accuracy: 1.0000 - precision: 0.7543 - recall: 0.7000 - val_loss: 2.8202 - val_accuracy: 0.2800 - val_precision: 0.3049 - val_recall: 0.2500
# Epoch 2/20
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0783 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8112 - val_accuracy: 0.3100 - val_precision: 0.3210 - val_recall: 0.2600
# Epoch 3/20
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0789 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8458 - val_accuracy: 0.3100 - val_precision: 0.3059 - val_recall: 0.2600
# Epoch 4/20
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0781 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8343 - val_accuracy: 0.3100 - val_precision: 0.3095 - val_recall: 0.2600
# Epoch 5/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0773 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8347 - val_accuracy: 0.2800 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 6/20
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0766 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8505 - val_accuracy: 0.2800 - val_precision: 0.3012 - val_recall: 0.2500
# Epoch 7/20
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0777 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8184 - val_accuracy: 0.2800 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 1/30
# 3/3 [==============================] - 1s 366ms/step - loss: 0.0769 - accuracy: 1.0000 - precision: 0.7586 - recall: 0.7040 - val_loss: 2.8437 - val_accuracy: 0.2800 - val_precision: 0.3171 - val_recall: 0.2600
# Epoch 2/30
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0773 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8643 - val_accuracy: 0.2900 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 3/30
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0754 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8496 - val_accuracy: 0.2800 - val_precision: 0.3086 - val_recall: 0.2500
# Epoch 4/30
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0757 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8444 - val_accuracy: 0.3100 - val_precision: 0.3059 - val_recall: 0.2600
# Epoch 5/30
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0755 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8716 - val_accuracy: 0.3000 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 6/30
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0753 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8513 - val_accuracy: 0.2800 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 1/50
# 3/3 [==============================] - 1s 366ms/step - loss: 0.0744 - accuracy: 1.0000 - precision: 0.7554 - recall: 0.7040 - val_loss: 2.8778 - val_accuracy: 0.2800 - val_precision: 0.2976 - val_recall: 0.2500
# Epoch 2/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0740 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8625 - val_accuracy: 0.2900 - val_precision: 0.3012 - val_recall: 0.2500
# Epoch 3/50
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0738 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 2.8530 - val_accuracy: 0.2800 - val_precision: 0.3133 - val_recall: 0.2600
# Epoch 4/50
# 3/3 [==============================] - 0s 61ms/step - loss: 0.
 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3864 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3863 - accuracy: 0.4800 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 0s 46ms/step - loss: 1.3865 - accuracy: 0.2667 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 0s 45ms/step - loss: 1.3865 - accuracy: 0.2733 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 3/3 [==============================] - 0s 49ms/step - loss: 1.3865 - accuracy: 0.3267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3864 - accuracy: 0.3467 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 3/3 [==============================] - 0s 44ms/step - loss: 1.3864 - accuracy: 0.3533 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.2200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 3/3 [==============================] - 0s 59ms/step - loss: 1.3863 - accuracy: 0.3600 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3864 - accuracy: 0.3333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3863 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
average_accuracy = {}

for optimizer in optimizers: 
    for batch_size in batch_sizes:
        for epoch in epochs:
            history = results_combined[(optimizer, batch_size, epoch)].history
            avg_acc = sum(history['accuracy']) / len(history['accuracy'])
            average_accuracy[(optimizer, batch_size, epoch)] = avg_acc


for optimizer in optimizers: 
    for batch_size in batch_sizes:
        for epoch in epochs:
            print(f"Optimizer {optimizer}, Batch Size {batch_size}, Epochs {epoch}:")
            print(f"Average Accuracy: {average_accuracy[(optimizer, batch_size, epoch)]}")
# Out:
# Optimizer SGD, Batch Size 10, Epochs 5:
# Average Accuracy: 0.762666666507721
# Optimizer SGD, Batch Size 10, Epochs 10:
# Average Accuracy: 0.8103703724013435
# Optimizer SGD, Batch Size 10, Epochs 20:
# Average Accuracy: 0.8622222277853224
# Optimizer SGD, Batch Size 10, Epochs 30:
# Average Accuracy: 0.9091666713356972
# Optimizer SGD, Batch Size 10, Epochs 50:
# Average Accuracy: 0.9447618978364127
# Optimizer SGD, Batch Size 20, Epochs 5:
# Average Accuracy: 0.9479999899864197
# Optimizer SGD, Batch Size 20, Epochs 10:
# Average Accuracy: 0.9699999988079071
# Optimizer SGD, Batch Size 20, Epochs 20:
# Average Accuracy: 0.9744444489479065
# Optimizer SGD, Batch Size 20, Epochs 30:
# Average Accuracy: 0.9833333492279053
# Optimizer SGD, Batch Size 20, Epochs 50:
# Average Accuracy: 0.9847619192940849
# Optimizer SGD, Batch Size 30, Epochs 5:
# Average Accuracy: 0.9946666717529297
# Optimizer SGD, Batch Size 30, Epochs 10:
# Average Accuracy: 0.9923809596470424
# Optimizer SGD, Batch Size 30, Epochs 20:
# Average Accuracy: 0.9942857197352818
# Optimizer SGD, Batch Size 30, Epochs 30:
# Average Accuracy: 0.9944444497426351
# Optimizer SGD, Batch Size 30, Epochs 50:
# Average Accuracy: 0.995555559794108
# Optimizer SGD, Batch Size 40, Epochs 5:
# Average Accuracy: 0.9960000038146972
# Optimizer SGD, Batch Size 40, Epochs 10:
# Average Accuracy: 0.9983333349227905
# Optimizer SGD, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer SGD, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 10, Epochs 5:
# Average Accuracy: 0.7293333292007447
# Optimizer RMSprop, Batch Size 10, Epochs 10:
# Average Accuracy: 0.9522222181161245
# Optimizer RMSprop, Batch Size 10, Epochs 20:
# Average Accuracy: 0.9944444398085276
# Optimizer RMSprop, Batch Size 10, Epochs 30:
# Average Accuracy: 0.9876190509114947
# Optimizer RMSprop, Batch Size 10, Epochs 50:
# Average Accuracy: 0.9844444493452708
# Optimizer RMSprop, Batch Size 20, Epochs 5:
# Average Accuracy: 0.9679999947547913
# Optimizer RMSprop, Batch Size 20, Epochs 10:
# Average Accuracy: 0.9838095222200666
# Optimizer RMSprop, Batch Size 20, Epochs 20:
# Average Accuracy: 0.9766666690508524
# Optimizer RMSprop, Batch Size 20, Epochs 30:
# Average Accuracy: 0.9895238109997341
# Optimizer RMSprop, Batch Size 20, Epochs 50:
# Average Accuracy: 0.9957142855439868
# Optimizer RMSprop, Batch Size 30, Epochs 5:
# Average Accuracy: 0.9866666674613953
# Optimizer RMSprop, Batch Size 30, Epochs 10:
# Average Accuracy: 0.9933333311762128
# Optimizer RMSprop, Batch Size 30, Epochs 20:
# Average Accuracy: 0.9855555593967438
# Optimizer RMSprop, Batch Size 30, Epochs 30:
# Average Accuracy: 0.9922222197055817
# Optimizer RMSprop, Batch Size 30, Epochs 50:
# Average Accuracy: 0.9828571421759469
# Optimizer RMSprop, Batch Size 40, Epochs 5:
# Average Accuracy: 0.972000002861023
# Optimizer RMSprop, Batch Size 40, Epochs 10:
# Average Accuracy: 0.997142859867641
# Optimizer RMSprop, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer RMSprop, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 10, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 10, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 10, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 10, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 10, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adam, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 10, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 10, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 10, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 10, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 10, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adadelta, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 10, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 10, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 10, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 10, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 10, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adagrad, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 10, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 10, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 10, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 10, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 10, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Adamax, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 10, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 10, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 10, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 10, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 10, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 20, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 20, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 20, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 20, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 20, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 30, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 30, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 30, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 30, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 30, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 40, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 40, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 40, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 40, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 40, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 50, Epochs 5:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 50, Epochs 10:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 50, Epochs 20:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 50, Epochs 30:
# Average Accuracy: 1.0
# Optimizer Nadam, Batch Size 50, Epochs 50:
# Average Accuracy: 1.0
# Optimizer Ftrl, Batch Size 10, Epochs 5:
# Average Accuracy: 0.27200000286102294
# Optimizer Ftrl, Batch Size 10, Epochs 10:
# Average Accuracy: 0.09250000026077032
# Optimizer Ftrl, Batch Size 10, Epochs 20:
# Average Accuracy: 0.12416666746139526
# Optimizer Ftrl, Batch Size 10, Epochs 30:
# Average Accuracy: 0.12066666893661022
# Optimizer Ftrl, Batch Size 10, Epochs 50:
# Average Accuracy: 0.2913333311676979
# Optimizer Ftrl, Batch Size 20, Epochs 5:
# Average Accuracy: 0.18533333241939545
# Optimizer Ftrl, Batch Size 20, Epochs 10:
# Average Accuracy: 0.3926666609942913
# Optimizer Ftrl, Batch Size 20, Epochs 20:
# Average Accuracy: 0.2850000001490116
# Optimizer Ftrl, Batch Size 20, Epochs 30:
# Average Accuracy: 0.20666666949788728
# Optimizer Ftrl, Batch Size 20, Epochs 50:
# Average Accuracy: 0.1405128211929248
# Optimizer Ftrl, Batch Size 30, Epochs 5:
# Average Accuracy: 0.12133333086967468
# Optimizer Ftrl, Batch Size 30, Epochs 10:
# Average Accuracy: 0.24666666202247142
# Optimizer Ftrl, Batch Size 30, Epochs 20:
# Average Accuracy: 0.12666666880249977
# Optimizer Ftrl, Batch Size 30, Epochs 30:
# Average Accuracy: 0.2726666659116745
# Optimizer Ftrl, Batch Size 30, Epochs 50:
# Average Accuracy: 0.12222222321563297
# Optimizer Ftrl, Batch Size 40, Epochs 5:
# Average Accuracy: 0.1840000033378601
# Optimizer Ftrl, Batch Size 40, Epochs 10:
# Average Accuracy: 0.2377777819832166
# Optimizer Ftrl, Batch Size 40, Epochs 20:
# Average Accuracy: 0.12421052726475816
# Optimizer Ftrl, Batch Size 40, Epochs 30:
# Average Accuracy: 0.2063636373389851
# Optimizer Ftrl, Batch Size 40, Epochs 50:
# Average Accuracy: 0.16190476609127863
# Optimizer Ftrl, Batch Size 50, Epochs 5:
# Average Accuracy: 0.13333333432674407
# Optimizer Ftrl, Batch Size 50, Epochs 10:
# Average Accuracy: 0.218888891239961
# Optimizer Ftrl, Batch Size 50, Epochs 20:
# Average Accuracy: 0.1557575755498626
# Optimizer Ftrl, Batch Size 50, Epochs 30:
# Average Accuracy: 0.17151515185832977
# Optimizer Ftrl, Batch Size 50, Epochs 50:
# Average Accuracy: 0.31400000154972074

# %% [markdown]
# let's try : Optimizer SGD, Batch Size 10, Epochs 50:

# %%
model_24 = Sequential()

model_24.add(Conv2D(filters=16, 
                    kernel_size=(3, 3), 
                    activation='relu', 
                    input_shape=(64, 64, 1)))

model_24.add(MaxPooling2D(pool_size=(2, 2)))
model_24.add(Flatten())
model_24.add(Dense(4, activation='softmax'))

# %%
model_24.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_24_results = model_24.fit(X_train, 
                                y_train, 
                                batch_size=10, 
                                epochs=50,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 38ms/step - loss: 1.4094 - accuracy: 0.2067 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3889 - val_accuracy: 0.2300 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3646 - accuracy: 0.3533 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4012 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3399 - accuracy: 0.4667 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3785 - val_accuracy: 0.2700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 15/15 [==============================] - 0s 10ms/step - loss: 1.3080 - accuracy: 0.3800 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.3918 - val_accuracy: 0.2400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.2888 - accuracy: 0.4667 - precision: 1.0000 - recall: 0.0133 - val_loss: 1.4114 - val_accuracy: 0.2800 - val_precision: 0.1429 - val_recall: 0.0100
# Epoch 6/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.2644 - accuracy: 0.5067 - precision: 0.8889 - recall: 0.0533 - val_loss: 1.4057 - val_accuracy: 0.2500 - val_precision: 0.2000 - val_recall: 0.0100
# Epoch 7/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.2338 - accuracy: 0.5333 - precision: 1.0000 - recall: 0.0467 - val_loss: 1.3976 - val_accuracy: 0.2400 - val_precision: 0.2000 - val_recall: 0.0100
# Epoch 8/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.2191 - accuracy: 0.4667 - precision: 0.9091 - recall: 0.0667 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100

# %%
evaluate_model(model_24)
# Out:
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1404 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4680 - accuracy: 0.2800 - precision: 0.3333 - recall: 0.0200
# Training Loss: 1.14
# Training Accuracy: 0.58
# Training Precision: 0.929
# Training Recall: 0.0867
# ---------------------------
# Testing Loss: 1.47
# Testing Accuracy: 0.28
# Testing Precision: 0.333
# Testing Recall: 0.02

# %% [markdown]
# SGD is sensitive to learning rate, let's play with that

# %%
learning_rate_results = {}
learning_rates = [0.00001, 0.001, 0.01, 0.1, 1]

for rate in learning_rates:
    model = model_24
    
    optimizer = tf.keras.optimizers.SGD(learning_rate=rate)
    
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy', precision, recall])
        
    # Train the model
    model_results = model.fit(X_train, 
                              y_train, 
                              batch_size=batch_size, 
                              epochs=epoch,
                              validation_data=(extra_val_images, extra_val_labels),
                              callbacks=[early_stop],
                              class_weight=class_weights_dict)
        
    # Store the results in a dictionary using the learning rate as the key
    learning_rate_results[rate] = model_results
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 166ms/step - loss: 1.1570 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0520 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 2/50
# 3/3 [==============================] - 0s 34ms/step - loss: 1.1570 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 3/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1570 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 4/50
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1570 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 5/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1569 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 6/50
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1569 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 1/50
# 3/3 [==============================] - 0s 167ms/step - loss: 1.1575 - accuracy: 0.5800 - precision: 0.6087 - recall: 0.0560 - val_loss: 1.4215 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 2/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1568 - accuracy: 0.5667 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4216 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 3/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1557 - accuracy: 0.5800 - precision: 0.9286 - recall: 0.0867 - val_loss: 1.4217 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 4/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1554 - accuracy: 0.5733 - precision: 1.0000 - recall: 0.0867 - val_loss: 1.4217 - val_accuracy: 0.2800 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 5/50
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1541 - accuracy: 0.5733 - precision: 1.0000 - recall: 0.0867 - val_loss: 1.4218 - val_accuracy: 0.2800 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 6/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1536 - accuracy: 0.5733 - precision: 1.0000 - recall: 0.0867 - val_loss: 1.4219 - val_accuracy: 0.2700 - val_precision: 0.1111 - val_recall: 0.0100
# Epoch 1/50
# 3/3 [==============================] - 1s 182ms/step - loss: 1.1561 - accuracy: 0.5800 - precision: 0.6087 - recall: 0.0560 - val_loss: 1.4204 - val_accuracy: 0.2700 - val_precision: 0.1250 - val_recall: 0.0100
# Epoch 2/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1532 - accuracy: 0.5600 - precision: 0.9375 - recall: 0.1000 - val_loss: 1.4201 - val_accuracy: 0.2700 - val_precision: 0.1250 - val_recall: 0.0100
# Epoch 3/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1431 - accuracy: 0.5800 - precision: 0.9333 - recall: 0.0933 - val_loss: 1.4223 - val_accuracy: 0.2700 - val_precision: 0.1429 - val_recall: 0.0100
# Epoch 4/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.
- val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3857 - accuracy: 0.1333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3911 - val_accuracy: 0.2800 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3860 - accuracy: 0.3400 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3770 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.3914 - accuracy: 0.0933 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3830 - val_accuracy: 0.3400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3895 - accuracy: 0.0933 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3884 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3911 - accuracy: 0.3267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3870 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3929 - accuracy: 0.2067 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3916 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/50
# 3/3 [==============================] - 0s 31ms/step - loss: 1.4060 - accuracy: 0.1200 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3916 - val_accuracy: 0.1700 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
average_accuracy = {}

for rate in learning_rates: 
    history = learning_rate_results[rate].history
    avg_acc = sum(history['accuracy']) / len(history['accuracy'])
    average_accuracy[rate] = avg_acc

for rate in learning_rates: 
    print(f"Learning Rate {rate}:")
    print(f"Average Accuracy: {average_accuracy[rate]}")
# Out:
# Learning Rate 1e-05:
# Average Accuracy: 0.5799999833106995
# Learning Rate 0.001:
# Average Accuracy: 0.5744444330533346
# Learning Rate 0.01:
# Average Accuracy: 0.5666666626930237
# Learning Rate 0.1:
# Average Accuracy: 0.5323809470449176
# Learning Rate 1:
# Average Accuracy: 0.20619047539574759

# %% [markdown]
# Let's try 1e-05.

# %%
model_24 = Sequential()

model_24.add(Conv2D(filters=16, 
                    kernel_size=(3, 3), 
                    activation='relu', 
                    input_shape=(64, 64, 1)))

model_24.add(MaxPooling2D(pool_size=(2, 2)))
model_24.add(Flatten())
model_24.add(Dense(4, activation='softmax'))

# %%
model_24.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.00001),
              loss='categorical_crossentropy',
              metrics=['accuracy', precision, recall])

model_24_results = model_24.fit(X_train, 
                                y_train, 
                                batch_size=10, 
                                epochs=50,
                                validation_data=(extra_val_images, extra_val_labels),
                                callbacks=[early_stop],
                                class_weight=class_weights_dict)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 43ms/step - loss: 1.3936 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4011 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.3935 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4010 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3934 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4010 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3933 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4009 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 15/15 [==============================] - 0s 10ms/step - loss: 1.3932 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4009 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3931 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4008 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.3930 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4008 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3929 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4007 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3928 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4007 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3927 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4006 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3926 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4006 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/50
# 15/15 [==============================] - 0s 9ms/step - loss: 1.3925 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4005 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3924 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4005 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3923 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4004 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3922 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4004 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3921 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4003 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.3920 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4003 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3919 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4002 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3918 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4002 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3917 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4001 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3916 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4001 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.3915 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4000 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3914 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4000 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3913 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3999 - val_accuracy: 0.2600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/50
# 15/15 [==============================] - 0s 11ms/step - loss: 1.3912 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3999 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3911 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3999 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3910 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3998 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3909 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3998 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3908 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3997 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3907 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3997 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/50
# 15/15 [==============================] - 0s 15ms/step - loss: 1.3906 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3996 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/50
# 15/15 [==============================] - 0s 13ms/step - loss: 1.3905 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3996 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/50
# 15/15 [==============================] - 0s 12ms/step - loss: 1.3904 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3995 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3903 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3995 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/50
# 15/15 [==============================] - 0s 15ms/step - loss: 1.3902 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3994 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/50
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3901 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3994 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/50
# 15/15 [==============================] - 0s 14ms/step - loss: 1.3900 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3994 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/50
# 15/15 [==============================] - 0s 19ms/step - loss: 1.3899 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3993 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/50
# 15/15 [==============================] - 0s 18ms/step - loss: 1.3898 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3993 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.3897 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3992 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/50
# 15/15 [==============================] - 0s 25ms/step - loss: 1.3896 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3992 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/50
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3896 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3991 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/50
# 15/15 [==============================] - 0s 27ms/step - loss: 1.3895 - accuracy: 0.2267 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3991 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/50
# 15/15 [==============================] - 0s 26ms/step - loss: 1.3894 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3991 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/50
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3893 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3990 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/50
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3892 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3990 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/50
# 15/15 [==============================] - 0s 26ms/step - loss: 1.3891 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3989 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/50
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3890 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3989 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.3889 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3988 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/50
# 15/15 [==============================] - 0s 30ms/step - loss: 1.3888 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3988 - val_accuracy: 0.2500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
evaluate_model(model_24)
# Out:
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4089 - accuracy: 0.2333 - precision: 0.0000e+00 - recall: 0.0000e+00
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4041 - accuracy: 0.2400 - precision: 0.0000e+00 - recall: 0.0000e+00
# Training Loss: 1.41
# Training Accuracy: 0.233
# Training Precision: 0.0
# Training Recall: 0.0
# ---------------------------
# Testing Loss: 1.4
# Testing Accuracy: 0.24
# Testing Precision: 0.0
# Testing Recall: 0.0

# %% [markdown]
# # Pre-trained models

# %% [markdown]
# There are a number of pre-trained models that might help performance. Starting with VGG16.

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
# include_top = false so we can customize the number of classes
vgg_model = VGG16(include_top=False, 
                  input_shape=(64, 64, 3), 
                  classes=4)

# %%
# oooook, time to try another method. 
# try data augmentation
# need to do the train test split first and then augment
# research and find out how to do that
# maybe load in normally, do the split, then reload the train as augmented and just using xtrain, ytrain?

# %% [markdown]
# # Let's try grid searching

# %%
def build_model():
    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(64, 64, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(16, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(4, activation='softmax'))

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy', precision, recall])
    
    return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_77 (Conv2D)           (None, 62, 62, 32)        320
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 62, 62, 32)        128
# _________________________________________________________________
# max_pooling2d_77 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 29, 29, 32)        9248
# _________________________________________________________________
# max_pooling2d_78 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 12, 12, 16)        4624
# _________________________________________________________________
# max_pooling2d_79 (MaxPooling (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_117 (Dense)            (None, 32)                18464
# _________________________________________________________________
# dense_118 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_119 (Dense)            (None, 4)                 68
# =================================================================
# Total params: 33,380
# Trainable params: 33,316
# Non-trainable params: 64
# _________________________________________________________________

# %%
keras_model = KerasClassifier(build_fn=build_model,
                              epochs=50,
                              batch_size=150,
                              verbose=1)

# %%
nn_pipe = Pipeline(steps=[('nn', keras_model)])
nn_pipe.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'nn', 'nn__epochs', 'nn__batch_size', 'nn__verbose', 'nn__build_fn'])

# %%
batch_size = [10, 20, 30]
epochs = [10, 20, 30]
verbose = [1, 2, 3]

param_grid = dict(batch_size=batch_size, epochs=epochs, verbose=verbose)

# %%
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted')
}

# %%
nn_gs = GridSearchCV(estimator=keras_model, 
                     param_grid=param_grid, 
                     n_jobs=-1, 
                     cv=3, 
                     scoring=scoring, 
                     refit=False)

# %%
with parallel_backend('threading'):
    grid_result = nn_gs.fit(X_train, y_train_multiclass)
# Out:
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
# Epoch 1/10
#  2/10 [=====>........................] - ETA: 0s - loss: 1.6760 - accuracy: 0.2500 - precision_1: 0.4757 - recall_1: 0.272210/10 - 1s - loss: 1.2689 - accuracy: 0.4800 - precision_1: 0.5128 - recall_1: 0.2727
# Epoch 2/10
#  6/10 [=================>............] - ETA: 0s - loss: 1.4733 - accuracy: 0.2833 - precision_1: 0.4444 - recall_1: 0.2182Epoch 2/10
# 10/10 [==============================] - 1s 111ms/step - loss: 1.4433 - accuracy: 0.3100 - precision_1: 0.5111 - recall_1: 0.1150
# Epoch 2/10
#  8/10 [=======================>......] - ETA: 0s - loss: 1.4836 - accuracy: 0.4000 - precision_1: 0.5147 - recall_1: 0.175010/10 - 1s - loss: 1.1921 - accuracy: 0.4500 - precision_1: 0.5410 - recall_1: 0.1737
# Epoch 3/10
# 10/10 [==============================] - 1s 136ms/step - loss: 1.4460 - accuracy: 0.4000 - precision_1: 0.4000 - recall_1: 0.1833
# Epoch 2/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4615 - accuracy: 0.2000 - precision_1: 0.7059 - recall_1: 0.2400Epoch 3/10
# 10/10 - 2s - loss: 1.4086 - accuracy: 0.1200 - precision_1: 0.6364 - recall_1: 0.1750
# Epoch 2/10
#  7/10 [====================>.........] - ETA: 0s - loss: 1.3973 - accuracy: 0.3857 - precision_1: 0.5938 - recall_1: 0.1727
#  3/10 [========>.....................] - ETA: 0s - loss: 1.3072 - accuracy: 0.3667 - precision_1: 0.5385 - recall_1: 0.200010/10 - 1s - loss: 1.2631 - accuracy: 0.4100 - precision_1: 0.5882 - recall_1: 0.2000
# Epoch 2/10
# 10/10 [==============================] - 2s 151ms/step - loss: 1.3442 - accuracy: 0.3800 - precision_1: 0.6923 - recall_1: 0.1800
# Epoch 2/10
# 10/10 [==============================] - 2s 159ms/step - loss: 1.3158 - accuracy: 0.3900 - precision_1: 0.5926 - recall_1: 0.2286
# Epoch 3/10
#  8/10 [=======================>......] - ETA: 0s - loss: 1.1917 - accuracy: 0.5125 - precision_1: 0.4839 - recall_1: 0.150010/10 - 1s - loss: 1.0856 - accuracy: 0.5500 - precision_1: 0.4857 - recall_1: 0.1417
# Epoch 4/10
# 10/10 [==============================] - 1s 144ms/step - loss: 1.1978 - accuracy: 0.5200 - precision_1: 0.6829 - recall_1: 0.2545
# Epoch 3/10
#  5/10 [==============>...............] - ETA: 0s - loss: 1.2001 - accuracy: 0.5000 - precision_1: 0.6731 - recall_1: 0.2333Epoch 4/10
#  1/10 [==>...........................] - ETA: 0s - loss: 0.8329 - accuracy: 0.8000 - precision_1: 0.6000 - recall_1: 0.3000Epoch 3/10
#  7/10 [====================>.........] - ETA: 0s - loss: 1.1714 - accuracy: 0.5143 - precision_1: 0.7500 - recall_1: 0.300010/10 - 2s - loss: 1.3479 - accuracy: 0.3700 - precision_1: 0.7000 - recall_1: 0.2333
# Epoch 3/10
#  7/10 [====================>.........] - ETA: 0s - loss: 1.1401 - accuracy: 0.5286 - precision_1: 0.5000 - recall_1: 0.100010/10 - 2s - loss: 1.1945 - accuracy: 0.4800 - precision_1: 0.6389 - recall_1: 0.2875
# Epoch 3/10
# 10/10 [==============================] - 2s 162ms/step - loss: 1.1204 - accuracy: 0.5400 - precision_1: 0.5738 - recall_1: 0.2333
# Epoch 3/10
# 10/10 [==============================] - 2s 151ms/step - loss: 1.2201 - accuracy: 0.4800 - precision_1: 0.6000 - recall_1: 0.2211
# Epoch 4/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.0334 - accuracy: 0.4000 - precision_1: 0.6667 - recall_1: 0.200010/10 - 2s - loss: 1.0672 - accuracy: 0.5400 - precision_1: 0.6364 - recall_1: 0.2000
# Epoch 5/10
#  4/10 [===========>..................] - ETA: 1s - loss: 1.1646 - accuracy: 0.5250 - precision_1: 0.7018 - recall_1: 0.2353 2/10 [=====>........................] - ETA: 0s - loss: 1.1615 - accuracy: 0.6000 - precision_1: 0.6552 - recall_1:Epoch 5/10
# Epoch 4/10
# 10/10 [==============================] - 2s 215ms/step - loss: 1.1147 - accuracy: 0.5400 - precision_1: 0.9000 - recall_1: 0.4500
# Epoch 4/10
# 10/10 - 2s - loss: 1.2531 - accuracy: 0.4700 - precision_1: 0.7500 - recall_1: 0.3000
# Epoch 4/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.0156 - accuracy: 0.6000 - precision_1: 0.7500 - recall_1: 0.300010/10 - 2s - loss: 1.1265 - accuracy: 0.4900 - precision_1: 0.6154 - recall_1: 0.2667
# Epoch 4/10
# 10/10 [==============================] - 3s 264ms/step - loss: 1.0709 - accuracy: 0.5700 - precision_1: 0.6637 - recall_1: 0.3261
# Epoch 4/10
# 10/10 [==============================] - 3s 261ms/step - loss: 1.1592 - accuracy: 0.5600 - precision_1: 0.6410 - recall_1: 0.3125
# Epoch 5/10
# 10/10 - 2s - loss: 1.0340 - accuracy: 0.5200 - precision_1: 0.6000 - recall_1: 0.3000
# Epoch 6/10
#  3/10 [========>.....................] - ETA: 1s - loss: 1.0801 - accuracy: 0.5333 - precision_1: 0.6990 - recall_1: 0.3789Epoch 6/10
#  4/10 [===========>..................] - ETA: 1s - loss: 1.0261 - accuracy: 0.5750 - precision_1: 0.7324 - recall_1: 0.4000Epoch 5/10
# 10/10 [==============================] - 3s 270ms/step - loss: 1.0435 - accuracy: 0.5800 - precision_1: 0.9000 - recall_1: 0.4500
# Epoch 5/10
#  5/10 [==============>...............] - ETA: 1s - loss: 1.0931 - accuracy: 0.5200 - precision_1: 0.6957 - recall_1: 0.400010/10 - 3s - loss: 1.1887 - accuracy: 0.4700 - precision_1: 0.6944 - recall_1: 0.4167
# Epoch 5/10
#  6/10 [=================>............] - ETA: 1s - loss: 1.1261 - accuracy: 0.4833 - precision_1: 0.5357 - recall_1: 0.300010/10 - 3s - loss: 1.0990 - accuracy: 0.4900 - precision_1: 0.6053 - recall_1: 0.3286
# Epoch 5/10
# 10/10 [==============================] - 3s 274ms/step - loss: 1.1039 - accuracy: 0.5400 - precision_1: 0.7183 - recall_1: 0.3923
# Epoch 6/10
# 10/10 - 3s - loss: 0.9902 - accuracy: 0.5800 - precision_1: 0.7338 - recall_1: 0.3897
# 10/10 [==============================] - 3s 290ms/step - loss: 1.0807 - accuracy: 0.5200 - precision_1: 0.7211 - recall_1: 0.3926
# Epoch 7/10
# Epoch 5/10
#  3/10 [========>.....................] - ETA: 1s - loss: 0.9938 - accuracy: 0.5333 - precision_1: 0.6857 - recall_1: 0.4364Epoch 7/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9664 - accuracy: 0.6111 - precision_1: 0.6774 - recall_1: 0.4375Epoch 6/10
# 10/10 [==============================] - 3s 269ms/step - loss: 0.9927 - accuracy: 0.6000 - precision_1: 0.7143 - recall_1: 0.5000
# Epoch 6/10
#  4/10 [===========>..................] - ETA: 1s - loss: 0.9662 - accuracy: 0.5500 - precision_1: 0.7500 - recall_1: 0.360010/10 - 3s - loss: 1.1726 - accuracy: 0.4700 - precision_1: 0.5385 - recall_1: 0.2333
# Epoch 6/10
#  6/10 [=================>............] - ETA: 0s - loss: 1.1511 - accuracy: 0.5333 - precision_1: 0.8824 - recall_1: 0.500010/10 - 3s - loss: 1.0667 - accuracy: 0.5600 - precision_1: 0.8500 - recall_1: 0.4250
# Epoch 6/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9655 - accuracy: 0.5444 - precision_1: 0.6984 - recall_1: 0.382610/10 - 3s - loss: 0.9248 - accuracy: 0.5900 - precision_1: 0.6978 - recall_1: 0.3880
# Epoch 8/10
# 10/10 [==============================] - 3s 274ms/step - loss: 1.0812 - accuracy: 0.6000 - precision_1: 0.6971 - recall_1: 0.3935
# Epoch 7/10
# 10/10 [==============================] - 3s 268ms/step - loss: 0.9673 - accuracy: 0.5500 - precision_1: 0.7018 - recall_1: 0.4000
# Epoch 6/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9229 - accuracy: 0.6444 - precision_1: 0.7667 - recall_1: 0.4381Epoch 8/10
#  3/10 [========>.....................] - ETA: 1s - loss: 0.8457 - accuracy: 0.7000 - precision_1: 0.7619 - recall_1: 0.4364Epoch 7/10
# 10/10 [==============================] - 3s 253ms/step - loss: 0.9364 - accuracy: 0.6400 - precision_1: 0.8333 - recall_1: 0.5000
#  4/10 [===========>..................]
#  1/10 [==>...........................] - ETA: 0s - loss: 0.9767 - accuracy: 0.5000 - precision_1: 0.6923 - recall_1: 0.450010/10 - 3s - loss: 1.1331 - accuracy: 0.4700 - precision_1: 0.6667 - recall_1: 0.3333
# Epoch 7/10
#  2/10 [=====>........................] - ETA: 1s - loss: 0.9417 - accuracy: 0.5500 - precision_1: 0.7778 - recall_1: 0.350010/10 - 3s - loss: 1.0422 - accuracy: 0.5800 - precision_1: 0.7917 - recall_1: 0.3800
# Epoch 7/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9973 - accuracy: 0.5889 - precision_1: 0.7634 - recall_1: 0.476210/10 - 2s - loss: 0.8645 - accuracy: 0.6800 - precision_1: 0.7870 - recall_1: 0.4926
# Epoch 9/10
# 10/10 [==============================] - 3s 250ms/step - loss: 0.8362 - accuracy: 0.6900 - precision_1: 0.8889 - recall_1: 0.8000
# Epoch 7/10
# 10/10 [==============================] - 3s 262ms/step - loss: 1.0031 - accuracy: 0.5800 - precision_1: 0.7865 - recall_1: 0.4871
# Epoch 8/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.8916 - accuracy: 0.6111 - precision_1: 0.7442 - recall_1: 0.5333Epoch 9/10
# Epoch 8/10
# 10/10 [==============================] - 3s 251ms/step - loss: 0.9088 - accuracy: 0.6000 - precision_1: 0.7200 - recall_1: 0.4500
# Epoch 8/10
#  4/10 [===========>..................] - ETA: 1s - loss: 0.7757 - accuracy: 0.7250 - precision_1: 0.8750 - recall_1: 0.700010/10 - 2s - loss: 1.1239 - accuracy: 0.4700 - precision_1: 0.6471 - recall_1: 0.5500
# Epoch 8/10
#  5/10 [==============>...............] - ETA: 1s - loss: 0.8838 - accuracy: 0.6400 - precision_1: 0.3333 - recall_1: 0.300010/10 - 2s - loss: 0.9981 - accuracy: 0.6200 - precision_1: 0.5200 - recall_1: 0.3250
# Epoch 8/10
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9726 - accuracy: 0.5778 - precision_1: 0.7372 - recall_1: 0.460010/10 - 2s - loss: 0.7949 - accuracy: 0.6800 - precision_1: 0.7473 - recall_1: 0.4633
# Epoch 10/10
# 10/10 [==============================] - 2s 243ms/step - loss: 0.7846 - accuracy: 0.7200 - precision_1: 0.7350 - recall_1: 0.4594
# Epoch 8/10
# 10/10 [==============================] - 2s 240ms/step - loss: 0.9819 - accuracy: 0.5800 - precision_1: 0.7342 - recall_1: 0.4657
# Epoch 9/10
#  2/10 [=====>........................] - ETA: 1s - loss: 0.8564 - accuracy: 0.7000 - precision_1: 0.8286 - recall_1: 0.5800Epoch 9/10
# Epoch 10/10
# 10/10 [==============================] - 3s 257ms/step - loss: 0.8530 - accuracy: 0.6700 - precision_1: 0.7143 - recall_1: 0.5000
# Epoch 9/10
#  4/10 [===========>..................] - ETA: 1s - loss: 0.6962 - accuracy: 0.6750 - precision_1: 0.7778 - recall_1: 0.560010/10 - 2s - loss: 1.0961 - accuracy: 0.4700 - precision_1: 0.7917 - recall_1: 0.5429
# Epoch 9/10
#  4/10 [===========>..................] - ETA: 1s - loss: 0.8760 - accuracy: 0.7250 - precision_1: 0.8036 - recall_1: 0.562510/10 - 2s - loss: 0.9520 - accuracy: 0.6000 - precision_1: 1.0000 - recall_1: 0.4000
# Epoch 9/10
# 10/10 [==============================] - 2s 248ms/step - loss: 0.9712 - accuracy: 0.6200 - precision_1: 0.7038 - recall_1: 0.5083
# Epoch 10/10
# 10/10 [==============================] - 3s 263ms/step - loss: 0.7931 - accuracy: 0.6500 - precision_1: 0.7099 - recall_1: 0.5200
# Epoch 9/10
# 10/10 - 3s - loss: 0.8441 - accuracy: 0.6400 - precision_1: 0.7076 - recall_1: 0.5195
#  1/10 [==>...........................] - ETA: 0s - loss: 0.
# C:\Users\rache\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 1/20
# Epoch 2/10
#  3/10 [========>.....................] - ETA: 0s - loss: 1.4690 - accuracy: 0.1000 - precision_1: 0.4828 - recall_1: 0.1167   Epoch 3/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4550 - accuracy: 0.2000 - precision_1: 0.5600 - recall_1: 0.1333precision_1: 0.5938 - recall_1: 0.1462 - ETA: 0s - loss: 1.3941 - accuracy: 0.3143 - precision_1: 0.6000 - recall_1: 0.15Epoch 4/1
# 10/10 [==============================] - 1s 135ms/step - loss: 1.3140 - accuracy: 0.3800 - precision_1: 0.3878 - recall_1: 0.1267=========================>...] - ETA: 0s - loss: 1.3561 - accuracy: 0.3333 - precision_1: 0.5000 - recall_1: 0.1250 5/10 [==============>...............] - ETA: 0s - loss: 1.3189 - accuracy: 0.3600 - precision_1: 0.4667 - recall_1: 0.1
# Epoch 2/20
#  5/10 [==============>...............] - ETA: 0s - loss: 1.3462 - accuracy: 0.4400 - precision_1: 0.4706 - recall_1: 0.160010/10 - 1s - loss: 1.4053 - accuracy: 0.2900 - precision_1: 0.4667 - recall_1: 0.2000
# Epoch 2/20
# 10/10 [==============================] - 1s 147ms/step - loss: 1.2571 - accuracy: 0.4400 - precision_1: 0.5918 - recall_1: 0.1933[==========================>...] - ETA: 0s - loss: 1.2501 - accuracy: 0.4333 - precision_1: 0.6296 - recall_1: 0.2
# Epoch 2/20
# 10/10 [==============================] - 2s 159ms/step - loss: 1.2647 - accuracy: 0.5200 - precision_1: 0.4737 - recall_1: 0.1800
# Epoch 2/20
# Epoch 5/10
#  1/10 [==>...........................] - ETA: 0s - loss: 0.9344 - accuracy: 0.8000 - precision_1: 0.6875 - recall_1: 0.3667Epoch 2/20
# 10/10 [==============================] - 3s 296ms/step - loss: 1.1633 - accuracy: 0.4900 - precision_1: 0.5840 - recall_1: 0.3318
# Epoch 3/20
# 10/10 - 3s - loss: 1.3205 - accuracy: 0.4500 - precision_1: 0.5938 - recall_1: 0.3167
# Epoch 2/20
#  7/10 [====================>.........] - ETA: 1s - loss: 1.0640 - accuracy: 0.5571 - precision_1: 0.5000 - recall_1: 0.200010/10 - 3s - loss: 1.1702 - accuracy: 0.4900 - precision_1: 0.6364 - recall_1: 0.2333
# Epoch 3/20
#  8/10 [=======================>......] - ETA: 0s - loss: 1.0764 - accuracy: 0.5500 - precision_1: 0.4545 - recall_1: 0.250010/10 - 4s - loss: 1.2690 - accuracy: 0.4500 - precision_1: 0.4348 - recall_1: 0.2000
# Epoch 2/20
# 10/10 [==============================] - 4s 392ms/step - loss: 1.1302 - accuracy: 0.5200 - precision_1: 0.5763 - recall_1: 0.3091
# Epoch 3/20
# 10/10 [==============================] - 4s 429ms/step - loss: 1.1562 - accuracy: 0.6100 - precision_1: 0.5741 - recall_1: 0.2818: 0s - loss: 1.0380 - accuracy: 0.6000 - precision_1: 0.6552 - recall_1: 0.
# Epoch 3/20
# Epoch 6/10
# Epoch 3/20
#  - ETA: 0s - loss: 1.1066 - accuracy: 0.4889 - precision_1: 0.5926 - recall_1: 0.2286 4/10 [===========>..................] - ETA: 1s - loss: 1.1538 - accuracy: 0.5250 - precision_1: 0.5909 - recall_1: 0.236410/10 - 4s - loss: 1.1697 - accuracy: 0.5000 - precision_1: 0.6364 - recall_1: 0.2593
# Epoch 3/20
# 10/10 [==============================] - 4s 424ms/step - loss: 1.1110 - accuracy: 0.4900 - precision_1: 0.6190 - recall_1: 0.2600
# Epoch 4/20
# 10/10 - 4s - loss: 1.1174 - accuracy: 0.4900 - precision_1: 0.6875 - recall_1: 0.3667
# Epoch 4/20
#  1/10 [==>...........................] - ETA: 0s - loss: 0.9265 - accuracy: 0.6000 - precision_1: 0.6667 - recall_1: 0.300010/10 - 4s - loss: 1.2040 - accuracy: 0.5100 - precision_1: 0.5455 - recall_1: 0.2000
# Epoch 3/20
# 10/10 [==============================] - 4s 368ms/step - loss: 1.0762 - accuracy: 0.5300 - precision_1: 0.7297 - recall_1: 0.3375
# Epoch 4/20
# 10/10 [==============================] - 4s 370ms/step - loss: 1.0755 - accuracy: 0.5900 - precision_1: 0.7143 - recall_1: 0.3333
# Epoch 4/20
# Epoch 7/10
# Epoch 4/20
#  9/10 [==========================>...] - ETA: 0s - loss: 1.1188 - accuracy: 0.5333 - precision_1: 0.5916 - recall_1: 0.3324- ETA: 1s - loss: 1.2001 - accuracy: 0.5667 - precision_1: 0.5288 - recall_1: 010/10 - 4s - loss: 1.1155 - accuracy: 0.5100 - precision_1: 0.6087 - recall_1: 0.3405
# Epoch 4/20
#  8/10 [=======================>......] - ETA: 0s - loss: 1.0264 - accuracy: 0.5750 - precision_1: 0.6223 - recall_1: 0.362510/10 - 4s - loss: 1.1124 - accuracy: 0.5100 - precision_1: 0.5000 - recall_1: 0.4000
# Epoch 5/20
# 10/10 [==============================] - 4s 406ms/step - loss: 1.1178 - accuracy: 0.5100 - precision_1: 0.6000 - recall_1: 0.4000
# 10/10 - 4s - loss: 1.1523 - accuracy: 0.5500 - precision_1: 0.3750 - recall_1: 0.3000
# Epoch 5/20
# Epoch 4/20
# 10/10 [==============================] - 4s 373ms/step - loss: 1.0516 - accuracy: 0.5900 - precision_1: 0.7500 - recall_1: 0.5250
# Epoch 5/20
# 10/10 [==============================] - 4s 379ms/step - loss: 1.0754 - accuracy: 0.5800 - precision_1: 0.6066 - recall_1: 0.3083
# Epoch 5/20
# Epoch 5/20
# Epoch 8/10
#  7/10 [====================>.........] - ETA: 1s - loss: 1.0472 - accuracy: 0.5429 - precision_1: 0.6821 - recall_1: 0.347110/10 - 4s - loss: 1.0815 - accuracy: 0.5800 - precision_1: 0.6957 - recall_1: 0.3556
# Epoch 5/20
# 10/10 - 4s - loss: 1.0411 - accuracy: 0.5400 - precision_1: 0.7026 - recall_1: 0.3605
# Epoch 6/20
# 10/10 [==============================] - 4s 387ms/step - loss: 1.0658 - accuracy: 0.5400 - precision_1: 0.6250 - recall_1: 0.3333
# Epoch 6/20
# 10/10 - 4s - loss: 1.1033 - accuracy: 0.5800 - precision_1: 0.6111 - recall_1: 0.3143
# Epoch 5/20
# 10/10 [==============================] - 4s 403ms/step - loss: 1.0296 - accuracy: 0.5600 - precision_1: 0.6944 - recall_1: 0.4167
# Epoch 6/20
# 10/10 [==============================] - 4s 394ms/step - loss: 1.0324 - accuracy: 0.5800 - precision_1: 0.7778 - recall_1: 0.4375
# Epoch 6/20
# Epoch 6/20
#  2/10 [=====>........................] - ETA: 1s - loss: 0.8829 - accuracy: 0.7500 - precision_1: 0.7679 - recall_1: 0.4300Epoch 9/10
#  8/10 [=======================>......] - ETA: 0s - loss: 1.0501 - accuracy: 0.5750 - precision_1: 0.6603 - recall_1: 0.3943- ETA: 2s - loss: 0.8469 - accuracy: 0.7250 - precision_1: 0.8235 - reca10/10 - 4s - loss: 1.0423 - accuracy: 0.5700 - precision_1: 0.6605 - recall_1: 0.3944
# Epoch 6/20
# 10/10 - 4s - loss: 1.0569 - accuracy: 0.4900 - precision_1: 0.6561 - recall_1: 0.3919
# Epoch 7/20
#  9/10 [==========================>...] - ETA: 0s - loss: 1.0637 - accuracy: 0.5556 - precision_1: 0.4444 - recall_1: 0.400010/10 - 4s - loss: 1.0573 - accuracy: 0.5700 - precision_1: 0.6977 - recall_1: 0.5000
# Epoch 6/20
# 10/10 [==============================] - 4s 422ms/step - loss: 1.0913 - accuracy: 0.5300 - precision_1: 0.6615 - recall_1: 0.4778
# Epoch 7/20
# 10/10 [==============================] - 4s 397ms/step - loss: 0.9700 - accuracy: 0.6000 - precision_1: 0.7879 - recall_1: 0.5200
# Epoch 7/20
# 10/10 [==============================] - 4s 391ms/step - loss: 0.9381 - accuracy: 0.6400 - precision_1: 0.7115 - recall_1: 0.4625
# Epoch 7/20Epoch 7/20
#
#  3/10 [========>.....................] - ETA: 2s - loss: 0.8622 - accuracy: 0.5333 - precision_1: 0.6429 - recall_1: 0.4091Epoch 10/10
#  8/10 [=======================>......] - ETA: 0s - loss: 1.0055 - accuracy: 0.5125 - precision_1: 0.7711 - recall_1: 0.518910/10 - 4s - loss: 1.0371 - accuracy: 0.5400 - precision_1: 0.7634 - recall_1: 0.5128
# Epoch 8/20
#  6/10 [=================>............]10/10 - 4s - loss: 1.0118 - accuracy: 0.5900 - precision_1: 0.7679 - recall_1: 0.5114
#  - ETA: 1s - loss: 0.8949 - accuracy: 0.6500 - precision_1: 0.7679 - recall_1: 0.5119Epoch 7/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9730 - accuracy: 0.5333 - precision_1: 1.0000 - recall_1: 0.500010/10 - 4s - loss: 1.0119 - accuracy: 0.5900 - precision_1: 1.0000 - recall_1: 0.5000
# Epoch 7/20
# 10/10 [==============================] - 4s 374ms/step - loss: 0.9742 - accuracy: 0.5400 - precision_1: 0.9231 - recall_1: 0.4000
# Epoch 8/20
# 10/10 [==============================] - 3s 338ms/step - loss: 0.9048 - accuracy: 0.6500 - precision_1: 0.7838 - recall_1: 0.4833
# Epoch 8/20
#  2/10 [=====>........................] - ETA: 1s - loss: 0.9376 - accuracy: 0.6500 - precision_1: 0.7818 - recall_1: 0.4778Epoch 8/20
# 10/10 [==============================] - 3s 333ms/step - loss: 0.9211 - accuracy: 0.6400 - precision_1: 0.7467 - recall_1: 0.4667
# Epoch 8/20
#  6/10 [=================>............] - ETA: 1s - loss: 0.9837 - accuracy: 0.5500 - precision_1: 0.6667 - recall_1: 0.4480
# C:\Users\rache\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.6660 - accuracy: 0.7250 - precision_1: 0.8200 - recall_1: 0.512510/10 - 3s - loss: 0.7836 - accuracy: 0.6600 - precision_1: 0.3750 - recall_1: 0.3000
# Epoch 12/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6864 - accuracy: 0.7000 - precision_1: 0.8000 - recall_1: 0.5714Epoch 13/20
# 10/10 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.7200 - precision_1: 0.7414 - recall_1: 0.5375Epoch 3/20
# 10/10 [==============================] - 3s 322ms/step - loss: 0.6726 - accuracy: 0.7200 - precision_1: 0.7414 - recall_1: 0.5375
# Epoch 13/20
# 10/10 [==============================] - 3s 332ms/step - loss: 0.7243 - accuracy: 0.7400 - precision_1: 1.0000 - recall_1: 0.5500
# Epoch 13/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.7228 - accuracy: 0.7000 - precision_1: 0.7700 - recall_1: 0.5775- ETA: 1s - loss: 0.6676 - accuracy: 0.6667 - precision_1: 0.7698 - recall_1: 0.57410/10 - 3s - loss: 0.6355 - accuracy: 0.7300 - precision_1: 0.7735 - recall_1: 0.5829
# Epoch 14/20
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6946 - accuracy: 0.7000 - precision_1: 0.7037 - recall_1: 0.475 - ETA: 0s - loss: 0.6598 - accuracy: 0.6714 - precision_1: 0.6667 - recall_1: 0.400010/10 - 3s - loss: 0.7221 - accuracy: 0.7300 - precision_1: 0.7907 - recall_1: 0.5667
# Epoch 13/20
# 10/10 [==============================] - 3s 344ms/step - loss: 0.6999 - accuracy: 0.7000 - precision_1: 0.7826 - recall_1: 0.5400
# Epoch 14/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.6315 - accuracy: 0.7500 - precision_1: 0.8333 - recall_1: 0.500010/10 - 4s - loss: 0.7919 - accuracy: 0.6900 - precision_1: 0.8889 - recall_1: 0.6000
# Epoch 13/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.7545 - accuracy: 0.6333 - precision_1: 0.7593 - recall_1: 0.5857Epoch 14/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6266 - accuracy: 0.7667 - precision_1: 0.8824 - recall_1: 0.7500Epoch 4/20
# 10/10 [==============================] - 3s 340ms/step - loss: 0.7412 - accuracy: 0.6400 - precision_1: 0.8302 - recall_1: 0.6286
# Epoch 14/20
# 10/10 [==============================] - 3s 344ms/step - loss: 0.6314 - accuracy: 0.7600 - precision_1: 0.7778 - recall_1: 0.7000
# Epoch 14/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.6321 - accuracy: 0.7375 - precision_1: 0.8161 - recall_1: 0.648710/10 - 3s - loss: 0.5999 - accuracy: 0.7500 - precision_1: 0.8145 - recall_1: 0.6475
# Epoch 15/20
#  7/10 [====================>.........] - ETA: 0s - loss: 0.6889 - accuracy: 0.7286 - precision_1: 0.7500 - recall_1: 0.650010/10 - 3s - loss: 0.6593 - accuracy: 0.7600 - precision_1: 0.7419 - recall_1: 0.6571
# Epoch 14/20
# 10/10 [==============================] - 3s 337ms/step - loss: 0.5886 - accuracy: 0.7700 - precision_1: 0.7590 - recall_1: 0.6300
# Epoch 15/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.6418 - accuracy: 0.7500 - precision_1: 0.8421 - recall_1: 0.800010/10 - 3s - loss: 0.7193 - accuracy: 0.7500 - precision_1: 0.7500 - recall_1: 0.7000
# Epoch 14/20
#  1/10 [==>...........................] - ETA: 0s - loss: 0.4101 - accuracy: 1.0000 - precision_1: 0.9048 - recall_1: 0.6333Epoch 15/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6574 - accuracy: 0.7333 - precision_1: 0.7143 - recall_1: 0.5000Epoch 5/20
# 10/10 [==============================] - 4s 352ms/step - loss: 0.7243 - accuracy: 0.6800 - precision_1: 0.7000 - recall_1: 0.5250
# Epoch 15/20
# 10/10 [==============================] - 3s 326ms/step - loss: 0.6497 - accuracy: 0.7400 - precision_1: 0.8824 - recall_1: 0.7500
# Epoch 15/20
#  6/10 [=================>............] - ETA: 1s - loss: 0.5032 - accuracy: 0.8667 - precision_1: 0.8613 - recall_1: 0.693010/10 - 3s - loss: 0.5547 - accuracy: 0.8200 - precision_1: 0.8564 - recall_1: 0.6870
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4676 - accuracy: 0.8556 - precision_1: 0.8590 - recall_1: 0.6872Epoch 16/20
#  7/10 [====================>.........] - ETA: 0s - loss: 0.5763 - accuracy: 0.8000 - precision_1: 0.8600 - recall_1: 0.673110/10 - 3s - loss: 0.5975 - accuracy: 0.7900 - precision_1: 0.5714 - recall_1: 0.4000
# Epoch 15/20
# 10/10 [==============================] - 3s 324ms/step - loss: 0.4777 - accuracy: 0.8400 - precision_1: 0.6875 - recall_1: 0.5500
# Epoch 16/20
# 10/10 - 3s - loss: 0.6503 - accuracy: 0.7300 - precision_1: 0.8140 - recall_1: 0.7000
# Epoch 15/20
#  1/10 [==>...........................] - ETA: 0s - loss: 0.3258 - accuracy: 1.0000 - precision_1: 0.9412 - recall_1: 0.8000Epoch 16/2
# 10/10 [==============================] - 3s 328ms/step - loss: 0.6499 - accuracy: 0.6700 - precision_1: 0.9074 - recall_1: 0.8167
# Epoch 16/20Epoch 6/20
#
# 10/10 [==============================] - 3s 326ms/step - loss: 0.5454 - accuracy: 0.8100 - precision_1: 0.9104 - recall_1: 0.7625
# Epoch 16/20
#  7/10 [====================>.........] - ETA: 0s - loss: 0.4664 - accuracy: 0.8286 - precision_1: 0.8984 - recall_1: 0.714910/10 - 3s - loss: 0.4220 - accuracy: 0.8300 - precision_1: 0.8955 - recall_1: 0.7200
# Epoch 17/20
# 10/10 [==============================] - 3s 324ms/step - loss: 0.3664 - accuracy: 0.8900 - precision_1: 0.9000 - recall_1: 0.7167
# 10/10 - 3s - loss: 0.5213 - accuracy: 0.8100 - precision_1: 0.8981 - recall_1: 0.7151
# Epoch 17/20
# Epoch 16/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.4676 - accuracy: 0.8250 - precision_1: 0.8889 - recall_1: 0.800010/10 - 3s - loss: 0.5943 - accuracy: 0.7500 - precision_1: 0.8333 - recall_1: 0.7500
# Epoch 16/20
#  1/10 [==>...........................] - ETA: 0s - loss: 0.1813 - accuracy: 1.0000 - precision_1: 0.9615 - recall_1: 0.8333Epoch 17/20
# 10/10 [==============================] - 3s 309ms/step - loss: 0.4688 - accuracy: 0.8200 - precision_1: 0.9259 - recall_1: 0.8333
# Epoch 17/20
# Epoch 7/20
# 10/10 [==============================] - 3s 339ms/step - loss: 0.4837 - accuracy: 0.8600 - precision_1: 1.0000 - recall_1: 0.6000
# Epoch 17/20
# 10/10 [==============================] - 3s 315ms/step - loss: 0.3398 - accuracy: 0.9000 - precision_1: 0.8943 - recall_1: 0.7429: 1s - loss: 0.2554 - accuracy: 0.9500 - precision_1: 0.9007 - recall_1 9/10 [==========================>...] - ETA: 0s - loss: 0.3098 - accuracy: 0.9222 - precision_1: 0.9054 - recall_1: 0.7
# Epoch 18/20
# 10/10 - 3s - loss: 0.2925 - accuracy: 0.9000 - precision_1: 0.8965 - recall_1: 0.7471
# Epoch 18/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0
# Epoch 19/20
# 10/10 [==============================] - 3s 339ms/step - loss: 0.2758 - accuracy: 0.9100 - precision_1: 0.8889 - recall_1: 0.8000
# Epoch 20/20
#  8/10 [=======================>......] - ETA: 0s - loss: 0.4233 - accuracy: 0.8750 - precision_1: 1.0000 - recall_1: 0.9000Epoch 10/20
# 10/10 [==============================] - 3s 346ms/step - loss: 0.4386 - accuracy: 0.8600 - precision_1: 0.8913 - recall_1: 0.8200: 0s - loss: 0.2667 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0
# Epoch 20/20
#  4/10 [===========>..................] - ETA: 1s - loss: 0.2535 - accuracy: 0.9250 - precision_1: 0.9193 - recall_1: 0.818810/10 - 3s - loss: 0.3570 - accuracy: 0.8900 - precision_1: 0.9184 - recall_1: 0.8182
# Epoch 20/20
# 10/10 [==============================] - 3s 344ms/step - loss: 0.1290 - accuracy: 0.9700 - precision_1: 0.9195 - recall_1: 0.8250
#  8/10 [=======================>......] - ETA: 0s - loss: 0.2613 - accuracy: 0.9500 - precision_1: 0.8444 - recall_1: 0.760010/10 - 3s - loss: 0.1843 - accuracy: 0.9200 - precision_1: 0.8727 - recall_1: 0.8000
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2398 - accuracy: 0.9556 - precision_1: 0.8803 - recall_1: 0.7923 6/10 [=================>............] - ETA: 1s - loss: 0.2979 - accuracy: 0.9000 - precision_1: 0.8700 - recall_1: 0.790910/10 - 3s - loss: 0.3778 - accuracy: 0.8500 - precision_1: 0.8692 - recall_1: 0.7750
# Epoch 20/20
# Epoch 11/20
# 10/10 [==============================] - 3s 334ms/step - loss: 0.2253 - accuracy: 0.9600 - precision_1: 1.0000 - recall_1: 1.0000ion_1: 1.0000 - recall_1: 1.0000 - ETA: 1s - loss: 0.3193 - accuracy: 0.9000 - precision_1: 0.9474 - recall_1: 0.900
# 10/10 [==============================] - 3s 328ms/step - loss: 0.3325 - accuracy: 0.8900 - precision_1: 0.9245 - recall_1: 0.8167
# 5/5 [==============================] - 1s 138ms/step
# 5/5 - 0s
# 10/10 - 2s - loss: 0.3168 - accuracy: 0.8900 - precision_1: 0.9128 - recall_1: 0.7850
# C:\Users\rache\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1/5 [=====>........................] - ETA: 0s10/10 - 2s - loss: 0.2986 - accuracy: 0.9200 - precision_1: 0.9159 - recall_1: 0.7840
# 3/5 [=================>............] - ETA:  - ETA: 0sEpoch 12/20
# 5/5 [==============================] - 0s 91ms/step
# Epoch 13/20
# 2/5 [===========>..................] - ETA: 0s5/5 - 0s
# Epoch 14/20
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0530s vs `on_predict_batch_end` time: 0.0932s). Check your callbacks.
# 4/5 [=======================>......] - ETA: 0sEpoch 1/20
# 5/5 [==============================] - 0s 90ms/step
# Epoch 1/30
# 5/5 - 0s
# Epoch 1/30Epoch 15/20
#
# Epoch 16/20
# Epoch 1/30
# Epoch 17/20
# Epoch 18/20
# Epoch 1/30
# Epoch 1/30
# Epoch 19/20
# Epoch 1/30
# Epoch 20/20
# Epoch 1/30
#  1/10 [==>...........................] - ETA: 1s - loss: 2.5221 - accuracy: 0.0500 - precision_1: 0.8672 - recall_1: 0.5045Epoch 2/20
#  8/10 [=======================>......] - ETA: 0s - loss: 1.3474 - accuracy: 0.4125 - precision_1: 0.5376 - recall_1: 0.1462 - ETA: 0s - loss: 1.3742 - accuracy: 0.3400 - precision_1: 0.6458 - recall_1: 0.1802recision_1: 0.5455 - recall10/10 - 2s - loss: 1.2934 - accuracy: 0.3700 - precision_1: 0.5426 - recall_1: 0.1449
# Epoch 2/30
# 10/10 [==============================] - 2s 244ms/step - loss: 1.6801 - accuracy: 0.1500 - precision_1: 0.5192 - recall_1: 0.1414
# Epoch 2/30
#  9/10 [==========================>...] - ETA: 0s - loss: 1.3256 - accuracy: 0.4444 - precision_1: 1.0000 - recall_1: 0.1000Epoch 3/20
# 10/10 [==============================] - 3s 291ms/step - loss: 1.3005 - accuracy: 0.4600 - precision_1: 0.3077 - recall_1: 0.1333
# Epoch 2/30
# 10/10 [==============================] - 4s 427ms/step - loss: 1.3159 - accuracy: 0.4300 - precision_1: 0.5112 - recall_1: 0.2459
# Epoch 2/30
#  7/10 [====================>.........] - ETA: 1s - loss: 1.2667 - accuracy: 0.4286 - precision_1: 0.6667 - recall_1: 0.200010/10 - 4s - loss: 1.2332 - accuracy: 0.4100 - precision_1: 0.6667 - recall_1: 0.4000
# Epoch 2/30
#  7/10 [====================>.........] - ETA: 1s - loss: 1.1643 - accuracy: 0.5429 - precision_1: 0.5833 - recall_1: 0.20010/10 - 4s - loss: 1.2997 - accuracy: 0.4500 - precision_1: 0.5882 - recall_1: 0.2000
#  3/10 [========>.....................] - ETA: 1s - loss: 1.1907 - accuracy: 0.3667 - precision_1: 0.6500 - recall_1: 0.2167Epoch 2/30
# 10/10 - 4s - loss: 1.1746 - accuracy: 0.5100 - precision_1: 0.6531 - recall_1: 0.2286
# Epoch 3/30
# 10/10 [==============================] - 4s 420ms/step - loss: 1.2251 - accuracy: 0.4500 - precision_1: 0.6429 - recall_1: 0.3000
# Epoch 3/30
#  9/10 [==========================>...] - ETA: 0s - loss: 1.1592 - accuracy: 0.5444 - precision_1: 0.5517 - recall_1: 0.2000Epoch 4/20
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2996 - accuracy: 0.6000 - precision_1: 0.5238 - recall_1: 0.1571Epoch 2/30
# 10/10 [==============================] - 4s 398ms/step - loss: 1.1276 - accuracy: 0.5700 - precision_1: 0.8750 - recall_1: 0.7000
# Epoch 3/30
# 10/10 [==============================] - 4s 379ms/step - loss: 1.1492 - accuracy: 0.5300 - precision_1: 0.6552 - recall_1: 0.2235
#  5/10 [==============>...............] - ETA: 1s - loss: 1.3223 - accuracy: 0.3600 - precision_1: 0.6190 - recall_1: 0.2167Epoch 3/30
# 10/10 - 4s - loss: 1.2158 - accuracy: 0.4500 - precision_1: 0.6176 - recall_1: 0.2211
# Epoch 3/30
#  7/10 [====================>.........] - ETA: 1s - loss: 1.1964 - accuracy: 0.4571 - precision_1: 0.8125 - recall_1: 0.288910/10 - 3s - loss: 1.1088 - accuracy: 0.5300 - precision_1: 0.7692 - recall_1: 0.2500
# Epoch 4/30
#  2/10 [=====>........................] - ETA: 1s - loss: 1.2602 - accuracy: 0.2500 - precision_1: 0.7778 - recall_1: 0.254510/10 - 4s - loss: 1.1388 - accuracy: 0.5500 - precision_1: 0.7455 - recall_1: 0.2733
# Epoch 3/30
# 10/10 [==============================] - 4s 367ms/step - loss: 1.1074 - accuracy: 0.6100 - precision_1: 0.6000 - recall_1: 0.2400
# Epoch 4/30
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4052 - accuracy: 0.5000 - precision_1: 0.6875 - recall_1: 0.3667Epoch 5/20
# 10/10 [==============================] - 4s 363ms/step - loss: 1.1008 - accuracy: 0.5500 - precision_1: 0.7105 - recall_1: 0.3857
# Epoch 4/30
# Epoch 3/30
# 10/10 [==============================] - 4s 362ms/step - loss: 1.0878 - accuracy: 0.4900 - precision_1: 0.6766 - recall_1: 0.3778
# Epoch 4/30
# 10/10 - 4s - loss: 1.0693 - accuracy: 0.5600 - precision_1: 0.6812 - recall_1: 0.3811
# Epoch 4/30
#  1/10 [==>...........................] - ETA: 0s - loss: 0.9775 - accuracy: 0.5000 - precision_1: 0.7273 - recall_1: 0.350010/10 - 3s - loss: 1.0928 - accuracy: 0.5700 - precision_1: 0.5758 - recall_1: 0.3000
#  8/10 [=======================>......] - ETA: 0s - loss: 1.0538 - accuracy: 0.5875 - precision_1: 0.5714 - recall_1: 0.3000
#  2/10 [=====>........................] - ETA: 1s - loss: 0.9694 - accuracy: 0.5500 - precision_1: 1.0000 - recall_1: 0.300010/10 - 4s - loss: 1.1086 - accuracy: 0.5100 - precision_1: 0.6818 - recall_1: 0.3750
# Epoch 4/30
# 10/10 [==============================] - 4s 374ms/step - loss: 1.0937 - accuracy: 0.5900 - precision_1: 0.6250 - recall_1: 0.4000
# Epoch 5/30
# 10/10 [==============================] - 3s 347ms/step - loss: 1.0339 - accuracy: 0.5700 - precision_1: 0.9231 - recall_1: 0.4000
# Epoch 5/30
# Epoch 4/30 1/10 [==>...........................] - ETA: 0s - loss: 1.1596 - accuracy: 0.6000 - precision_1: 0.8571 - recall_1: 0.3600
# Epoch 6/20
# ...
# 4/4 - 2s - loss: 0.2981 - accuracy: 0.9100 - precision_1: 0.6667 - recall_1: 0.5000
# Epoch 25/30
# 4/4 [==============================] - 2s 595ms/step - loss: 0.4961 - accuracy: 0.8300 - precision_1: 0.8000 - recall_1: 0.8000
# Epoch 25/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.2693 - accuracy: 0.9333 - precision_1: 0.9273 - recall_1: 0.85004/4 - 2s - loss: 0.3409 - accuracy: 0.8500 - precision_1: 0.8846 - recall_1: 0.5750
# Epoch 24/30
# 4/4 [==============================] - 3s 629ms/step - loss: 0.3601 - accuracy: 0.8600 - precision_1: 0.9052 - recall_1: 0.7500
# Epoch 25/30
# 4/4 [==============================] - 2s 619ms/step - loss: 0.2627 - accuracy: 0.9300 - precision_1: 0.8962 - recall_1: 0.7308
# Epoch 24/30
# 4/4 - 2s - loss: 0.3929 - accuracy: 0.9100 - precision_1: 0.9150 - recall_1: 0.7778
# Epoch 24/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.4939 - accuracy: 0.8667 - precision_1: 0.9091 - recall_1: 0.7647Epoch 6/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2771 - accuracy: 0.9667 - precision_1: 0.9412 - recall_1: 0.8615Epoch 25/30
# 4/4 - 3s - loss: 0.2441 - accuracy: 0.9400 - precision_1: 0.8644 - recall_1: 0.6375
# Epoch 26/30
# 4/4 [==============================] - 3s 661ms/step - loss: 0.4646 - accuracy: 0.8800 - precision_1: 0.9355 - recall_1: 0.8286
# Epoch 26/30
# 4/4 - 2s - loss: 0.2418 - accuracy: 0.9300 - precision_1: 0.9138 - recall_1: 0.7571
# Epoch 25/30
# 4/4 [==============================] - 2s 572ms/step - loss: 0.2269 - accuracy: 0.9500 - precision_1: 0.9371 - recall_1: 0.8200
# Epoch 25/30
# 4/4 [==============================] - 3s 662ms/step - loss: 0.2548 - accuracy: 0.9500 - precision_1: 0.9394 - recall_1: 0.8158
# Epoch 26/30
# 4/4 - 2s - loss: 0.5348 - accuracy: 0.8100 - precision_1: 0.9344 - recall_1: 0.8143
# Epoch 25/30
# Epoch 7/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3693 - accuracy: 0.8667 - precision_1: 0.8966 - recall_1: 0.8667Epoch 26/30
# 4/4 - 2s - loss: 0.2113 - accuracy: 0.9500 - precision_1: 0.8523 - recall_1: 0.6818
# Epoch 27/30
# 2/4 [==============>...............] - ETA: 1s - loss: 0.2683 - accuracy: 0.9333 - precision_1: 0.9825 - recall_1: 0.93334/4 - 3s - loss: 0.1908 - accuracy: 0.9600 - precision_1: 0.9209 - recall_1: 0.8000
# Epoch 26/30
# 4/4 [==============================] - 3s 708ms/step - loss: 0.3884 - accuracy: 0.9200 - precision_1: 0.9189 - recall_1: 0.8000
# Epoch 27/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2358 - accuracy: 0.9556 - precision_1: 0.9880 - recall_1: 0.91114/4 - 2s - loss: 0.3690 - accuracy: 0.8900 - precision_1: 1.0000 - recall_1: 0.9286
# Epoch 26/30
# 4/4 [==============================] - 2s 614ms/step - loss: 0.2240 - accuracy: 0.9400 - precision_1: 0.9865 - recall_1: 0.9125
# Epoch 26/30
# 4/4 [==============================] - 2s 606ms/step - loss: 0.2411 - accuracy: 0.9400 - precision_1: 0.9759 - recall_1: 0.9000
# Epoch 27/30
# Epoch 8/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1932 - accuracy: 1.0000 - precision_1: 0.9767 - recall_1: 0.9333Epoch 27/30
# 2/4 [==============>...............] - ETA: 1s - loss: 0.3611 - accuracy: 0.9000 - precision_1: 0.9333 - recall_1: 0.82734/4 - 3s - loss: 0.2228 - accuracy: 0.9100 - precision_1: 0.9531 - recall_1: 0.8714
# Epoch 28/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.1757 - accuracy: 0.9500 - precision_1: 0.9673 - recall_1: 0.92504/4 - 3s - loss: 0.1796 - accuracy: 0.9600 - precision_1: 0.9394 - recall_1: 0.8857
# Epoch 27/30
# 4/4 [==============================] - 3s 649ms/step - loss: 0.3547 - accuracy: 0.8800 - precision_1: 0.8621 - recall_1: 0.6250
# Epoch 28/30
# 4/4 [==============================] - 2s 524ms/step - loss: 0.1749 - accuracy: 0.9600 - precision_1: 0.9490 - recall_1: 0.8455
# Epoch 28/30
# 4/4 [==============================] - 3s 639ms/step - loss: 0.1872 - accuracy: 0.9600 - precision_1: 1.0000 - recall_1: 0.9000
# Epoch 27/30
# 4/4 - 3s - loss: 0.3125 - accuracy: 0.9300 - precision_1: 0.8421 - recall_1: 0.8000
# Epoch 27/30
# Epoch 9/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2201 - accuracy: 0.9000 - precision_1: 0.9077 - recall_1: 0.8429Epoch 28/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.3419 - accuracy: 0.9000 - precision_1: 0.9333 - recall_1: 0.80774/4 - 3s - loss: 0.1670 - accuracy: 0.9700 - precision_1: 0.9528 - recall_1: 0.9300
# Epoch 29/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.1732 - accuracy: 0.9500 - precision_1: 0.9667 - recall_1: 0.98334/4 - 3s - loss: 0.1474 - accuracy: 0.9900 - precision_1: 0.9329 - recall_1: 0.8687
# 3/4 [=====================>........] - ETA: 0s - loss: 0.3132 - accuracy: 0.9111 - precision_1: 0.8846 - recall_1: 0.7667Epoch 28/30
# 4/4 [==============================] - 3s 625ms/step - loss: 0.3231 - accuracy: 0.8900 - precision_1: 0.5806 - recall_1: 0.4500
# Epoch 29/30
# 4/4 [==============================] - 2s 542ms/step - loss: 0.1579 - accuracy: 0.9700 - precision_1: 0.6829 - recall_1: 0.5600
# 4/4 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9300 - precision_1: 0.7848 - recall_1: 0.6889Epoch 29/30
# 4/4 [==============================] - 2s 573ms/step - loss: 0.1973 - accuracy: 0.9300 - precision_1: 0.7848 - recall_1: 0.6889
# Epoch 28/30
# 4/4 - 2s - loss: 0.2670 - accuracy: 0.9500 - precision_1: 0.8376 - recall_1: 0.7538
# Epoch 28/30
# Epoch 10/30
# Epoch 29/30
# 2/4 [==============>...............] - ETA: 1s - loss: 0.1152 - accuracy: 0.9833 - precision_1: 0.9009 - recall_1: 0.83334/4 - 3s - loss: 0.1426 - accuracy: 0.9600 - precision_1: 0.9160 - recall_1: 0.8720
# Epoch 30/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1214 - accuracy: 0.9889 - precision_1: 1.0000 - recall_1: 1.00004/4 - 3s - loss: 0.1092 - accuracy: 0.9700 - precision_1: 0.9700 - recall_1: 0.9700
# Epoch 29/30
# 4/4 [==============================] - 2s 552ms/step - loss: 0.3810 - accuracy: 0.8400 - precision_1: 0.9638 - recall_1: 0.9500
# Epoch 30/30
# 4/4 [==============================] - 2s 608ms/step - loss: 0.1840 - accuracy: 0.9600 - precision_1: 0.9500 - recall_1: 0.9500
# Epoch 29/30
# 4/4 [==============================] - 3s 639ms/step - loss: 0.1157 - accuracy: 0.9900 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 30/30
# 4/4 - 3s - loss: 0.2518 - accuracy: 0.9400 - precision_1: 0.8889 - recall_1: 0.8000
# Epoch 29/30
# Epoch 30/30
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2207 - accuracy: 0.9333 - precision_1: 0.9556 - recall_1: 0.9214Epoch 11/30
# 2/4 [==============>...............] - ETA: 0s - loss: 0.3005 - accuracy: 0.9167 - precision_1: 0.9535 - recall_1: 0.91114/4 - 2s - loss: 0.1688 - accuracy: 0.9400 - precision_1: 0.9175 - recall_1: 0.8591
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2321 - accuracy: 0.9444 - precision_1: 0.9292 - recall_1: 0.88654/4 - 3s - loss: 0.1396 - accuracy: 0.9500 - precision_1: 0.9191 - recall_1: 0.8702
# Epoch 30/30
# 4/4 [==============================] - 2s 565ms/step - loss: 0.3032 - accuracy: 0.8900 - precision_1: 0.9205 - recall_1: 0.8687
# 4/4 [==============================] - 2s 546ms/step - loss: 0.1261 - accuracy: 0.9900 - precision_1: 0.9218 - recall_1: 0.8720
# 4/4 [==============================] - 2s 559ms/step - loss: 0.2252 - accuracy: 0.9500 - precision_1: 0.9222 - recall_1: 0.8714
# Epoch 30/30
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8C920160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 0s
# 4/4 - 2s - loss: 0.2238 - accuracy: 0.9200 - precision_1: 0.9600 - recall_1: 0.9600
# C:\Users\rache\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 12/30
# Epoch 30/30
# 3/4 [=====================>........] - ETA: 0s - loss: 0.1447 - accuracy: 0.9556 - precision_1: 0.9227 - recall_1: 0.8458WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8DDE6F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 [==============>...............] - ETA: 0s4/4 - 1s - loss: 0.0816 - accuracy: 0.9800 - precision_1: 0.9217 - recall_1: 0.8480
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8C1FE9D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9600 - precision_1: 0.9072 - recall_1: 0.825WARNING:tensorflow:7 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019D1189BDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 139ms/step
# 4/4 [==============================] - 2s 417ms/step - loss: 0.1392 - accuracy: 0.9600 - precision_1: 0.9072 - recall_1: 0.8250
# 4/4 - 1s - loss: 0.1748 - accuracy: 0.9700 - precision_1: 0.9058 - recall_1: 0.8206
# 2/2 [==============================] - ETA: 0sEpoch 13/30
# 2/2 [==============================] - 0s 132ms/step
# Epoch 1/30
# Epoch 14/30
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019D2B8C7C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 0s
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019D1CB6DC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 49ms/step
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C9BFB0160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 - 0s
# Epoch 15/30
# Epoch 16/30
# Epoch 17/30
# Epoch 18/30
# Epoch 19/30
# Epoch 20/30
# Epoch 21/30
# Epoch 22/30
# Epoch 2/30
# Epoch 23/30
# Epoch 3/30
# Epoch 4/30
# Epoch 24/30
# Epoch 25/30
# Epoch 5/30
# Epoch 26/30
# Epoch 6/30
# Epoch 27/30
# Epoch 7/30
# Epoch 28/30
# Epoch 8/30
# Epoch 29/30
# Epoch 9/30
# Epoch 30/30
# Epoch 10/30
# Epoch 11/30
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8B885940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 12/30
# Epoch 13/30
# Epoch 14/30
# Epoch 15/30
# Epoch 16/30
# Epoch 17/30
# Epoch 18/30
# Epoch 19/30
# Epoch 20/30
# Epoch 21/30
# Epoch 22/30
# Epoch 23/30
# Epoch 24/30
# Epoch 25/30
# Epoch 26/30
# Epoch 27/30
# Epoch 28/30
# Epoch 29/30
# Epoch 30/30
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C8B885E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
nn_gs.get_params()
# Out:
# {'cv': 3,
#  'error_score': nan,
#  'estimator__epochs': 50,
#  'estimator__batch_size': 150,
#  'estimator__verbose': 1,
#  'estimator__build_fn': <function __main__.build_model()>,
#  'estimator': <tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier at 0x19d1c131820>,
#  'n_jobs': -1,
#  'param_grid': {'batch_size': [10, 20, 30],
#   'epochs': [10, 20, 30],
#   'verbose': [1, 2, 3]},
#  'pre_dispatch': '2*n_jobs',
#  'refit': False,
#  'return_train_score': False,
#  'scoring': {'accuracy': make_scorer(accuracy_score),
#   'precision': make_scorer(precision_score, average=weighted),
#   'recall': make_scorer(recall_score, average=weighted)},
#  'verbose': 0}

# %%
best_nn = KerasClassifier(build_model,
                              verbose=1,
                              batch_size=10,
                              epochs=10)

nn_gs_results = SaveModel(model=best_nn, 
                          model_name='best_nn',
                          X_train=X_train,
                          X_test=X_test,
                          y_train=y_train_multiclass,
                          y_test=y_test_multiclass,
                          X_tt=extra_val_images,
                          y_tt=extra_val_labels_multiclass,
                          X_val=val_images,
                          y_val=val_labels)

# %%
nn_gs_results.score_model_train_test()
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 51ms/step - loss: 1.2598 - accuracy: 0.4733 - precision_1: 0.8047 - recall_1: 0.5440
# Epoch 2/10
# 15/15 [==============================] - 1s 65ms/step - loss: 1.1678 - accuracy: 0.5400 - precision_1: 0.7500 - recall_1: 0.1800
# Epoch 3/10
# 15/15 [==============================] - 1s 69ms/step - loss: 1.0955 - accuracy: 0.5467 - precision_1: 0.6410 - recall_1: 0.3333
# Epoch 4/10
# 15/15 [==============================] - 1s 72ms/step - loss: 1.0648 - accuracy: 0.5467 - precision_1: 0.6301 - recall_1: 0.3067
# Epoch 5/10
# 15/15 [==============================] - 1s 93ms/step - loss: 1.0117 - accuracy: 0.5400 - precision_1: 0.6829 - recall_1: 0.3733
# Epoch 6/10
# 15/15 [==============================] - 1s 99ms/step - loss: 0.9743 - accuracy: 0.5733 - precision_1: 0.7391 - recall_1: 0.4533
# Epoch 7/10
# 15/15 [==============================] - 1s 79ms/step - loss: 0.8896 - accuracy: 0.6400 - precision_1: 0.7778 - recall_1: 0.4667
# Epoch 8/10
# 15/15 [==============================] - 1s 86ms/step - loss: 0.8836 - accuracy: 0.6600 - precision_1: 0.7431 - recall_1: 0.5400
# Epoch 9/10
# 15/15 [==============================] - 1s 80ms/step - loss: 0.7875 - accuracy: 0.7133 - precision_1: 0.7870 - recall_1: 0.5667
# Epoch 10/10
# 15/15 [==============================] - 1s 75ms/step - loss: 0.7764 - accuracy: 0.7067 - precision_1: 0.7434 - recall_1: 0.5600
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019C9890A5E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 15/15 [==============================] - 0s 15ms/step
# 5/5 [==============================] - 0s 16ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-301-6213ff5885b4> in <module>
# ----> 1 nn_gs_results.score_model_train_test()
#
# ~\Documents\Flatiron\phase_5\Project\Retinal-OCT-Images\src\model_handling.py in score_model_train_test(self)
#     185           self.model_scores = pd.DataFrame([
#     186                          [self.model_name, 'train', 'accuracy_score', accuracy_score(self.y_train, ytrain_hat)],
# --> 187                          [self.model_name, 'train', 'recall_score', recall_score(self.y_train, ytrain_hat)],
#     188                          [self.model_name, 'train', 'precision_score', precision_score(self.y_train, ytrain_hat)],
#     189                          [self.model_name, 'train', 'f1_score', f1_score(self.y_train, ytrain_hat)],
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     209                     )
#     210                 ):
# --> 211                     return func(*args, **kwargs)
#     212             except InvalidParameterError as e:
#     213                 # When the function is just a wrapper around an estimator, we allow
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2297     array([1. , 1. , 0.5])
#    2298     """
# -> 2299     _, r, _, _ = precision_recall_fscore_support(
#    2300         y_true,
#    2301         y_pred,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     182             global_skip_validation = get_config()["skip_parameter_validation"]
#     183             if global_skip_validation:
# --> 184                 return func(*args, **kwargs)
#     185
#     186             func_sig = signature(func)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1719     """
#    1720     zero_division_value = _check_zero_division(zero_division)
# -> 1721     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1722
#    1723     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1514             if y_type == "multiclass":
#    1515                 average_options.remove("samples")
# -> 1516             raise ValueError(
#    1517                 "Target is %s but average='binary'. Please "
#    1518                 "choose another average setting, one of %r." % (y_type, average_options)
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
# model_dict = ModelStorer()

# %%
# best_estimator = nn_gs.best_estimator_

# %%
from sklearn.utils.multiclass import type_of_target
type_of_target(y_train)
# Out:
# 'multilabel-indicator'

# %%
# Convert to multiclass format by choosing the class with the highest probability
y_train_multiclass = np.argmax(y_train, axis=1)
extra_val_labels_multiclass = np.argmax(extra_val_labels, axis=1)
y_test_multiclass = np.argmax(y_test, axis=1)

# %%
# # best estimator from the grid search
# best_estimator = nn_gs.best_estimator_

# # Define scoring functions for accuracy, precision, and recall
# scoring = {
#     'accuracy': make_scorer(accuracy_score),
#     'precision': make_scorer(precision_score, average='weighted'),
#     'recall': make_scorer(recall_score, average='weighted')
# }

# # Perform cross-validation to obtain scores
# accuracy_scores = cross_val_score(best_estimator, X_train, y_train_multiclass, cv=3, scoring=scoring['accuracy'])
# precision_scores = cross_val_score(best_estimator, X_train, y_train_multiclass, cv=3, scoring=scoring['precision'])
# recall_scores = cross_val_score(best_estimator, X_train, y_train_multiclass, cv=3, scoring=scoring['recall'])

# # Print the scores
# print("Accuracy Scores:", accuracy_scores.mean())
# print("Precision Scores:", precision_scores.mean())
# print("Recall Scores:", recall_scores.mean())

# %%
# model_dict.add_model(nn_gs_results)

# %% [markdown]
# recall v precision: recall prioritizes minimizing false negatives, precision minimizes false positives. We don't want to miss a potential diagnosis and call it normal, so we need to prioritize recall.
#
# Then:
# 1. train test split (DONE)
# 2. baseline model (DONE)
# 3. fsm (DONE)
# 4. ssm, tsm, etc. until final
# 5. try gridsearching
# 6. fine tune activators, optimizers, how many units per layer, num of layers, etc.
# 7. print scores, plot loss/accuracy/recall, confusion matrix, roc curves. can do functions
# 8. use sequential models to start, look up other architectures
# 9. conclusion & next steps
#
# Each session should have:
# 1. create model, fit it, look at results, save both model and results
# 2. loss/accuracy plots, confusion matrices, roc curves
# 3. explanation of metrics, work out next model, etc.
# 4. maybe at the end can add a ranking
# 5. maybe print out some of the predicted labels for an image, inspect it visually
